# %%
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import OrderedDict
from tqdm import tqdm
import scipy
import pyDOE

import torch
import torch.nn as nn

# %%
# Multi-layer Perceptron
class NN(nn.Module):
    def __init__(
        self,
        input_size,  
        hidden_size, 
        output_size, 
        depth,
        act=torch.nn.Tanh,
    ):
        super(NN, self).__init__()
        
        layers = [('input', torch.nn.Linear(input_size, hidden_size))]
        layers.append(('input_activation', act()))
        for i in range(depth): 
            layers.append(
                (f'hidden_{i}', torch.nn.Linear(hidden_size, hidden_size))
            )
            layers.append((f'activation_{i}', act()))
        layers.append(('output', torch.nn.Linear(hidden_size, output_size)))

        layerDict = OrderedDict(layers)
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %%
# 간격
h = 0.1
k = 0.1
# (x,y) 좌표점
x = torch.arange(-np.pi, np.pi + h, h)
y = torch.arange(-np.pi, np.pi + k, k)
X = torch.stack(torch.meshgrid(x, y)).reshape(2, -1).T
print("x,y,X")
print(x.shape,y.shape,X.shape)

# Boundary Conditions
# 경계점은 mesh grid로 Data points를 생성
bc1 = torch.stack(torch.meshgrid(x[0], y)).reshape(2, -1).T 
bc2 = torch.stack(torch.meshgrid(x[-1], y)).reshape(2, -1).T
X_train = torch.cat([bc1, bc2]) # X_train : Data BCs
print("bc1,bc2,X_train")
print(bc1.shape,bc2.shape,X_train.shape)

f_bc1 = torch.zeros(len(bc1))
f_bc2 = torch.zeros(len(bc2))
f_train = torch.cat([f_bc1, f_bc2]) # f_train : PDE BCs
print("f_bc1,f_bc2,f_train")
print(f_bc1.shape,f_bc2.shape,f_train.shape)
f_train = f_train.unsqueeze(1)
print("f_train.shape unsqueeae(1):", f_train.shape)

# Domain Data points는 Latin Hypercube Sampling을 통해 생성
sample_data = pyDOE.lhs(2, samples=3000)
sample_data -= 0.5
sample_data *= 2 * np.pi
x = torch.tensor(sample_data.T[0])
y = torch.tensor(sample_data.T[1])
X = torch.cat([x, y]).reshape(2,-1).T
print("x,y,X")
print(x.shape,y.shape,X.shape)
# Out:
# x,y,X
# torch.Size([64]) torch.Size([64]) torch.Size([4096, 2])
# bc1,bc2,X_train
# torch.Size([64, 2]) torch.Size([64, 2]) torch.Size([128, 2])
# f_bc1,f_bc2,f_train
# torch.Size([64]) torch.Size([64]) torch.Size([128])
# f_train.shape unsqueeae(1): torch.Size([128, 1])
# x,y,X
# torch.Size([3000]) torch.Size([3000]) torch.Size([3000, 2])

# %%
class Net:
    def __init__(self, A=1.0, B=1.0, C=1.0):
        device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

        self.model = NN(
            input_size=2,
            hidden_size=100,
            output_size=1,
            depth=8,
            act=torch.nn.Tanh
        ).to(device)
        
        # 간격
        self.h = 0.1
        self.k = 0.1
        # (x,y) 좌표점
        x = torch.arange(-np.pi, np.pi + self.h, self.h)
        y = torch.arange(-np.pi, np.pi + self.k, self.k)
        self.X = torch.stack(torch.meshgrid(x, y)).reshape(2, -1).T
        
        # u = f(x,y)=A*sin(B*x)*sin(C*y)
        self.A = torch.tensor([A,]).to(device)
        self.B = torch.tensor([B,]).to(device)
        self.C = torch.tensor([C,]).to(device)
        
        # Boundary Conditions
        # 경계점은 mesh grid로 Data points를 생성
        bc1 = torch.stack(torch.meshgrid(x[0], y)).reshape(2, -1).T 
        bc2 = torch.stack(torch.meshgrid(x[-1], y)).reshape(2, -1).T
        self.X_train = torch.cat([bc1, bc2]) # X_train : Data BCs
        
        f_bc1 = torch.zeros(len(bc1))
        f_bc2 = torch.zeros(len(bc2))
        self.f_train = torch.cat([f_bc1, f_bc2]) # f_train : PDE BCs
        self.f_train = self.f_train.unsqueeze(1)
        
        # Domain Data points는 Latin Hypercube Sampling을 통해 생성
        sample_data = pyDOE.lhs(2, samples=3000)
        sample_data -= 0.5
        sample_data *= 2 * np.pi
        x = torch.tensor(sample_data.T[0], dtype=torch.float)
        y = torch.tensor(sample_data.T[1], dtype=torch.float)
        self.X = torch.cat([x, y]).reshape(2,-1).T
        
        self.X = self.X.to(device)
        self.X_train = self.X_train.to(device)
        self.f_train = self.f_train.to(device)
        self.X.requires_grad = True
        
        self.criterion = torch.nn.MSELoss()
        self.iter = 1
        
        self.optimizer = torch.optim.LBFGS(
            self.model.parameters(), 
            lr=1.0, 
            max_iter=50000, 
            max_eval=50000, 
            history_size=5,
            tolerance_grad=1e-13, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe",
        )
        self.adam = torch.optim.Adam(self.model.parameters(), lr=0.00001)
        self.data_loss_hist = []
        self.pde_loss_hist = []
        self.total_loss_hist = []
        self.print_model_state()
        
    # this won't use
    def func(x,y,a=1,b=1,c=1):
        return a*np.sin(b*x)*np.sin(c*y)
    
    def print_model_state(self):
        print("Model's state_dict:")
        for param_tensor in self.model.state_dict():
            print(param_tensor, "\t", self.model.state_dict()[param_tensor].size())
            
    def loss_func(self):
        
        # 초기화
        self.adam.zero_grad()
        self.optimizer.zero_grad()
        
        f_pred = self.model(self.X_train)
        loss_data = self.criterion(f_pred, self.f_train)
        u = self.model(self.X)

        du_dX = torch.autograd.grad(
            inputs=self.X, 
            outputs=u, 
            grad_outputs=torch.ones_like(u), 
            retain_graph=True, 
            create_graph=True
        )[0]
        
        du_dx = du_dX[:, 0]
        du_dy = du_dX[:, 1]
        du_dXX = torch.autograd.grad(
            inputs=self.X, 
            outputs=du_dX, 
            grad_outputs=torch.ones_like(du_dX), 
            retain_graph=True, 
            create_graph=True
        )[0]
        
        du_dxx = du_dXX[:,0]
        du_dyy = du_dXX[:,1]
        
        # u = f(x,y)=A*sin(B*x)*sin(C*y)
        # fxx + fyy + A*(B^2+C^2)*f = 0
        loss_pde = self.criterion( du_dxx + du_dyy , -self.A*(self.B*self.B+self.C*self.C)*u.squeeze() )

        loss = loss_pde + loss_data
        loss.backward()
        if self.iter % 100 == 0: 
            print(f"it :{self.iter:05}, Data Loss :{loss_data.item()},\t PDE Loss :{loss_pde.item()}, \t Total Loss :{loss.item()}")
            self.total_loss_hist.append(loss.item())
            self.pde_loss_hist.append(loss_pde.item())
            self.data_loss_hist.append(loss_data.item())
        self.iter = self.iter + 1
        return loss
    
    def train(self):
        self.model.train()
        print("train with Adam optimizer")
        for i in range(1000):
            self.adam.step(self.loss_func)
        print("train with L-BFGs")
        self.optimizer.step(self.loss_func)
        
    def eval_(self):
        self.model.eval()

# %% [markdown]
# $$f(x,y)=1 \cdot \sin(1\cdot x)\sin(1\cdot y)\quad \text{--Train--} $$

# %%
net = Net()
# Out:
# Model's state_dict:
# layers.input.weight 	 torch.Size([100, 2])
# layers.input.bias 	 torch.Size([100])
# layers.hidden_0.weight 	 torch.Size([100, 100])
# layers.hidden_0.bias 	 torch.Size([100])
# layers.hidden_1.weight 	 torch.Size([100, 100])
# layers.hidden_1.bias 	 torch.Size([100])
# layers.hidden_2.weight 	 torch.Size([100, 100])
# layers.hidden_2.bias 	 torch.Size([100])
# layers.hidden_3.weight 	 torch.Size([100, 100])
# layers.hidden_3.bias 	 torch.Size([100])
# layers.hidden_4.weight 	 torch.Size([100, 100])
# layers.hidden_4.bias 	 torch.Size([100])
# layers.hidden_5.weight 	 torch.Size([100, 100])
# layers.hidden_5.bias 	 torch.Size([100])
# layers.hidden_6.weight 	 torch.Size([100, 100])
# layers.hidden_6.bias 	 torch.Size([100])
# layers.hidden_7.weight 	 torch.Size([100, 100])
# layers.hidden_7.bias 	 torch.Size([100])
# layers.output.weight 	 torch.Size([1, 100])
# layers.output.bias 	 torch.Size([1])

# %%
net.train()
# Out:
# train with Adam optimizer
# it :00100, Data Loss :0.00010772039968287572,	 PDE Loss :0.00026348797837272286, 	 Total Loss :0.0003712083853315562
# it :00200, Data Loss :5.594396952801617e-06,	 PDE Loss :2.099036646541208e-05, 	 Total Loss :2.6584762963466346e-05
# it :00300, Data Loss :4.9689156185195316e-06,	 PDE Loss :1.8410166376270354e-05, 	 Total Loss :2.3379081540042534e-05
# it :00400, Data Loss :4.2604601731e-06,	 PDE Loss :1.5922307284199633e-05, 	 Total Loss :2.0182767912046984e-05
# it :00500, Data Loss :3.604589892347576e-06,	 PDE Loss :1.3559249055106193e-05, 	 Total Loss :1.7163838492706418e-05
# it :00600, Data Loss :3.015964466612786e-06,	 PDE Loss :1.1393922250135802e-05, 	 Total Loss :1.4409886716748588e-05
# it :00700, Data Loss :2.4987725737446453e-06,	 PDE Loss :9.45886131376028e-06, 	 Total Loss :1.1957634342252277e-05
# it :00800, Data Loss :2.051293677141075e-06,	 PDE Loss :7.763130270177498e-06, 	 Total Loss :9.814423719944898e-06
# it :00900, Data Loss :1.6692588360456284e-06,	 PDE Loss :6.302492693066597e-06, 	 Total Loss :7.971751983859576e-06
# it :01000, Data Loss :1.346880253549898e-06,	 PDE Loss :5.0657322390179615e-06, 	 Total Loss :6.41261249256786e-06
# train with L-BFGs
# it :01100, Data Loss :1.9329821299152172e-08,	 PDE Loss :4.866743807951934e-08, 	 Total Loss :6.79972629313852e-08
# it :01200, Data Loss :6.555260334550894e-09,	 PDE Loss :3.703594231296847e-08, 	 Total Loss :4.359120353569779e-08
# it :01300, Data Loss :3.2821256823467593e-09,	 PDE Loss :2.7124560375568763e-08, 	 Total Loss :3.04066851697371e-08
# it :01400, Data Loss :2.957424083405158e-09,	 PDE Loss :2.5985897877944808e-08, 	 Total Loss :2.8943322405439176e-08
# it :01500, Data Loss :2.178551383735794e-08,	 PDE Loss :1.4253353697313287e-07, 	 Total Loss :1.6431904725777713e-07
# it :01600, Data Loss :2.3740961196949684e-08,	 PDE Loss :1.637773863194525e-07, 	 Total Loss :1.875183528454727e-07
# it :01700, Data Loss :2.1483621992501867e-08,	 PDE Loss :1.4873519660341117e-07, 	 Total Loss :1.7021881149048568e-07
# it :01800, Data Loss :1.9408538776133355e-08,	 PDE Loss :1.3366299356221134e-07, 	 Total Loss :1.5307153944377205e-07
# it :01900, Data Loss :1.8350593933291748e-08,	 PDE Loss :1.2601368837295013e-07, 	 Total Loss :1.443642787535282e-07
# it :02000, Data Loss :1.67971325737426e-08,	 PDE Loss :1.1406261535285012e-07, 	 Total Loss :1.3085974615023588e-07
# it :02100, Data Loss :1.6219296128383576e-08,	 PDE Loss :1.0978190090327189e-07, 	 Total Loss :1.2600119703165547e-07
# it :02200, Data Loss :1.5459971081099866e-08,	 PDE Loss :1.0393684846121687e-07, 	 Total Loss :1.1939681598960306e-07
# it :02300, Data Loss :1.4639670808946903e-08,	 PDE Loss :9.753907903586878e-08, 	 Total Loss :1.1217875339752936e-07
# it :02400, Data Loss :1.2503438284738877e-08,	 PDE Loss :8.017958919026569e-08, 	 Total Loss :9.268302392229089e-08
# it :02500, Data Loss :1.1984937486886338e-08,	 PDE Loss :7.611042462940532e-08, 	 Total Loss :8.809536211629165e-08
# it :02600, Data Loss :1.148648287596643e-08,	 PDE Loss :7.21791053592824e-08, 	 Total Loss :8.366559001160567e-08
# it :02700, Data Loss :1.024331286458846e-08,	 PDE Loss :6.19072295648948e-08, 	 Total Loss :7.215054154130485e-08
# it :02800, Data Loss :9.514779186758915e-09,	 PDE Loss :5.5911829832666626e-08, 	 Total Loss :6.54266116839608e-08
# it :02900, Data Loss :8.912993010312675e-09,	 PDE Loss :5.095896327134142e-08, 	 Total Loss :5.987195805801093e-08
# it :03000, Data Loss :8.502579973423963e-09,	 PDE Loss :4.762875249753051e-08, 	 Total Loss :5.6131334247311315e-08
# it :03100, Data Loss :7.983905092601162e-09,	 PDE Loss :4.331794301037917e-08, 	 Total Loss :5.130184632662349e-08
# it :03200, Data Loss :7.709189731031074e-09,	 PDE Loss :4.114179574798982e-08, 	 Total Loss :4.885098547902089e-08
# it :03300, Data Loss :7.439894922356416e-09,	 PDE Loss :3.9002269858201544e-08, 	 Total Loss :4.644216389237954e-08
# it :03400, Data Loss :7.132459955982995e-09,	 PDE Loss :3.650897539841935e-08, 	 Total Loss :4.364143535440235e-08
# it :03500, Data Loss :6.855996659282937e-09,	 PDE Loss :3.4276570914926197e-08, 	 Total Loss :4.1132565797852294e-08
# it :03600, Data Loss :6.689833575990178e-09,	 PDE Loss :3.304104012613607e-08, 	 Total Loss :3.9730874590304666e-08
# it :03700, Data Loss :6.47737552483818e-09,	 PDE Loss :3.1372472619750624e-08, 	 Total Loss :3.7849847700499595e-08
# it :03800, Data Loss :6.279493369731881e-09,	 PDE Loss :2.983863467420633e-08, 	 Total Loss :3.6118127155759794e-08
# it :03900, Data Loss :6.098135330034893e-09,	 PDE Loss :2.844963375991938e-08, 	 Total Loss :3.454776731359743e-08
# it :04000, Data Loss :5.97890004172541e-09,	 PDE Loss :2.7651138267970055e-08, 	 Total Loss :3.3630037421517045e-08
# it :04100, Data Loss :5.972346173166443e-09,	 PDE Loss :2.7928518164799243e-08, 	 Total Loss :3.3900864337965686e-08
# it :04200, Data Loss :6.11798789407203e-09,	 PDE Loss :2.962755374369408e-08, 	 Total Loss :3.574554341412295e-08
# it :04300, Data Loss :6.216521519775142e-09,	 PDE Loss :3.08188603526105e-08, 	 Total Loss :3.703538098420722e-08
# it :04400, Data Loss :6.122884421699837e-09,	 PDE Loss :3.0213410440183e-08, 	 Total Loss :3.6336295750061254e-08
# it :04500, Data Loss :5.9670544061418695e-09,	 PDE Loss :2.900903162128543e-08, 	 Total Loss :3.49760860274273e-08
# it :04600, Data Loss :5.821802151473321e-09,	 PDE Loss :2.7898718002461464e-08, 	 Total Loss :3.3720521486202415e-08
# it :04700, Data Loss :5.68793012689639e-09,	 PDE Loss :2.688682165796763e-08, 	 Total Loss :3.257475356122086e-08
# it :04800, Data Loss :5.534042113453097e-09,	 PDE Loss :2.5679065984718363e-08, 	 Total Loss :3.121310854226067e-08
# it :04900, Data Loss :5.426856297674476e-09,	 PDE Loss :2.491353612299463e-08, 	 Total Loss :3.0340391532490685e-08
# it :05000, Data Loss :5.366457944688818e-09,	 PDE Loss :2.4600293357934788e-08, 	 Total Loss :2.9966752634891236e-08
# it :05100, Data Loss :5.306054706721852e-09,	 PDE Loss :2.4275980337051806e-08, 	 Total Loss :2.9582034599684448e-08
# it :05200, Data Loss :5.186355789277286e-09,	 PDE Loss :2.3367862311829413e-08, 	 Total Loss :2.855421854519591e-08
# it :05300, Data Loss :5.0879505053558205e-09,	 PDE Loss :2.2666906573931556e-08, 	 Total Loss :2.7754857967465796e-08
# it :05400, Data Loss :4.969678002453293e-09,	 PDE Loss :2.1760254043101668e-08, 	 Total Loss :2.672993204555496e-08
# it :05500, Data Loss :4.899435523952889e-09,	 PDE Loss :2.1335615940643038e-08, 	 Total Loss :2.6235051464595927e-08
# it :05600, Data Loss :4.803031750100217e-09,	 PDE Loss :2.064292203840523e-08, 	 Total Loss :2.544595290032703e-08
# it :05700, Data Loss :4.7022670202068184e-09,	 PDE Loss :1.9902065773180766e-08, 	 Total Loss :2.4604332793387584e-08
# it :05800, Data Loss :4.633037953283292e-09,	 PDE Loss :1.9485248969886015e-08, 	 Total Loss :2.4118286034990888e-08
# it :05900, Data Loss :4.530112729383973e-09,	 PDE Loss :1.8709716442799618e-08, 	 Total Loss :2.32398296162728e-08
# it :06000, Data Loss :4.451564450391743e-09,	 PDE Loss :1.8188821115927567e-08, 	 Total Loss :2.264038556631931e-08
# it :06100, Data Loss :4.576604428763176e-09,	 PDE Loss :1.9765467484944566e-08, 	 Total Loss :2.434207146961853e-08
# it :06200, Data Loss :4.659576724463932e-09,	 PDE Loss :2.0832914060520125e-08, 	 Total Loss :2.5492489896805637e-08
# it :06300, Data Loss :4.687242149969961e-09,	 PDE Loss :2.1303140584905123e-08, 	 Total Loss :2.5990383178964294e-08
# it :06400, Data Loss :4.679375109617467e-09,	 PDE Loss :2.1416580509026062e-08, 	 Total Loss :2.609595561864353e-08
# it :06500, Data Loss :4.662509489605782e-09,	 PDE Loss :2.1442540187877057e-08, 	 Total Loss :2.610504878930442e-08
# it :06600, Data Loss :4.584542079300036e-09,	 PDE Loss :2.0858685445546143e-08, 	 Total Loss :2.544322796893539e-08
# it :06700, Data Loss :4.49798420731895e-09,	 PDE Loss :2.018940747916531e-08, 	 Total Loss :2.468739168648426e-08
# it :06800, Data Loss :4.422432198225579e-09,	 PDE Loss :1.9624746272484117e-08, 	 Total Loss :2.4047178470709696e-08
# it :06900, Data Loss :4.3783265901709e-09,	 PDE Loss :1.937378257821365e-08, 	 Total Loss :2.375210961247376e-08
# it :07000, Data Loss :4.304512302155672e-09,	 PDE Loss :1.881982925056036e-08, 	 Total Loss :2.3124341552716032e-08
# it :07100, Data Loss :4.24545909538665e-09,	 PDE Loss :1.8415935443272247e-08, 	 Total Loss :2.2661394538658897e-08
# it :07200, Data Loss :4.181472057496194e-09,	 PDE Loss :1.7958283748953363e-08, 	 Total Loss :2.2139754918271137e-08
# it :07300, Data Loss :4.190607860721229e-09,	 PDE Loss :1.825076978434481e-08, 	 Total Loss :2.244137675688762e-08
# it :07400, Data Loss :4.150450205742118e-09,	 PDE Loss :1.8027609627324637e-08, 	 Total Loss :2.2178060277155964e-08
# it :07500, Data Loss :4.105713102831032e-09,	 PDE Loss :1.775303992701538e-08, 	 Total Loss :2.1858753029846412e-08
# it :07600, Data Loss :4.054857338786633e-09,	 PDE Loss :1.7414636843682274e-08, 	 Total Loss :2.1469494626558117e-08
# it :07700, Data Loss :3.975426654534431e-09,	 PDE Loss :1.6784614587095348e-08, 	 Total Loss :2.076004079754057e-08
# it :07800, Data Loss :3.9486227620955106e-09,	 PDE Loss :1.669862292885682e-08, 	 Total Loss :2.064724569095233e-08
# it :07900, Data Loss :3.892991262688383e-09,	 PDE Loss :1.6312633022153022e-08, 	 Total Loss :2.0205623840752196e-08
# it :08000, Data Loss :3.831241546237152e-09,	 PDE Loss :1.5864829450151774e-08, 	 Total Loss :1.9696070552299716e-08
# it :08100, Data Loss :3.792441027883342e-09,	 PDE Loss :1.565214802212722e-08, 	 Total Loss :1.9444588161832144e-08
# it :08200, Data Loss :3.760555866705317e-09,	 PDE Loss :1.5513077045170576e-08, 	 Total Loss :1.9273633355965103e-08
# it :08300, Data Loss :3.714145657696122e-09,	 PDE Loss :1.522090720129654e-08, 	 Total Loss :1.8935052636948058e-08
# it :08400, Data Loss :3.6729472796537266e-09,	 PDE Loss :1.4987737273486346e-08, 	 Total Loss :1.8660685441318492e-08
# it :08500, Data Loss :3.634109901895499e-09,	 PDE Loss :1.4772148837494115e-08, 	 Total Loss :1.8406257851211194e-08
# it :08600, Data Loss :3.590325370339542e-09,	 PDE Loss :1.4503601875048844e-08, 	 Total Loss :1.8093928133566806e-08
# it :08700, Data Loss :3.547361737687993e-09,	 PDE Loss :1.4248110247194745e-08, 	 Total Loss :1.7795471762838133e-08
# it :08800, Data Loss :3.5955129984444056e-09,	 PDE Loss :1.4944681936412962e-08, 	 Total Loss :1.8540195156901973e-08
# it :08900, Data Loss :3.566260620146977e-09,	 PDE Loss :1.479979516716412e-08, 	 Total Loss :1.8366055343221888e-08
# it :09000, Data Loss :3.537632409233993e-09,	 PDE Loss :1.4662063563264383e-08, 	 Total Loss :1.8199695972498375e-08
# it :09100, Data Loss :3.5023024480551612e-09,	 PDE Loss :1.4465502573557387e-08, 	 Total Loss :1.796780502161255e-08
# it :09200, Data Loss :3.4523646164075217e-09,	 PDE Loss :1.4107568446775076e-08, 	 Total Loss :1.7559933951361018e-08
# it :09300, Data Loss :3.435341566770944e-09,	 PDE Loss :1.4099139633572122e-08, 	 Total Loss :1.753448053420925e-08
# it :09400, Data Loss :3.3928255760429238e-09,	 PDE Loss :1.3820996791480411e-08, 	 Total Loss :1.7213821479344915e-08
# it :09500, Data Loss :3.349632127225277e-09,	 PDE Loss :1.3532980069896894e-08, 	 Total Loss :1.688261264121138e-08
# it :09600, Data Loss :3.3105762575758035e-09,	 PDE Loss :1.3292832612421535e-08, 	 Total Loss :1.6603408425908128e-08
# it :09700, Data Loss :3.2885618672651162e-09,	 PDE Loss :1.3231368001243027e-08, 	 Total Loss :1.6519930312597353e-08
# it :09800, Data Loss :3.2535438787562043e-09,	 PDE Loss :1.3034334500616751e-08, 	 Total Loss :1.628787771323914e-08
# it :09900, Data Loss :3.212707655464442e-09,	 PDE Loss :1.2771294244373621e-08, 	 Total Loss :1.5984001677793458e-08
# it :10000, Data Loss :3.1849149983997904e-09,	 PDE Loss :1.2649401526232396e-08, 	 Total Loss :1.5834316968721396e-08
# it :10100, Data Loss :3.1507023656729416e-09,	 PDE Loss :1.2459945963883001e-08, 	 Total Loss :1.5610648773645153e-08
# it :10200, Data Loss :3.1159663738122845e-09,	 PDE Loss :1.2262909798721466e-08, 	 Total Loss :1.5378876838667566e-08
# it :10300, Data Loss :3.0877784773508665e-09,	 PDE Loss :1.2133729576646601e-08, 	 Total Loss :1.5221507609908258e-08
# it :10400, Data Loss :3.060365072471427e-09,	 PDE Loss :1.2019361506077075e-08, 	 Total Loss :1.5079725912414688e-08
# it :10500, Data Loss :3.028895800838427e-09,	 PDE Loss :1.1857700599193777e-08, 	 Total Loss :1.4886596844121414e-08
# it :10600, Data Loss :3.0122806471410968e-09,	 PDE Loss :1.1859665249858153e-08, 	 Total Loss :1.487194545291004e-08
# it :10700, Data Loss :3.0443878529240465e-09,	 PDE Loss :1.2361017986961542e-08, 	 Total Loss :1.540540495170717e-08
# it :10800, Data Loss :3.0886666557705666e-09,	 PDE Loss :1.2950882144480147e-08, 	 Total Loss :1.6039548356161504e-08
# it :10900, Data Loss :3.064914988470946e-09,	 PDE Loss :1.2830998485924283e-08, 	 Total Loss :1.589591391848444e-08
# it :11000, Data Loss :3.038666651633548e-09,	 PDE Loss :1.2684727046519129e-08, 	 Total Loss :1.5723394142241887e-08
# it :11100, Data Loss :3.0161089181746092e-09,	 PDE Loss :1.2573734053944463e-08, 	 Total Loss :1.5589842305985258e-08
# it :11200, Data Loss :2.983346458762526e-09,	 PDE Loss :1.2358286838320964e-08, 	 Total Loss :1.53416337411727e-08
# it :11300, Data Loss :2.9602458262445452e-09,	 PDE Loss :1.2245592095894153e-08, 	 Total Loss :1.520583836622791e-08
# it :11400, Data Loss :2.9434670256733853e-09,	 PDE Loss :1.2194405485388415e-08, 	 Total Loss :1.5137873177195615e-08
# it :11500, Data Loss :2.9104647580879828e-09,	 PDE Loss :1.1978896097275538e-08, 	 Total Loss :1.488936085536352e-08
# it :11600, Data Loss :2.8924094230831088e-09,	 PDE Loss :1.1916021058766546e-08, 	 Total Loss :1.4808430037760445e-08
# it :11700, Data Loss :2.8688276199062557e-09,	 PDE Loss :1.1797133048219166e-08, 	 Total Loss :1.4665960890170027e-08
# it :11800, Data Loss :2.8319562250800345e-09,	 PDE Loss :1.1540937983056665e-08, 	 Total Loss :1.4372893986092095e-08
# it :11900, Data Loss :2.813283828118074e-09,	 PDE Loss :1.1476016581468684e-08, 	 Total Loss :1.4289300409586758e-08
# it :12000, Data Loss :2.7838980010130854e-09,	 PDE Loss :1.1294901902658694e-08, 	 Total Loss :1.4078800347760989e-08
# it :12100, Data Loss :2.765195405984855e-09,	 PDE Loss :1.1225478324661253e-08, 	 Total Loss :1.3990673508601503e-08
# it :12200, Data Loss :2.7542315095274716e-09,	 PDE Loss :1.1236840791184477e-08, 	 Total Loss :1.3991072300711949e-08
# it :12300, Data Loss :2.7200752761302738e-09,	 PDE Loss :1.1008666866985095e-08, 	 Total Loss :1.3728742587204579e-08
# it :12400, Data Loss :2.687094324826944e-09,	 PDE Loss :1.0791776361429584e-08, 	 Total Loss :1.3478870464211923e-08
# it :12500, Data Loss :2.6772244421380265e-09,	 PDE Loss :1.0818686391189658e-08, 	 Total Loss :1.349591105537229e-08
# it :12600, Data Loss :2.674098276145287e-09,	 PDE Loss :1.0911679559910681e-08, 	 Total Loss :1.3585777836055968e-08
# it :12700, Data Loss :2.6288129451046416e-09,	 PDE Loss :1.0567618780044086e-08, 	 Total Loss :1.3196431503104122e-08
# it :12800, Data Loss :2.6176116829645935e-09,	 PDE Loss :1.0579727316439858e-08, 	 Total Loss :1.3197339221449056e-08
# it :12900, Data Loss :2.5904758338413103e-09,	 PDE Loss :1.0426352226033941e-08, 	 Total Loss :1.3016828503964462e-08
# it :13000, Data Loss :2.5815622972658048e-09,	 PDE Loss :1.0460944999124422e-08, 	 Total Loss :1.3042507518434832e-08
# it :13100, Data Loss :2.5531528002886716e-09,	 PDE Loss :1.0292882102191925e-08, 	 Total Loss :1.2846035346569806e-08
# it :13200, Data Loss :2.522751341160756e-09,	 PDE Loss :1.0104066028304715e-08, 	 Total Loss :1.262681692537626e-08
# it :13300, Data Loss :2.518860009459445e-09,	 PDE Loss :1.0190998267489704e-08, 	 Total Loss :1.2709858054904544e-08
# it :13400, Data Loss :2.4867936598838014e-09,	 PDE Loss :9.984813864605258e-09, 	 Total Loss :1.2471607746533664e-08
# it :13500, Data Loss :2.4674413623415603e-09,	 PDE Loss :9.912724863170297e-09, 	 Total Loss :1.2380166225511857e-08
# it :13600, Data Loss :2.450121439068198e-09,	 PDE Loss :9.861133243305176e-09, 	 Total Loss :1.2311254238284164e-08
# it :13700, Data Loss :2.413193866956931e-09,	 PDE Loss :9.607908246778152e-09, 	 Total Loss :1.2021102335779688e-08
# it :13800, Data Loss :2.397943177356865e-09,	 PDE Loss :9.58282875274108e-09, 	 Total Loss :1.1980771930097944e-08
# it :13900, Data Loss :2.3768094159493103e-09,	 PDE Loss :9.492296726421046e-09, 	 Total Loss :1.1869106586459566e-08
# it :14000, Data Loss :2.361450590626646e-09,	 PDE Loss :9.465570549593849e-09, 	 Total Loss :1.1827021140220495e-08
# it :14100, Data Loss :2.3438933016706187e-09,	 PDE Loss :9.411655454982792e-09, 	 Total Loss :1.1755548534608806e-08
# it :14200, Data Loss :2.3207387123136414e-09,	 PDE Loss :9.298475767138825e-09, 	 Total Loss :1.1619214035363257e-08
# it :14300, Data Loss :2.30440888593364e-09,	 PDE Loss :9.25723320222005e-09, 	 Total Loss :1.1561642310198295e-08
# it :14400, Data Loss :2.2905637386827493e-09,	 PDE Loss :9.241460041664595e-09, 	 Total Loss :1.1532023336258135e-08
# it :14500, Data Loss :2.271088206384775e-09,	 PDE Loss :9.16728115640808e-09, 	 Total Loss :1.1438369362792855e-08
# it :14600, Data Loss :2.2467725457886445e-09,	 PDE Loss :9.04415742297715e-09, 	 Total Loss :1.1290929968765795e-08
# it :14700, Data Loss :2.2208292982384137e-09,	 PDE Loss :8.903280779293254e-09, 	 Total Loss :1.1124109633442458e-08
# it :14800, Data Loss :2.210998051310753e-09,	 PDE Loss :8.929578854122155e-09, 	 Total Loss :1.1140576461343699e-08
# it :14900, Data Loss :2.188866865537875e-09,	 PDE Loss :8.829228015372337e-09, 	 Total Loss :1.1018094880910212e-08
# it :15000, Data Loss :2.166211654497374e-09,	 PDE Loss :8.726068756459426e-09, 	 Total Loss :1.089228085504601e-08
# it :15100, Data Loss :2.150254196919832e-09,	 PDE Loss :8.69102123601806e-09, 	 Total Loss :1.0841275432937891e-08
# it :15200, Data Loss :2.1327102306401002e-09,	 PDE Loss :8.642788706936244e-09, 	 Total Loss :1.077549871553174e-08
# it :15300, Data Loss :2.1122754656488496e-09,	 PDE Loss :8.558711073192171e-09, 	 Total Loss :1.0670986760885626e-08
# it :15400, Data Loss :2.0917862997293923e-09,	 PDE Loss :8.480911972696958e-09, 	 Total Loss :1.057269827242635e-08
# it :15500, Data Loss :2.067088056278976e-09,	 PDE Loss :8.361111802912546e-09, 	 Total Loss :1.0428199637146918e-08
# it :15600, Data Loss :2.0621113705487915e-09,	 PDE Loss :8.436889409324522e-09, 	 Total Loss :1.0499000779873313e-08
# it :15700, Data Loss :2.036546042916143e-09,	 PDE Loss :8.297907250209846e-09, 	 Total Loss :1.0334453293125989e-08
# it :15800, Data Loss :2.0152277624418957e-09,	 PDE Loss :8.208635549067367e-09, 	 Total Loss :1.0223863533553867e-08
# it :15900, Data Loss :2.000230869825259e-09,	 PDE Loss :8.183378419346354e-09, 	 Total Loss :1.0183609511216218e-08
# it :16000, Data Loss :1.9855366240051353e-09,	 PDE Loss :8.155443431689946e-09, 	 Total Loss :1.0140979611605871e-08
# it :16100, Data Loss :1.9691133168464603e-09,	 PDE Loss :8.11227796049252e-09, 	 Total Loss :1.008139172142819e-08
# it :16200, Data Loss :1.9509593940369996e-09,	 PDE Loss :8.056482592166958e-09, 	 Total Loss :1.0007441986203958e-08
# it :16300, Data Loss :1.9269219553308403e-09,	 PDE Loss :7.937036805572006e-09, 	 Total Loss :9.863958538858242e-09
# it :16400, Data Loss :1.9188419742022234e-09,	 PDE Loss :7.9736635072436e-09, 	 Total Loss :9.892505481445824e-09
# it :16500, Data Loss :1.8962775794051367e-09,	 PDE Loss :7.86908049832391e-09, 	 Total Loss :9.765358299773652e-09
# it :16600, Data Loss :1.8766381781887276e-09,	 PDE Loss :7.800736057106405e-09, 	 Total Loss :9.677374457339738e-09
# it :16700, Data Loss :1.8546320035284225e-09,	 PDE Loss :7.70386865411865e-09, 	 Total Loss :9.558500657647073e-09
# it :16800, Data Loss :1.8420942549113306e-09,	 PDE Loss :7.703475191078724e-09, 	 Total Loss :9.545569668034659e-09
# it :16900, Data Loss :1.8203715201892123e-09,	 PDE Loss :7.61501439683343e-09, 	 Total Loss :9.43538580600034e-09
# it :17000, Data Loss :1.803152183121881e-09,	 PDE Loss :7.564644022295397e-09, 	 Total Loss :9.36779631643958e-09
# it :17100, Data Loss :1.7914216776659941e-09,	 PDE Loss :7.565535753428776e-09, 	 Total Loss :9.35695787518398e-09
# it :17200, Data Loss :1.8137291668551825e-09,	 PDE Loss :7.857965833579783e-09, 	 Total Loss :9.671694556345756e-09
# it :17300, Data Loss :1.8305029714227317e-09,	 PDE Loss :8.065999423934045e-09, 	 Total Loss :9.896502284334474e-09
# it :17400, Data Loss :1.8117928268779337e-09,	 PDE Loss :7.957767778066227e-09, 	 Total Loss :9.769560271877253e-09
# it :17500, Data Loss :1.8021585335148416e-09,	 PDE Loss :7.929079615109913e-09, 	 Total Loss :9.731238037602452e-09
# it :17600, Data Loss :1.7904193683193625e-09,	 PDE Loss :7.88190845923964e-09, 	 Total Loss :9.672327827559002e-09
# it :17700, Data Loss :1.7951431452445377e-09,	 PDE Loss :7.978919747131386e-09, 	 Total Loss :9.774062448286713e-09
# it :17800, Data Loss :1.7755060754964802e-09,	 PDE Loss :7.85989939799947e-09, 	 Total Loss :9.635405362473648e-09
# it :17900, Data Loss :1.7567151067154896e-09,	 PDE Loss :7.753399700050068e-09, 	 Total Loss :9.51011447369865e-09
# it :18000, Data Loss :1.7449509615019565e-09,	 PDE Loss :7.706473681423631e-09, 	 Total Loss :9.451424531903285e-09
# it :18100, Data Loss :1.7395102025474785e-09,	 PDE Loss :7.712782412738761e-09, 	 Total Loss :9.452292282219332e-09
# it :18200, Data Loss :1.7303438681892658e-09,	 PDE Loss :7.689222591977796e-09, 	 Total Loss :9.419566460167061e-09
# it :18300, Data Loss :1.71992042830027e-09,	 PDE Loss :7.653061295798125e-09, 	 Total Loss :9.37298150205379e-09
# it :18400, Data Loss :1.701496610273523e-09,	 PDE Loss :7.546144153991463e-09, 	 Total Loss :9.247640875287289e-09
# it :18500, Data Loss :1.6970747029887434e-09,	 PDE Loss :7.563357051765252e-09, 	 Total Loss :9.26043153270939e-09
# it :18600, Data Loss :1.6877723663100141e-09,	 PDE Loss :7.53718065737985e-09, 	 Total Loss :9.224953245734469e-09
# it :18700, Data Loss :1.6795718149609229e-09,	 PDE Loss :7.52086126709628e-09, 	 Total Loss :9.200433304101807e-09
# it :18800, Data Loss :1.6653837198177257e-09,	 PDE Loss :7.452694461562714e-09, 	 Total Loss :9.118077848313533e-09
# it :18900, Data Loss :1.6482548659269014e-09,	 PDE Loss :7.360677400924942e-09, 	 Total Loss :9.008932266851843e-09
# it :19000, Data Loss :1.645720892895497e-09,	 PDE Loss :7.3903949626696885e-09, 	 Total Loss :9.036115855565185e-09
# it :19100, Data Loss :1.6293358884311715e-09,	 PDE Loss :7.3041142023555494e-09, 	 Total Loss :8.933450423853628e-09
# it :19200, Data Loss :1.6247414524883652e-09,	 PDE Loss :7.3192931715482246e-09, 	 Total Loss :8.944034846081195e-09
# it :19300, Data Loss :1.608314259549104e-09,	 PDE Loss :7.233860177535689e-09, 	 Total Loss :8.842174104017886e-09
# it :19400, Data Loss :1.599326449053251e-09,	 PDE Loss :7.211246266791704e-09, 	 Total Loss :8.810572715844955e-09
# it :19500, Data Loss :1.5931118646506093e-09,	 PDE Loss :7.209633334781529e-09, 	 Total Loss :8.802745199432138e-09
# it :19600, Data Loss :1.57717527926593e-09,	 PDE Loss :7.126903511789351e-09, 	 Total Loss :8.70407923514449e-09
# it :19700, Data Loss :1.5687923182738928e-09,	 PDE Loss :7.1093708697844704e-09, 	 Total Loss :8.67816307703606e-09
# it :19800, Data Loss :1.5603276448672432e-09,	 PDE Loss :7.090303011381138e-09, 	 Total Loss :8.650630434203777e-09
# it :19900, Data Loss :1.5472079173406428e-09,	 PDE Loss :7.0302421661949666e-09, 	 Total Loss :8.577449861491004e-09
# it :20000, Data Loss :1.540089833440561e-09,	 PDE Loss :7.021402126383691e-09, 	 Total Loss :8.561491959824252e-09
# it :20100, Data Loss :1.5273017295314162e-09,	 PDE Loss :6.966665466734412e-09, 	 Total Loss :8.49396730728813e-09
# it :20200, Data Loss :1.5207037851183713e-09,	 PDE Loss :6.96285118451101e-09, 	 Total Loss :8.483555191673986e-09
# it :20300, Data Loss :1.5058798652489713e-09,	 PDE Loss :6.889417925037833e-09, 	 Total Loss :8.395297790286804e-09
# it :20400, Data Loss :1.4988729146736546e-09,	 PDE Loss :6.882045155975902e-09, 	 Total Loss :8.38091818167186e-09
# it :20500, Data Loss :1.4890467747719072e-09,	 PDE Loss :6.850634726163207e-09, 	 Total Loss :8.339681834002022e-09
# it :20600, Data Loss :1.4811973869655048e-09,	 PDE Loss :6.838474675419093e-09, 	 Total Loss :8.319672062384598e-09
# it :20700, Data Loss :1.468609234223095e-09,	 PDE Loss :6.7848073825871325e-09, 	 Total Loss :8.253416616810227e-09
# it :20800, Data Loss :1.457696297002542e-09,	 PDE Loss :6.7441621176556055e-09, 	 Total Loss :8.201858747725055e-09
# it :20900, Data Loss :1.4475706189287507e-09,	 PDE Loss :6.7104681811258615e-09, 	 Total Loss :8.15803868903231e-09
# it :21000, Data Loss :1.4364059941485152e-09,	 PDE Loss :6.6694347822249256e-09, 	 Total Loss :8.105840443306533e-09
# it :21100, Data Loss :1.4227914402198394e-09,	 PDE Loss :6.606559299626724e-09, 	 Total Loss :8.029350517801959e-09
# it :21200, Data Loss :1.4148495708354858e-09,	 PDE Loss :6.592064227817218e-09, 	 Total Loss :8.006914242741914e-09
# it :21300, Data Loss :1.409319327905223e-09,	 PDE Loss :6.597172585998123e-09, 	 Total Loss :8.006491469814137e-09
# it :21400, Data Loss :1.3999916781415322e-09,	 PDE Loss :6.569901067621231e-09, 	 Total Loss :7.969893189851973e-09
# it :21500, Data Loss :1.3881588101227749e-09,	 PDE Loss :6.522858253532604e-09, 	 Total Loss :7.911016730588472e-09
# it :21600, Data Loss :1.3794160258484567e-09,	 PDE Loss :6.5002256910418055e-09, 	 Total Loss :7.879641827912565e-09
# it :21700, Data Loss :1.3671367371514975e-09,	 PDE Loss :6.448894751542866e-09, 	 Total Loss :7.816031377672061e-09
# it :21800, Data Loss :1.3597432069190063e-09,	 PDE Loss :6.437269384207411e-09, 	 Total Loss :7.797012813171023e-09
# it :21900, Data Loss :1.3481586957908576e-09,	 PDE Loss :6.392412377209666e-09, 	 Total Loss :7.740570850955919e-09
# it :22000, Data Loss :1.3388098407673965e-09,	 PDE Loss :6.366151605874393e-09, 	 Total Loss :7.704961113574882e-09
# it :22100, Data Loss :1.3291606704157743e-09,	 PDE Loss :6.3351834889147085e-09, 	 Total Loss :7.664343826263575e-09
# it :22200, Data Loss :1.3247052343956511e-09,	 PDE Loss :6.347209868806658e-09, 	 Total Loss :7.6719146591131e-09
# it :22300, Data Loss :1.3081709049345136e-09,	 PDE Loss :6.261236862314945e-09, 	 Total Loss :7.569408211338668e-09
# it :22400, Data Loss :1.3030853063256131e-09,	 PDE Loss :6.269444075002184e-09, 	 Total Loss :7.572529270305495e-09
# it :22500, Data Loss :1.2876462118782683e-09,	 PDE Loss :6.193419999078742e-09, 	 Total Loss :7.481066433001615e-09
# it :22600, Data Loss :1.2838438090412296e-09,	 PDE Loss :6.2098122199927275e-09, 	 Total Loss :7.493656362100864e-09
# it :22700, Data Loss :1.274111705029668e-09,	 PDE Loss :6.179389000493529e-09, 	 Total Loss :7.453500927567802e-09
# it :22800, Data Loss :1.2588066145013954e-09,	 PDE Loss :6.1026828035437575e-09, 	 Total Loss :7.361489196000548e-09
# it :22900, Data Loss :1.254800263694733e-09,	 PDE Loss :6.119964535145073e-09, 	 Total Loss :7.374764798839806e-09
# it :23000, Data Loss :1.2426953910349425e-09,	 PDE Loss :6.069460489754874e-09, 	 Total Loss :7.312155769767514e-09
# it :23100, Data Loss :1.2354635092748367e-09,	 PDE Loss :6.057317314400734e-09, 	 Total Loss :7.292780601630966e-09
# it :23200, Data Loss :1.2247486358418769e-09,	 PDE Loss :6.018984866074106e-09, 	 Total Loss :7.243733612938286e-09
# it :23300, Data Loss :1.213882550032963e-09,	 PDE Loss :5.9778235694807336e-09, 	 Total Loss :7.191705897469092e-09
# it :23400, Data Loss :1.2010170635790018e-09,	 PDE Loss :5.922075274611416e-09, 	 Total Loss :7.123092338190418e-09
# it :23500, Data Loss :1.2009305772053835e-09,	 PDE Loss :5.968323169014411e-09, 	 Total Loss :7.169253635197492e-09
# it :23600, Data Loss :1.185076259346829e-09,	 PDE Loss :5.890028464961006e-09, 	 Total Loss :7.0751049463524396e-09
# it :23700, Data Loss :1.1774518027252157e-09,	 PDE Loss :5.874635888858393e-09, 	 Total Loss :7.052087802605911e-09
# it :23800, Data Loss :1.1682717016014976e-09,	 PDE Loss :5.847256456803507e-09, 	 Total Loss :7.0155281584050044e-09
# it :23900, Data Loss :1.1613348060990347e-09,	 PDE Loss :5.8402940261714775e-09, 	 Total Loss :7.001628610225907e-09
# it :24000, Data Loss :1.1538793254217694e-09,	 PDE Loss :5.826741311665273e-09, 	 Total Loss :6.98062052606474e-09
# it :24100, Data Loss :1.1460002946606096e-09,	 PDE Loss :5.810230963021468e-09, 	 Total Loss :6.956231146659775e-09
# it :24200, Data Loss :1.1360958840356261e-09,	 PDE Loss :5.7763780425545974e-09, 	 Total Loss :6.9124741486348285e-09
# it :24300, Data Loss :1.124338955271753e-09,	 PDE Loss :5.72915981322808e-09, 	 Total Loss :6.85349865747753e-09
# it :24400, Data Loss :1.1158807211586463e-09,	 PDE Loss :5.708438166607266e-09, 	 Total Loss :6.824318887765912e-09
# it :24500, Data Loss :1.1060868887469155e-09,	 PDE Loss :5.677915915214271e-09, 	 Total Loss :6.784002692938884e-09
# it :24600, Data Loss :1.1005353295345799e-09,	 PDE Loss :5.678978620693442e-09, 	 Total Loss :6.77951383920572e-09
# it :24700, Data Loss :1.0871099576093002e-09,	 PDE Loss :5.618838727627917e-09, 	 Total Loss :6.7059486852372174e-09
# it :24800, Data Loss :1.075953326434842e-09,	 PDE Loss :5.576955786068538e-09, 	 Total Loss :6.652909334547985e-09
# it :24900, Data Loss :1.0670682115687669e-09,	 PDE Loss :5.550274906340746e-09, 	 Total Loss :6.617343117909513e-09
# it :25000, Data Loss :1.0601144406763297e-09,	 PDE Loss :5.538571823393568e-09, 	 Total Loss :6.598686042025292e-09
# it :25100, Data Loss :1.051874920499074e-09,	 PDE Loss :5.517819534617274e-09, 	 Total Loss :6.569694566138651e-09
# it :25200, Data Loss :1.039826114102027e-09,	 PDE Loss :5.468585584367247e-09, 	 Total Loss :6.508411587446972e-09
# it :25300, Data Loss :1.0315731602261735e-09,	 PDE Loss :5.448247186734534e-09, 	 Total Loss :6.479820235938405e-09
# it :25400, Data Loss :1.0240902570402e-09,	 PDE Loss :5.433993699455186e-09, 	 Total Loss :6.458083845473084e-09
# it :25500, Data Loss :1.0185983168042867e-09,	 PDE Loss :5.433938632393165e-09, 	 Total Loss :6.4525371712420565e-09
# it :25600, Data Loss :1.0036478315100794e-09,	 PDE Loss :5.364768629334549e-09, 	 Total Loss :6.368416460844628e-09
# it :25700, Data Loss :9.957017432782322e-10,	 PDE Loss :5.346738163325426e-09, 	 Total Loss :6.3424399066036585e-09
# it :25800, Data Loss :9.878926565676238e-10,	 PDE Loss :5.330699881511691e-09, 	 Total Loss :6.31859276012392e-09
# it :25900, Data Loss :9.773237774624022e-10,	 PDE Loss :5.292765337117089e-09, 	 Total Loss :6.270089336624096e-09
# it :26000, Data Loss :9.721405902496372e-10,	 PDE Loss :5.29433252793865e-09, 	 Total Loss :6.266473118188287e-09
# it :26100, Data Loss :9.608842610475676e-10,	 PDE Loss :5.250541335044545e-09, 	 Total Loss :6.211425596092113e-09
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 net.train()
#
# Cell In[31], line 129, in Net.train(self)
#     127     self.adam.step(self.loss_func)
#     128 print("train with L-BFGs")
# --> 129 self.optimizer.step(self.loss_func)
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/optimizer.py:113, in Optimizer._hook_for_profile.<locals>.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     111 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112 with torch.autograd.profiler.record_function(profile_name):
# --> 113     return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/lbfgs.py:425, in LBFGS.step(self, closure)
#     422     def obj_func(x, t, d):
#     423         return self._directional_evaluate(closure, x, t, d)
# --> 425     loss, flat_grad, t, ls_func_evals = _strong_wolfe(
#     426         obj_func, x_init, t, d, loss, flat_grad, gtd)
#     427 self._add_grad(t, d)
#     428 opt_cond = flat_grad.abs().max() <= tolerance_grad
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/lbfgs.py:49, in _strong_wolfe(obj_func, x, t, d, f, g, gtd, c1, c2, tolerance_change, max_ls)
#      47 g = g.clone(memory_format=torch.contiguous_format)
#      48 # evaluate objective and gradient using initial step
# ---> 49 f_new, g_new = obj_func(x, t, d)
#      50 ls_func_evals = 1
#      51 gtd_new = g_new.dot(d)
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/lbfgs.py:423, in LBFGS.step.<locals>.obj_func(x, t, d)
#     422 def obj_func(x, t, d):
# --> 423     return self._directional_evaluate(closure, x, t, d)
#
# File /usr/local/lib/python3.8/dist-packages/torch/optim/lbfgs.py:277, in LBFGS._directional_evaluate(self, closure, x, t, d)
#     275 def _directional_evaluate(self, closure, x, t, d):
#     276     self._add_grad(t, d)
# --> 277     loss = float(closure())
#     278     flat_grad = self._gather_flat_grad()
#     279     self._set_param(x)
#
# File /usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# Cell In[31], line 84, in Net.loss_func(self)
#      81 self.adam.zero_grad()
#      82 self.optimizer.zero_grad()
# ---> 84 f_pred = self.model(self.X_train)
#      85 loss_data = self.criterion(f_pred, self.f_train)
#      86 u = self.model(self.X)
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[8], line 26, in NN.forward(self, x)
#      25 def forward(self, x):
# ---> 26     out = self.layers(x)
#      27     return out
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/activation.py:354, in Tanh.forward(self, input)
#     353 def forward(self, input: Tensor) -> Tensor:
# --> 354     return torch.tanh(input)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10,3))
t_loss = np.log1p(net.total_loss_hist)
p_loss = np.log1p(net.pde_loss_hist)
d_loss = np.log1p(net.data_loss_hist)
epochs = range(1, 1+len(t_loss))
xbins = range(0, len(t_loss)+1, 50)
# plt.plot(epochs[:100], t_loss[:100], lw=1,linestyle='-', label='Total Loss', c="k")
# plt.plot(epochs[:100], p_loss[:100], lw=1,linestyle='-', label='PDE Loss', c="r")
# plt.plot(epochs[:100], d_loss[:100], lw=1,linestyle='-', label='Data Loss', c="b")
plt.plot(epochs, t_loss, lw=1,linestyle='-', label='Total Loss', c="k")
plt.plot(epochs, p_loss, lw=1,linestyle='-', label='PDE Loss', c="r")
plt.plot(epochs, d_loss, lw=1,linestyle='-', label='Data Loss', c="b")
plt.legend()
plt.grid(True)
# plt.xticks(xbins)
plt.xlabel('per 100 Epochs')
plt.ylabel('Log Loss')
# x, y = epochs[-1], loss[-1]
# plt.text(x, y, y)
plt.show()

# %%
# 데이터 불러오기
# 데이터에 대해서는 ./make_dataset.ipynb 에서 확인
with open(f'./data/data_1_1_1.npy', 'rb') as f:
    data = np.load(f,allow_pickle=True)
x = data.T[0]
y = data.T[1]
X = data[:,:2]
f_true = data.T[2]

print(x.shape, y.shape, X.shape, f_true.shape)
# Out:
# (3000,) (3000,) (3000, 2) (3000,)

# %%
X = torch.tensor(X, dtype=torch.float)
print(X.shape)
X = X.to(net.X.device)
# Out:
# torch.Size([3000, 2])

# %%
model = net.model
model.eval()
with torch.no_grad():
    f_pred = model(X).cpu().numpy().squeeze()
    
print(f_pred.shape, f_true.shape)
print(type(f_pred), type(f_true))
# Out:
# (3000,) (3000,)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
print("Test MSE Loss : ", np.mean(np.sqrt(np.square(f_true)-np.square(f_pred))))

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(7,3))
# grid
xi, yi = np.mgrid[x.min():x.max():500j, y.min():y.max():500j]

# f_true figure
rbf = scipy.interpolate.Rbf(x, y, f_true)
org = rbf(xi, yi)
img = ax[0].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[0].scatter(x, y, c=f_true)
ax[0].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

# f_pred figure
rbf = scipy.interpolate.Rbf(x, y, f_pred)
org = rbf(xi, yi)
img = ax[1].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[1].scatter(x, y, c=f_pred)
ax[1].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

plt.tight_layout()
# Out:
# Test MSE Loss :  0.4051965139540671

# %%
# model_1_1_1 save
torch.save(model.state_dict(), "./data/model_1_1_1.pt")

# %% [markdown]
# $$f(x,y)=3 \cdot \sin(1\cdot x)\sin(1\cdot y)\quad \text{--Train--} $$

# %%
net = Net(A=3)
# Out:
# Model's state_dict:
# layers.input.weight 	 torch.Size([100, 2])
# layers.input.bias 	 torch.Size([100])
# layers.hidden_0.weight 	 torch.Size([100, 100])
# layers.hidden_0.bias 	 torch.Size([100])
# layers.hidden_1.weight 	 torch.Size([100, 100])
# layers.hidden_1.bias 	 torch.Size([100])
# layers.hidden_2.weight 	 torch.Size([100, 100])
# layers.hidden_2.bias 	 torch.Size([100])
# layers.hidden_3.weight 	 torch.Size([100, 100])
# layers.hidden_3.bias 	 torch.Size([100])
# layers.hidden_4.weight 	 torch.Size([100, 100])
# layers.hidden_4.bias 	 torch.Size([100])
# layers.hidden_5.weight 	 torch.Size([100, 100])
# layers.hidden_5.bias 	 torch.Size([100])
# layers.hidden_6.weight 	 torch.Size([100, 100])
# layers.hidden_6.bias 	 torch.Size([100])
# layers.hidden_7.weight 	 torch.Size([100, 100])
# layers.hidden_7.bias 	 torch.Size([100])
# layers.output.weight 	 torch.Size([1, 100])
# layers.output.bias 	 torch.Size([1])

# %%
net.train()
# Out:
# train with Adam optimizer
# it :00100, Data Loss :2.950071802843013e-06,	 PDE Loss :4.96777101943735e-05, 	 Total Loss :5.2627783588832244e-05
# it :00200, Data Loss :2.603264874778688e-06,	 PDE Loss :3.316832589916885e-05, 	 Total Loss :3.577159077394754e-05
# it :00300, Data Loss :2.0769027742062462e-06,	 PDE Loss :2.577215855126269e-05, 	 Total Loss :2.784906064334791e-05
# it :00400, Data Loss :1.6071094250946771e-06,	 PDE Loss :1.9231607438996434e-05, 	 Total Loss :2.0838717318838462e-05
# it :00500, Data Loss :1.2169323326816084e-06,	 PDE Loss :1.3913327165937517e-05, 	 Total Loss :1.513025927124545e-05
# it :00600, Data Loss :9.103212050831644e-07,	 PDE Loss :9.848378795140889e-06, 	 Total Loss :1.0758700227597728e-05
# it :00700, Data Loss :6.799604079787969e-07,	 PDE Loss :6.900145763211185e-06, 	 Total Loss :7.58010628487682e-06
# it :00800, Data Loss :5.133947524882387e-07,	 PDE Loss :4.862155492446618e-06, 	 Total Loss :5.375550244934857e-06
# it :00900, Data Loss :3.966341637351434e-07,	 PDE Loss :3.5129207844875054e-06, 	 Total Loss :3.909554834535811e-06
# it :01000, Data Loss :3.166671831422718e-07,	 PDE Loss :2.6509085273573874e-06, 	 Total Loss :2.967575710499659e-06
# train with L-BFGs
# it :01100, Data Loss :5.573867412067557e-08,	 PDE Loss :2.9218384156592947e-07, 	 Total Loss :3.479225085811777e-07
# it :01200, Data Loss :2.0629817854000976e-08,	 PDE Loss :1.5369357697636588e-07, 	 Total Loss :1.7432338950129633e-07
# it :01300, Data Loss :2.1355893053964792e-08,	 PDE Loss :1.4944154713703028e-07, 	 Total Loss :1.7079743486192456e-07
# it :01400, Data Loss :2.1334980004894533e-08,	 PDE Loss :1.4896119182594703e-07, 	 Total Loss :1.7029617538355524e-07
# it :01500, Data Loss :2.1324343180140204e-08,	 PDE Loss :1.4853411300919106e-07, 	 Total Loss :1.6985845263661759e-07
# it :01600, Data Loss :2.1306711062152317e-08,	 PDE Loss :1.4817442206549458e-07, 	 Total Loss :1.6948112602221954e-07
# it :01700, Data Loss :2.126917131306527e-08,	 PDE Loss :1.4781385004880576e-07, 	 Total Loss :1.6908302313822787e-07
# it :01800, Data Loss :2.1239038971998525e-08,	 PDE Loss :1.4748208343462466e-07, 	 Total Loss :1.6872112951205054e-07
# it :01900, Data Loss :2.1204318301215608e-08,	 PDE Loss :1.4717322471824446e-07, 	 Total Loss :1.6837753946674638e-07
# it :02000, Data Loss :2.116133224205896e-08,	 PDE Loss :1.4684688665056456e-07, 	 Total Loss :1.68008213563553e-07
# it :02100, Data Loss :2.1142861683642877e-08,	 PDE Loss :1.4655981317446276e-07, 	 Total Loss :1.6770268018717616e-07
# it :02200, Data Loss :2.1099209490671456e-08,	 PDE Loss :1.4632382772106212e-07, 	 Total Loss :1.674230389880904e-07
# it :02300, Data Loss :2.1060145627416205e-08,	 PDE Loss :1.4601071995912207e-07, 	 Total Loss :1.6707086558653828e-07
# it :02400, Data Loss :2.1013978113160192e-08,	 PDE Loss :1.4570446182915475e-07, 	 Total Loss :1.6671843638960127e-07
# it :02500, Data Loss :2.096843232379797e-08,	 PDE Loss :1.4538159121002536e-07, 	 Total Loss :1.6635001998110965e-07
# it :02600, Data Loss :2.0932450439659078e-08,	 PDE Loss :1.450433160243847e-07, 	 Total Loss :1.659757629113301e-07
# it :02700, Data Loss :2.0884540319343614e-08,	 PDE Loss :1.4474024112587358e-07, 	 Total Loss :1.6562478322157403e-07
# it :02800, Data Loss :2.0850290383123138e-08,	 PDE Loss :1.4443122609009151e-07, 	 Total Loss :1.6528152002592833e-07
# it :02900, Data Loss :2.083861261326092e-08,	 PDE Loss :1.4416923477256205e-07, 	 Total Loss :1.6500784738582297e-07
# it :03000, Data Loss :2.0820239754471004e-08,	 PDE Loss :1.439754129251014e-07, 	 Total Loss :1.6479565090321557e-07
# it :03100, Data Loss :2.0791445010104326e-08,	 PDE Loss :1.4378727541952685e-07, 	 Total Loss :1.6457872220598802e-07
# it :03200, Data Loss :2.0757564556106445e-08,	 PDE Loss :1.4357505051521002e-07, 	 Total Loss :1.6433261862403015e-07
# it :03300, Data Loss :2.0721614646390663e-08,	 PDE Loss :1.4331631348341034e-07, 	 Total Loss :1.64037928129801e-07
# it :03400, Data Loss :2.0696219849014597e-08,	 PDE Loss :1.4309657103694917e-07, 	 Total Loss :1.6379279088596377e-07
# it :03500, Data Loss :2.0656443666666746e-08,	 PDE Loss :1.4281751248290675e-07, 	 Total Loss :1.634739561495735e-07
# it :03600, Data Loss :2.0608883488648644e-08,	 PDE Loss :1.4251101276840927e-07, 	 Total Loss :1.6311989270434424e-07
# it :03700, Data Loss :2.0540960932180496e-08,	 PDE Loss :1.4216540478173556e-07, 	 Total Loss :1.6270637104298658e-07
# it :03800, Data Loss :2.0473828854505882e-08,	 PDE Loss :1.4162931449845928e-07, 	 Total Loss :1.6210314868203568e-07
# it :03900, Data Loss :2.0447687987257268e-08,	 PDE Loss :1.411683854257717e-07, 	 Total Loss :1.6161607163667213e-07
# it :04000, Data Loss :2.040079749576762e-08,	 PDE Loss :1.4083163080158556e-07, 	 Total Loss :1.6123243540278054e-07
# it :04100, Data Loss :2.0366954345263366e-08,	 PDE Loss :1.4050040419988363e-07, 	 Total Loss :1.60867358545147e-07
# it :04200, Data Loss :2.0308529968815492e-08,	 PDE Loss :1.4018252159075928e-07, 	 Total Loss :1.6049105511228845e-07
# it :04300, Data Loss :2.022086675879109e-08,	 PDE Loss :1.3958833733340725e-07, 	 Total Loss :1.5980920409219834e-07
# it :04400, Data Loss :2.0110256571115315e-08,	 PDE Loss :1.389137338492219e-07, 	 Total Loss :1.5902398331490986e-07
# it :04500, Data Loss :2.0399502531631697e-08,	 PDE Loss :1.3464209303037933e-07, 	 Total Loss :1.550415902329405e-07
# it :04600, Data Loss :1.9608052070907434e-08,	 PDE Loss :1.3327208137070556e-07, 	 Total Loss :1.52880133441613e-07
# it :04700, Data Loss :1.924215453641409e-08,	 PDE Loss :1.3176560287320171e-07, 	 Total Loss :1.5100775385690213e-07
# it :04800, Data Loss :1.983840647312718e-08,	 PDE Loss :1.2952031624990923e-07, 	 Total Loss :1.4935872627575009e-07
# it :04900, Data Loss :1.920869330263031e-08,	 PDE Loss :1.2836136420446564e-07, 	 Total Loss :1.4757006283616647e-07
# it :05000, Data Loss :1.885753064811979e-08,	 PDE Loss :1.270963423394278e-07, 	 Total Loss :1.4595387654026126e-07
# it :05100, Data Loss :1.94932283648086e-08,	 PDE Loss :1.2505060453804617e-07, 	 Total Loss :1.4454383290285477e-07
# it :05200, Data Loss :1.8849469540782593e-08,	 PDE Loss :1.2408260374741076e-07, 	 Total Loss :1.42932066182766e-07
# it :05300, Data Loss :1.8518367284059423e-08,	 PDE Loss :1.22983138339805e-07, 	 Total Loss :1.4150150207115075e-07
# it :05400, Data Loss :1.9167620379789696e-08,	 PDE Loss :1.210979974075599e-07, 	 Total Loss :1.4026561245827907e-07
# it :05500, Data Loss :1.8528336198642137e-08,	 PDE Loss :1.202605233174836e-07, 	 Total Loss :1.3878886306883942e-07
# it :05600, Data Loss :1.82531767478622e-08,	 PDE Loss :1.1923417275738757e-07, 	 Total Loss :1.3748734772889293e-07
# it :05700, Data Loss :1.888149725459698e-08,	 PDE Loss :1.1752405981724223e-07, 	 Total Loss :1.364055606245529e-07
# it :05800, Data Loss :1.823208073403748e-08,	 PDE Loss :1.1678745437393445e-07, 	 Total Loss :1.350195333316151e-07
# it :05900, Data Loss :1.7992702439073582e-08,	 PDE Loss :1.1582313419467027e-07, 	 Total Loss :1.3381583130467334e-07
# it :06000, Data Loss :1.85892261583831e-08,	 PDE Loss :1.1424307189145111e-07, 	 Total Loss :1.328322980498342e-07
# it :06100, Data Loss :1.7944985941653613e-08,	 PDE Loss :1.1358931573113296e-07, 	 Total Loss :1.315343070018571e-07
# it :06200, Data Loss :1.7710705790818793e-08,	 PDE Loss :1.1271144728652871e-07, 	 Total Loss :1.3042215130099066e-07
# it :06300, Data Loss :1.7626604176257388e-08,	 PDE Loss :1.1172966196681955e-07, 	 Total Loss :1.2935626614307694e-07
# it :06400, Data Loss :1.7706497601466253e-08,	 PDE Loss :1.1069897709603538e-07, 	 Total Loss :1.2840547469750163e-07
# it :06500, Data Loss :1.7652936890044657e-08,	 PDE Loss :1.0985085197035005e-07, 	 Total Loss :1.2750379596582206e-07
# it :06600, Data Loss :1.6997553586861613e-08,	 PDE Loss :1.0962016716575818e-07, 	 Total Loss :1.266177207526198e-07
# it :06700, Data Loss :1.735665833280109e-08,	 PDE Loss :1.0814614626042385e-07, 	 Total Loss :1.2550280814593862e-07
# it :06800, Data Loss :1.7395258566921257e-08,	 PDE Loss :1.071212381020814e-07, 	 Total Loss :1.2451650377443002e-07
# it :06900, Data Loss :1.7183227285499925e-08,	 PDE Loss :1.0652246373865637e-07, 	 Total Loss :1.2370568924779946e-07
# it :07000, Data Loss :1.7117855577453156e-08,	 PDE Loss :1.0592713550749977e-07, 	 Total Loss :1.2304499819038028e-07
# it :07100, Data Loss :1.7513359651388782e-08,	 PDE Loss :1.0468630051718719e-07, 	 Total Loss :1.221996654976465e-07
# it :07200, Data Loss :1.7063975121800468e-08,	 PDE Loss :1.0415081419523631e-07, 	 Total Loss :1.2121478221160942e-07
# it :07300, Data Loss :1.6837557126336833e-08,	 PDE Loss :1.0348053081088437e-07, 	 Total Loss :1.2031809148993489e-07
# it :07400, Data Loss :1.7301589494422842e-08,	 PDE Loss :1.0223025270761354e-07, 	 Total Loss :1.195318475311069e-07
# it :07500, Data Loss :1.684555783754149e-08,	 PDE Loss :1.0172894349125272e-07, 	 Total Loss :1.1857450488150789e-07
# it :07600, Data Loss :1.7290824771976077e-08,	 PDE Loss :1.0067542888236858e-07, 	 Total Loss :1.1796625187798782e-07
# it :07700, Data Loss :1.6601109820157944e-08,	 PDE Loss :1.0056031385374808e-07, 	 Total Loss :1.1716142012119235e-07
# it :07800, Data Loss :1.7015587161495205e-08,	 PDE Loss :9.94100091133987e-08, 	 Total Loss :1.164255962748939e-07
# it :07900, Data Loss :1.6552951009884964e-08,	 PDE Loss :9.896722730218244e-08, 	 Total Loss :1.1552018008842424e-07
# it :08000, Data Loss :1.6383392420493692e-08,	 PDE Loss :9.832383796037902e-08, 	 Total Loss :1.147072339335864e-07
# it :08100, Data Loss :1.6826760429466958e-08,	 PDE Loss :9.719957461129525e-08, 	 Total Loss :1.140263350407622e-07
# it :08200, Data Loss :1.634759172475242e-08,	 PDE Loss :9.678834089754673e-08, 	 Total Loss :1.1313593262229915e-07
# it :08300, Data Loss :1.6194144691894508e-08,	 PDE Loss :9.628816144413577e-08, 	 Total Loss :1.1248230435967344e-07
# it :08400, Data Loss :1.6131560087728758e-08,	 PDE Loss :9.572629977583347e-08, 	 Total Loss :1.1185785808720539e-07
# it :08500, Data Loss :1.6539587477382156e-08,	 PDE Loss :9.466534578450592e-08, 	 Total Loss :1.1120493326188807e-07
# it :08600, Data Loss :1.6084095832979983e-08,	 PDE Loss :9.42815461257851e-08, 	 Total Loss :1.1036564018240824e-07
# it :08700, Data Loss :1.591178389048764e-08,	 PDE Loss :9.371857601081501e-08, 	 Total Loss :1.0963036345401633e-07
# it :08800, Data Loss :1.588412423814134e-08,	 PDE Loss :9.307395032465138e-08, 	 Total Loss :1.0895807633914956e-07
# it :08900, Data Loss :1.5951401977076785e-08,	 PDE Loss :9.256882549379952e-08, 	 Total Loss :1.0852022569451947e-07
# it :09000, Data Loss :1.588207965141919e-08,	 PDE Loss :9.206024742525187e-08, 	 Total Loss :1.0794232707667106e-07
# it :09100, Data Loss :1.5794073604524783e-08,	 PDE Loss :9.146103963075802e-08, 	 Total Loss :1.0725511145892597e-07
# it :09200, Data Loss :1.582686870449379e-08,	 PDE Loss :9.08276902578109e-08, 	 Total Loss :1.0665456073866153e-07
# it :09300, Data Loss :1.5469654002231437e-08,	 PDE Loss :9.062346606469873e-08, 	 Total Loss :1.0609311829057333e-07
# it :09400, Data Loss :1.5348778248380768e-08,	 PDE Loss :9.010351931237892e-08, 	 Total Loss :1.0545230111347337e-07
# it :09500, Data Loss :1.5521971263865453e-08,	 PDE Loss :8.923332472932088e-08, 	 Total Loss :1.047552942168295e-07
# it :09600, Data Loss :1.5402605413328274e-08,	 PDE Loss :8.885691471505197e-08, 	 Total Loss :1.0425952012838025e-07
# it :09700, Data Loss :1.5826477905989123e-08,	 PDE Loss :8.788481409283122e-08, 	 Total Loss :1.0371129377517718e-07
# it :09800, Data Loss :1.5437706224474823e-08,	 PDE Loss :8.759958092241504e-08, 	 Total Loss :1.0303728714688987e-07
# it :09900, Data Loss :1.490597334452559e-08,	 PDE Loss :8.762373227000353e-08, 	 Total Loss :1.0252970383817228e-07
# it :10000, Data Loss :1.5222758165123196e-08,	 PDE Loss :8.655209171593015e-08, 	 Total Loss :1.0177485165741018e-07
# it :10100, Data Loss :1.558400342105415e-08,	 PDE Loss :8.570108178673763e-08, 	 Total Loss :1.012850816550781e-07
# it :10200, Data Loss :1.549769024222769e-08,	 PDE Loss :8.516675364944604e-08, 	 Total Loss :1.0066444389167373e-07
# it :10300, Data Loss :1.5116821572291883e-08,	 PDE Loss :8.486016156439291e-08, 	 Total Loss :9.997698668939847e-08
# it :10400, Data Loss :1.4958324356939556e-08,	 PDE Loss :8.441363519295919e-08, 	 Total Loss :9.937195954989875e-08
# it :10500, Data Loss :1.4589377705931383e-08,	 PDE Loss :8.435488751956655e-08, 	 Total Loss :9.894426256096267e-08
# it :10600, Data Loss :1.4981884177700522e-08,	 PDE Loss :8.338007972952255e-08, 	 Total Loss :9.836196568357991e-08
# it :10700, Data Loss :1.4779569568190709e-08,	 PDE Loss :8.303482701421672e-08, 	 Total Loss :9.781439302969375e-08
# it :10800, Data Loss :1.5048781776272335e-08,	 PDE Loss :8.222174585625908e-08, 	 Total Loss :9.727052940888825e-08
# it :10900, Data Loss :1.4794268921036746e-08,	 PDE Loss :8.188656863694632e-08, 	 Total Loss :9.668083578162623e-08
# it :11000, Data Loss :1.4877075571462228e-08,	 PDE Loss :8.127243944500151e-08, 	 Total Loss :9.61495132401069e-08
# it :11100, Data Loss :1.4679741866530094e-08,	 PDE Loss :8.091151215694481e-08, 	 Total Loss :9.55912540234749e-08
# it :11200, Data Loss :1.4597246078551507e-08,	 PDE Loss :8.047310728898083e-08, 	 Total Loss :9.507035514388917e-08
# it :11300, Data Loss :1.4586556851270416e-08,	 PDE Loss :8.005767426766397e-08, 	 Total Loss :9.464422845439913e-08
# it :11400, Data Loss :1.4422688821014162e-08,	 PDE Loss :7.968566251292941e-08, 	 Total Loss :9.410835133394357e-08
# it :11500, Data Loss :1.4718096963406424e-08,	 PDE Loss :7.890455577808098e-08, 	 Total Loss :9.36226527414874e-08
# it :11600, Data Loss :1.4582434815224588e-08,	 PDE Loss :7.849879324339781e-08, 	 Total Loss :9.308122628226556e-08
# it :11700, Data Loss :1.4473414466920076e-08,	 PDE Loss :7.811463120788176e-08, 	 Total Loss :9.258804567480183e-08
# it :11800, Data Loss :1.4403299886112109e-08,	 PDE Loss :7.773270027655599e-08, 	 Total Loss :9.213599838631126e-08
# it :11900, Data Loss :1.4091141586902722e-08,	 PDE Loss :7.756299424954705e-08, 	 Total Loss :9.165413672462819e-08
# it :12000, Data Loss :1.4271426707068713e-08,	 PDE Loss :7.687734182582062e-08, 	 Total Loss :9.114877030924617e-08
# it :12100, Data Loss :1.4203433984505409e-08,	 PDE Loss :7.64607790415539e-08, 	 Total Loss :9.066421569059457e-08
# it :12200, Data Loss :1.4092087496919703e-08,	 PDE Loss :7.610457686269001e-08, 	 Total Loss :9.019666435960971e-08
# it :12300, Data Loss :1.4164474926303683e-08,	 PDE Loss :7.562902482050049e-08, 	 Total Loss :8.979350241133943e-08
# it :12400, Data Loss :1.3816064736715816e-08,	 PDE Loss :7.554312730917445e-08, 	 Total Loss :8.935919026953343e-08
# it :12500, Data Loss :1.4037709661351983e-08,	 PDE Loss :7.490192643899718e-08, 	 Total Loss :8.893963610034916e-08
# it :12600, Data Loss :1.389892467784648e-08,	 PDE Loss :7.457038009306416e-08, 	 Total Loss :8.846930654726748e-08
# it :12700, Data Loss :1.4074126752916527e-08,	 PDE Loss :7.394775991542701e-08, 	 Total Loss :8.80218848919867e-08
# it :12800, Data Loss :1.38950753125755e-08,	 PDE Loss :7.370763199787689e-08, 	 Total Loss :8.760270731045239e-08
# it :12900, Data Loss :1.3769778206551564e-08,	 PDE Loss :7.337883545233126e-08, 	 Total Loss :8.714861365888282e-08
# it :13000, Data Loss :1.399411964086994e-08,	 PDE Loss :7.274000779489143e-08, 	 Total Loss :8.673412565940453e-08
# it :13100, Data Loss :1.3760153905195693e-08,	 PDE Loss :7.250339706388331e-08, 	 Total Loss :8.626355452179268e-08
# it :13200, Data Loss :1.3634183559929625e-08,	 PDE Loss :7.219074404929415e-08, 	 Total Loss :8.582492938558062e-08
# it :13300, Data Loss :1.3828246991920423e-08,	 PDE Loss :7.158459425227193e-08, 	 Total Loss :8.541284302054919e-08
# it :13400, Data Loss :1.3626381800690979e-08,	 PDE Loss :7.134109125672694e-08, 	 Total Loss :8.496747483377476e-08
# it :13500, Data Loss :1.347659939199275e-08,	 PDE Loss :7.106802257794698e-08, 	 Total Loss :8.454462374629657e-08
# it :13600, Data Loss :1.3799901665834113e-08,	 PDE Loss :7.038762106503782e-08, 	 Total Loss :8.418751917815825e-08
# it :13700, Data Loss :1.3503238527334815e-08,	 PDE Loss :7.020672398994066e-08, 	 Total Loss :8.370996340545389e-08
# it :13800, Data Loss :1.3462312153933453e-08,	 PDE Loss :6.984648592833764e-08, 	 Total Loss :8.33087980822711e-08
# it :13900, Data Loss :1.3419956701454794e-08,	 PDE Loss :6.948945951990027e-08, 	 Total Loss :8.290941622135506e-08
# it :14000, Data Loss :1.330297560997451e-08,	 PDE Loss :6.920370054785963e-08, 	 Total Loss :8.250667349329888e-08
# it :14100, Data Loss :1.3188493852567262e-08,	 PDE Loss :6.894163107062923e-08, 	 Total Loss :8.213012847591017e-08
# it :14200, Data Loss :1.3272656751439627e-08,	 PDE Loss :6.845311162351209e-08, 	 Total Loss :8.172576571041645e-08
# it :14300, Data Loss :1.3280470056997729e-08,	 PDE Loss :6.805269237020184e-08, 	 Total Loss :8.133316242719957e-08
# it :14400, Data Loss :1.2990575726234965e-08,	 PDE Loss :6.800377860827211e-08, 	 Total Loss :8.099435433450708e-08
# it :14500, Data Loss :1.3427571943225303e-08,	 PDE Loss :6.722005707615608e-08, 	 Total Loss :8.064763079573822e-08
# it :14600, Data Loss :1.3411652233230598e-08,	 PDE Loss :6.691740139785907e-08, 	 Total Loss :8.032905185473282e-08
# it :14700, Data Loss :1.3121066011478888e-08,	 PDE Loss :6.678374120383523e-08, 	 Total Loss :7.990480810349254e-08
# it :14800, Data Loss :1.2980138741625069e-08,	 PDE Loss :6.662005347379818e-08, 	 Total Loss :7.960019132724483e-08
# it :14900, Data Loss :1.3088090611290681e-08,	 PDE Loss :6.621768733339195e-08, 	 Total Loss :7.930577794468263e-08
# it :15000, Data Loss :1.304470576002359e-08,	 PDE Loss :6.59236505384797e-08, 	 Total Loss :7.896835541032488e-08
# it :15100, Data Loss :1.299029506185434e-08,	 PDE Loss :6.564160770494709e-08, 	 Total Loss :7.863189921408775e-08
# it :15200, Data Loss :1.298522978032679e-08,	 PDE Loss :6.529796792165143e-08, 	 Total Loss :7.828320036651348e-08
# it :15300, Data Loss :1.3004508581104801e-08,	 PDE Loss :6.496166804481618e-08, 	 Total Loss :7.79661775140994e-08
# it :15400, Data Loss :1.287973105945639e-08,	 PDE Loss :6.477022651552033e-08, 	 Total Loss :7.764995757497672e-08
# it :15500, Data Loss :1.2713616825976715e-08,	 PDE Loss :6.46213678123786e-08, 	 Total Loss :7.733498819106899e-08
# it :15600, Data Loss :1.2745578814588043e-08,	 PDE Loss :6.423717735515311e-08, 	 Total Loss :7.698275794609799e-08
# it :15700, Data Loss :1.277905870011864e-08,	 PDE Loss :6.387922724115924e-08, 	 Total Loss :7.665828860581314e-08
# it :15800, Data Loss :1.2812829908170897e-08,	 PDE Loss :6.352131975972952e-08, 	 Total Loss :7.633414611518674e-08
# it :15900, Data Loss :1.27605765953831e-08,	 PDE Loss :6.326065715711593e-08, 	 Total Loss :7.602123730521271e-08
# it :16000, Data Loss :1.2658055936753954e-08,	 PDE Loss :6.304561139813813e-08, 	 Total Loss :7.570366733489209e-08
# it :16100, Data Loss :1.2703889495924159e-08,	 PDE Loss :6.272600217016588e-08, 	 Total Loss :7.542989521880372e-08
# it :16200, Data Loss :1.2573223351353136e-08,	 PDE Loss :6.256146889427328e-08, 	 Total Loss :7.513469313380483e-08
# it :16300, Data Loss :1.2567096696614044e-08,	 PDE Loss :6.230684590491364e-08, 	 Total Loss :7.487394526606295e-08
# it :16400, Data Loss :1.260273752023977e-08,	 PDE Loss :6.19533153667362e-08, 	 Total Loss :7.455605555151124e-08
# it :16500, Data Loss :1.2544429495164877e-08,	 PDE Loss :6.175022804200125e-08, 	 Total Loss :7.429466108987981e-08
# it :16600, Data Loss :1.2537656246536244e-08,	 PDE Loss :6.145133824020377e-08, 	 Total Loss :7.398899271038317e-08
# it :16700, Data Loss :1.232367630166209e-08,	 PDE Loss :6.13735053889286e-08, 	 Total Loss :7.369717991423386e-08
# it :16800, Data Loss :1.2416681016702569e-08,	 PDE Loss :6.095981319731436e-08, 	 Total Loss :7.337649776673061e-08
# it :16900, Data Loss :1.2370069413236706e-08,	 PDE Loss :6.074123604093984e-08, 	 Total Loss :7.311130900689022e-08
# it :17000, Data Loss :1.2336771604282148e-08,	 PDE Loss :6.053010537243608e-08, 	 Total Loss :7.286687520036139e-08
# it :17100, Data Loss :1.220457956918608e-08,	 PDE Loss :6.040802702500514e-08, 	 Total Loss :7.261260748236964e-08
# it :17200, Data Loss :1.2297089568846786e-08,	 PDE Loss :6.000294661134831e-08, 	 Total Loss :7.230003973290877e-08
# it :17300, Data Loss :1.2299787854885835e-08,	 PDE Loss :5.972134431431186e-08, 	 Total Loss :7.202113039284086e-08
# it :17400, Data Loss :1.227409462956075e-08,	 PDE Loss :5.947590864252561e-08, 	 Total Loss :7.175000149572952e-08
# it :17500, Data Loss :1.220671208557178e-08,	 PDE Loss :5.9298720600509114e-08, 	 Total Loss :7.15054326860809e-08
# it :17600, Data Loss :1.2349813616197025e-08,	 PDE Loss :5.891203969099479e-08, 	 Total Loss :7.126185153083497e-08
# it :17700, Data Loss :1.230247015371333e-08,	 PDE Loss :5.8674626046695266e-08, 	 Total Loss :7.097709442405176e-08
# it :17800, Data Loss :1.212810829542832e-08,	 PDE Loss :5.8561127502798627e-08, 	 Total Loss :7.068923935094062e-08
# it :17900, Data Loss :1.2161874174410059e-08,	 PDE Loss :5.826535343089745e-08, 	 Total Loss :7.042722671712909e-08
# it :18000, Data Loss :1.1928546150841157e-08,	 PDE Loss :5.8251742984793964e-08, 	 Total Loss :7.018029180017038e-08
# it :18100, Data Loss :1.2010678673846087e-08,	 PDE Loss :5.787187618011558e-08, 	 Total Loss :6.988255307760483e-08
# it :18200, Data Loss :1.2151080142075443e-08,	 PDE Loss :5.747712350512302e-08, 	 Total Loss :6.962820009448478e-08
# it :18300, Data Loss :1.1965406443437132e-08,	 PDE Loss :5.740453090652409e-08, 	 Total Loss :6.936993912631806e-08
# it :18400, Data Loss :1.2073582134064509e-08,	 PDE Loss :5.704053762656258e-08, 	 Total Loss :6.911412242516235e-08
# it :18500, Data Loss :1.1957507872750739e-08,	 PDE Loss :5.690193560781154e-08, 	 Total Loss :6.885944259238386e-08
# it :18600, Data Loss :1.1879064842901244e-08,	 PDE Loss :5.671885361380191e-08, 	 Total Loss :6.859792023306e-08
# it :18700, Data Loss :1.191118315091444e-08,	 PDE Loss :5.6439485973669434e-08, 	 Total Loss :6.835067267729755e-08
# it :18800, Data Loss :1.2069458321661841e-08,	 PDE Loss :5.612800890730796e-08, 	 Total Loss :6.819746545261296e-08
# it :18900, Data Loss :1.186657616614184e-08,	 PDE Loss :5.605689779031309e-08, 	 Total Loss :6.792347306827651e-08
# it :19000, Data Loss :1.1859184745333096e-08,	 PDE Loss :5.583308748668969e-08, 	 Total Loss :6.769226956748753e-08
# it :19100, Data Loss :1.192069021271891e-08,	 PDE Loss :5.554698390142221e-08, 	 Total Loss :6.746767411414112e-08
# it :19200, Data Loss :1.1778773512105545e-08,	 PDE Loss :5.542717573803202e-08, 	 Total Loss :6.720594569742389e-08
# it :19300, Data Loss :1.1707324887311188e-08,	 PDE Loss :5.526620583395925e-08, 	 Total Loss :6.697352716855676e-08
# it :19400, Data Loss :1.1820346479396449e-08,	 PDE Loss :5.49221290668811e-08, 	 Total Loss :6.674247288174229e-08
# it :19500, Data Loss :1.1701350999260285e-08,	 PDE Loss :5.479171960587337e-08, 	 Total Loss :6.649307238149049e-08
# it :19600, Data Loss :1.1512412356751156e-08,	 PDE Loss :5.478878506437468e-08, 	 Total Loss :6.630119742112583e-08
# it :19700, Data Loss :1.1547868439265585e-08,	 PDE Loss :5.449716056205034e-08, 	 Total Loss :6.60450325540296e-08
# it :19800, Data Loss :1.158845996940272e-08,	 PDE Loss :5.4227914603188765e-08, 	 Total Loss :6.581637279623465e-08
# it :19900, Data Loss :1.1764270446690261e-08,	 PDE Loss :5.385967583038109e-08, 	 Total Loss :6.56239436125361e-08
# it :20000, Data Loss :1.1559659895965524e-08,	 PDE Loss :5.381401990689483e-08, 	 Total Loss :6.537368335557403e-08
# it :20100, Data Loss :1.1578856096150503e-08,	 PDE Loss :5.356521626254107e-08, 	 Total Loss :6.514407147051315e-08
# it :20200, Data Loss :1.1614983641550225e-08,	 PDE Loss :5.335519759341878e-08, 	 Total Loss :6.497018034679058e-08
# it :20300, Data Loss :1.1467673033394021e-08,	 PDE Loss :5.327720131731439e-08, 	 Total Loss :6.474487435070841e-08
# it :20400, Data Loss :1.1448468839603265e-08,	 PDE Loss :5.3077183537197925e-08, 	 Total Loss :6.452565060044435e-08
# it :20500, Data Loss :1.1467832905509567e-08,	 PDE Loss :5.2870511524361063e-08, 	 Total Loss :6.433834442987063e-08
# it :20600, Data Loss :1.1341185768287687e-08,	 PDE Loss :5.280089609982497e-08, 	 Total Loss :6.414208542082633e-08
# it :20700, Data Loss :1.1429396984397044e-08,	 PDE Loss :5.249111367788828e-08, 	 Total Loss :6.39205097741069e-08
# it :20800, Data Loss :1.1449085235426537e-08,	 PDE Loss :5.227579080724354e-08, 	 Total Loss :6.372487604267008e-08
# it :20900, Data Loss :1.1423866297377572e-08,	 PDE Loss :5.210187126181154e-08, 	 Total Loss :6.352573933554595e-08
# it :21000, Data Loss :1.1354139850539013e-08,	 PDE Loss :5.197033203785395e-08, 	 Total Loss :6.332447100021454e-08
# it :21100, Data Loss :1.1405238531381201e-08,	 PDE Loss :5.17204377104008e-08, 	 Total Loss :6.312567535360358e-08
# it :21200, Data Loss :1.1289261969693598e-08,	 PDE Loss :5.1639094778010985e-08, 	 Total Loss :6.2928357635883e-08
# it :21300, Data Loss :1.1273896483032786e-08,	 PDE Loss :5.1462574646166104e-08, 	 Total Loss :6.273646846466363e-08
# it :21400, Data Loss :1.1292790702555067e-08,	 PDE Loss :5.12601836533122e-08, 	 Total Loss :6.255297080315358e-08
# it :21500, Data Loss :1.1207308858729448e-08,	 PDE Loss :5.115062151617167e-08, 	 Total Loss :6.235792682218744e-08
# it :21600, Data Loss :1.1302936364643301e-08,	 PDE Loss :5.086186405378612e-08, 	 Total Loss :6.216480130660784e-08
# it :21700, Data Loss :1.1205274930148335e-08,	 PDE Loss :5.075061793036184e-08, 	 Total Loss :6.195589463686701e-08
# it :21800, Data Loss :1.1199490224100828e-08,	 PDE Loss :5.057253105178461e-08, 	 Total Loss :6.177202038770702e-08
# it :21900, Data Loss :1.1189478676953968e-08,	 PDE Loss :5.040050510274341e-08, 	 Total Loss :6.158998644423264e-08
# it :22000, Data Loss :1.1038233438398493e-08,	 PDE Loss :5.037948014319227e-08, 	 Total Loss :6.14177153579476e-08
# it :22100, Data Loss :1.1119816178961628e-08,	 PDE Loss :5.0109424165611927e-08, 	 Total Loss :6.122924389728723e-08
# it :22200, Data Loss :1.1038824965226013e-08,	 PDE Loss :4.999982650133461e-08, 	 Total Loss :6.103864791384694e-08
# it :22300, Data Loss :1.1224122964392791e-08,	 PDE Loss :4.966882016788077e-08, 	 Total Loss :6.089294402045198e-08
# it :22400, Data Loss :1.115289549602494e-08,	 PDE Loss :4.954139498636323e-08, 	 Total Loss :6.069429048238817e-08
# it :22500, Data Loss :1.1138544309119425e-08,	 PDE Loss :4.938420872235838e-08, 	 Total Loss :6.052275125512097e-08
# it :22600, Data Loss :1.099707347407275e-08,	 PDE Loss :4.933921005090269e-08, 	 Total Loss :6.033628352497544e-08
# it :22700, Data Loss :1.0876209266541537e-08,	 PDE Loss :4.9311331906665146e-08, 	 Total Loss :6.018753850867142e-08
# it :22800, Data Loss :1.0955691465142081e-08,	 PDE Loss :4.902808115048174e-08, 	 Total Loss :5.99837761683375e-08
# it :22900, Data Loss :1.105749447560811e-08,	 PDE Loss :4.8761584992007556e-08, 	 Total Loss :5.981907946761567e-08
# it :23000, Data Loss :1.0847987397255565e-08,	 PDE Loss :4.8791829243555185e-08, 	 Total Loss :5.963981664081075e-08
# it :23100, Data Loss :1.0840222941510547e-08,	 PDE Loss :4.862025804186487e-08, 	 Total Loss :5.946048275973226e-08
# it :23200, Data Loss :1.086497380953233e-08,	 PDE Loss :4.8422787557456104e-08, 	 Total Loss :5.9287760478810014e-08
# it :23300, Data Loss :1.0884969370295039e-08,	 PDE Loss :4.8252868367626434e-08, 	 Total Loss :5.913783951427831e-08
# it :23400, Data Loss :1.0928668636722705e-08,	 PDE Loss :4.8056019608111455e-08, 	 Total Loss :5.898468913301258e-08
# it :23500, Data Loss :1.0712721376648915e-08,	 PDE Loss :4.812612175442155e-08, 	 Total Loss :5.883884313107046e-08
# it :23600, Data Loss :1.0808147266061496e-08,	 PDE Loss :4.783221640991542e-08, 	 Total Loss :5.8640363675976914e-08
# it :23700, Data Loss :1.0774392933399213e-08,	 PDE Loss :4.7708333283935644e-08, 	 Total Loss :5.848272621733486e-08
# it :23800, Data Loss :1.0762351898563338e-08,	 PDE Loss :4.756170213227051e-08, 	 Total Loss :5.832405491901227e-08
# it :23900, Data Loss :1.0668714800488033e-08,	 PDE Loss :4.7514596701603296e-08, 	 Total Loss :5.818331061391291e-08
# it :24000, Data Loss :1.0704894748414517e-08,	 PDE Loss :4.730883418346821e-08, 	 Total Loss :5.8013728931882724e-08
# it :24100, Data Loss :1.0734094502140579e-08,	 PDE Loss :4.7127453939310726e-08, 	 Total Loss :5.7861548441451305e-08
# it :24200, Data Loss :1.07321973530361e-08,	 PDE Loss :4.6966896150024695e-08, 	 Total Loss :5.7699093503060794e-08
# it :24300, Data Loss :1.0635061720165595e-08,	 PDE Loss :4.6903572581413755e-08, 	 Total Loss :5.753863518975777e-08
# it :24400, Data Loss :1.064484855817227e-08,	 PDE Loss :4.673813336353305e-08, 	 Total Loss :5.738298369806216e-08
# it :24500, Data Loss :1.067192201276157e-08,	 PDE Loss :4.655606744563556e-08, 	 Total Loss :5.722798945839713e-08
# it :24600, Data Loss :1.0629868540945608e-08,	 PDE Loss :4.6472539594333284e-08, 	 Total Loss :5.710240813527889e-08
# it :24700, Data Loss :1.0712541964608135e-08,	 PDE Loss :4.625340821462487e-08, 	 Total Loss :5.6965951955589844e-08
# it :24800, Data Loss :1.0739588773844844e-08,	 PDE Loss :4.6092537786535104e-08, 	 Total Loss :5.683212833673679e-08
# it :24900, Data Loss :1.0605912592609457e-08,	 PDE Loss :4.6044256407640205e-08, 	 Total Loss :5.665016900024966e-08
# it :25000, Data Loss :1.0528436789059015e-08,	 PDE Loss :4.5993161279511696e-08, 	 Total Loss :5.652159984492755e-08
# it :25100, Data Loss :1.0559620733374686e-08,	 PDE Loss :4.5819955829529135e-08, 	 Total Loss :5.637957656290382e-08
# it :25200, Data Loss :1.0545234019332383e-08,	 PDE Loss :4.5699056983039554e-08, 	 Total Loss :5.62442892260151e-08
# it :25300, Data Loss :1.0476751910459825e-08,	 PDE Loss :4.561634270316972e-08, 	 Total Loss :5.6093092837272707e-08
# it :25400, Data Loss :1.0498236058253951e-08,	 PDE Loss :4.546730281163036e-08, 	 Total Loss :5.596553975806273e-08
# it :25500, Data Loss :1.0528443894486372e-08,	 PDE Loss :4.5296395967397984e-08, 	 Total Loss :5.5824841638241196e-08
# it :25600, Data Loss :1.0448339970992038e-08,	 PDE Loss :4.5239499257831994e-08, 	 Total Loss :5.568783834064561e-08
# it :25700, Data Loss :1.0572190234370282e-08,	 PDE Loss :4.5001719684023556e-08, 	 Total Loss :5.557390991839384e-08
# it :25800, Data Loss :1.0446989051615674e-08,	 PDE Loss :4.496978434076482e-08, 	 Total Loss :5.541677339238049e-08
# it :25900, Data Loss :1.0430010632944686e-08,	 PDE Loss :4.485105975504666e-08, 	 Total Loss :5.528107038799135e-08
# it :26000, Data Loss :1.0442393616472145e-08,	 PDE Loss :4.471441528153264e-08, 	 Total Loss :5.515681067436162e-08
# it :26100, Data Loss :1.0448241383187451e-08,	 PDE Loss :4.457045577055396e-08, 	 Total Loss :5.5018695377384574e-08
# it :26200, Data Loss :1.0360382773910715e-08,	 PDE Loss :4.4523950748498464e-08, 	 Total Loss :5.488433174605234e-08
# it :26300, Data Loss :1.042540986873064e-08,	 PDE Loss :4.433834632777689e-08, 	 Total Loss :5.476375619650753e-08
# it :26400, Data Loss :1.024447193742617e-08,	 PDE Loss :4.4397918230743016e-08, 	 Total Loss :5.4642391944526025e-08
# it :26500, Data Loss :1.0308671249958934e-08,	 PDE Loss :4.417333343553764e-08, 	 Total Loss :5.448200468549658e-08
# it :26600, Data Loss :1.0316842491420175e-08,	 PDE Loss :4.4040188384997236e-08, 	 Total Loss :5.435703087641741e-08
# it :26700, Data Loss :1.0306524522718519e-08,	 PDE Loss :4.39205223301542e-08, 	 Total Loss :5.422704774105114e-08
# it :26800, Data Loss :1.0301917541255534e-08,	 PDE Loss :4.379832319045818e-08, 	 Total Loss :5.410024073171371e-08
# it :26900, Data Loss :1.0316786536179734e-08,	 PDE Loss :4.3654566184159194e-08, 	 Total Loss :5.397135183216051e-08
# it :27000, Data Loss :1.017457051943893e-08,	 PDE Loss :4.367386807757612e-08, 	 Total Loss :5.384843859701505e-08
# it :27100, Data Loss :1.0283065954297399e-08,	 PDE Loss :4.342767923048996e-08, 	 Total Loss :5.3710746072965776e-08
# it :27200, Data Loss :1.032355267938101e-08,	 PDE Loss :4.3282945227929304e-08, 	 Total Loss :5.360649879548873e-08
# it :27300, Data Loss :1.02430801618425e-08,	 PDE Loss :4.322584246096994e-08, 	 Total Loss :5.346892351099086e-08
# it :27400, Data Loss :1.029754415071693e-08,	 PDE Loss :4.3065035981726396e-08, 	 Total Loss :5.336258013244333e-08
# it :27500, Data Loss :1.0156214536038988e-08,	 PDE Loss :4.305403678017683e-08, 	 Total Loss :5.32102504280374e-08
# it :27600, Data Loss :1.017306150430386e-08,	 PDE Loss :4.2928441246203874e-08, 	 Total Loss :5.3101501862329314e-08
# it :27700, Data Loss :1.0087603641295573e-08,	 PDE Loss :4.289620747499612e-08, 	 Total Loss :5.298381111629169e-08
# it :27800, Data Loss :1.0097348734916523e-08,	 PDE Loss :4.27700186378388e-08, 	 Total Loss :5.2867367372755325e-08
# it :27900, Data Loss :1.014267336785224e-08,	 PDE Loss :4.260212804751973e-08, 	 Total Loss :5.2744802303550387e-08
# it :28000, Data Loss :1.0094556301964985e-08,	 PDE Loss :4.2535024391554543e-08, 	 Total Loss :5.262958069351953e-08
# it :28100, Data Loss :1.0082417567502944e-08,	 PDE Loss :4.243673501491685e-08, 	 Total Loss :5.251915169424137e-08
# it :28200, Data Loss :1.0015885010261627e-08,	 PDE Loss :4.238754414132018e-08, 	 Total Loss :5.2403429151581804e-08
# it :28300, Data Loss :1.004747662847194e-08,	 PDE Loss :4.224854421863711e-08, 	 Total Loss :5.229601995893063e-08
# it :28400, Data Loss :9.97613014419585e-09,	 PDE Loss :4.221461935571824e-08, 	 Total Loss :5.219074949991409e-08
# it :28500, Data Loss :1.0100873915064312e-08,	 PDE Loss :4.197459091415112e-08, 	 Total Loss :5.2075463941037015e-08
# it :28600, Data Loss :1.0098328395713452e-08,	 PDE Loss :4.1862332267328384e-08, 	 Total Loss :5.1960661551220255e-08
# it :28700, Data Loss :9.986751869917043e-09,	 PDE Loss :4.184804680562593e-08, 	 Total Loss :5.183479956372139e-08
# it :28800, Data Loss :9.967446423786441e-09,	 PDE Loss :4.175569046083183e-08, 	 Total Loss :5.172313777279669e-08
# it :28900, Data Loss :9.968412761907075e-09,	 PDE Loss :4.1643122727919035e-08, 	 Total Loss :5.161153637800453e-08
# it :29000, Data Loss :9.95566118433544e-09,	 PDE Loss :4.1552286944579464e-08, 	 Total Loss :5.1507946352558065e-08
# it :29100, Data Loss :9.93620297151665e-09,	 PDE Loss :4.146095733403854e-08, 	 Total Loss :5.139715852919835e-08
# it :29200, Data Loss :9.914653986697886e-09,	 PDE Loss :4.137417519700648e-08, 	 Total Loss :5.1288829183704365e-08
# it :29300, Data Loss :9.904566056206932e-09,	 PDE Loss :4.128298769501271e-08, 	 Total Loss :5.118755552757648e-08
# it :29400, Data Loss :9.921872212714788e-09,	 PDE Loss :4.115434037998966e-08, 	 Total Loss :5.107621348088287e-08
# it :29500, Data Loss :9.916343302052155e-09,	 PDE Loss :4.104895978684908e-08, 	 Total Loss :5.0965304865258076e-08
# it :29600, Data Loss :9.868311501293192e-09,	 PDE Loss :4.098605188573856e-08, 	 Total Loss :5.085436427521017e-08
# it :29700, Data Loss :9.873851958275282e-09,	 PDE Loss :4.0871626083571755e-08, 	 Total Loss :5.0745477153668617e-08
# it :29800, Data Loss :9.854499438688435e-09,	 PDE Loss :4.0788844302142024e-08, 	 Total Loss :5.064334374083046e-08
# it :29900, Data Loss :9.857399341228756e-09,	 PDE Loss :4.0676944479400845e-08, 	 Total Loss :5.053434293245118e-08
# it :30000, Data Loss :9.739644646344914e-09,	 PDE Loss :4.070586712145996e-08, 	 Total Loss :5.0445510879626454e-08
# it :30100, Data Loss :9.80425163277232e-09,	 PDE Loss :4.052620639072302e-08, 	 Total Loss :5.03304562471385e-08

# %%
# 시각화
plt.figure(figsize=(10,3))
t_loss = np.log1p(net.total_loss_hist)
p_loss = np.log1p(net.pde_loss_hist)
d_loss = np.log1p(net.data_loss_hist)
epochs = range(1, 1+len(t_loss))
# xbins = range(0, len(t_loss)+1, 50)
# plt.plot(epochs[:100], t_loss[:100], lw=1,linestyle='-', label='Total Loss', c="k")
# plt.plot(epochs[:100], p_loss[:100], lw=1,linestyle='-', label='PDE Loss', c="r")
# plt.plot(epochs[:100], d_loss[:100], lw=1,linestyle='-', label='Data Loss', c="b")
plt.plot(epochs, t_loss, lw=1,linestyle='-', label='Total Loss', c="k")
plt.plot(epochs, p_loss, lw=1,linestyle='-', label='PDE Loss', c="r")
plt.plot(epochs, d_loss, lw=1,linestyle='-', label='Data Loss', c="b")
plt.legend()
plt.grid(True)
# plt.xticks(xbins)
plt.xlabel('per 100 Epochs')
plt.ylabel('Log Loss')
# x, y = epochs[-1], loss[-1]
# plt.text(x, y, y)
plt.show()

# %%
# 데이터 불러오기
# 데이터에 대해서는 ./make_dataset.ipynb 에서 확인
with open(f'./data/data_3_1_1.npy', 'rb') as f:
    data = np.load(f,allow_pickle=True)
x = data.T[0]
y = data.T[1]
X = data[:,:2]
f_true = data.T[2]


X = torch.tensor(X, dtype=torch.float)
X = X.to(net.X.device)

model = net.model
model.eval()
with torch.no_grad():
    f_pred = model(X).cpu().numpy().squeeze()

print("Test MSE Loss : ", np.mean(np.sqrt(np.square(f_true)-np.square(f_pred))))

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(7,3))
# grid
xi, yi = np.mgrid[x.min():x.max():500j, y.min():y.max():500j]

# f_true figure
rbf = scipy.interpolate.Rbf(x, y, f_true)
org = rbf(xi, yi)
img = ax[0].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[0].scatter(x, y, c=f_true)
ax[0].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

# f_pred figure
rbf = scipy.interpolate.Rbf(x, y, f_pred)
org = rbf(xi, yi)
img = ax[1].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[1].scatter(x, y, c=f_pred)
ax[1].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

plt.tight_layout()
# Out:
# /tmp/ipykernel_443/53678129.py:19: RuntimeWarning: invalid value encountered in sqrt
#   print("Test MSE Loss : ", np.mean(np.sqrt(np.square(f_true)-np.square(f_pred))))
# Test MSE Loss :  nan

# %%
# model_3_1_1 save
torch.save(model.state_dict(), "./data/model_3_1_1.pt")

# %%
net = Net(B=3)
net.train()
# Out:
# Model's state_dict:
# layers.input.weight 	 torch.Size([100, 2])
# layers.input.bias 	 torch.Size([100])
# layers.hidden_0.weight 	 torch.Size([100, 100])
# layers.hidden_0.bias 	 torch.Size([100])
# layers.hidden_1.weight 	 torch.Size([100, 100])
# layers.hidden_1.bias 	 torch.Size([100])
# layers.hidden_2.weight 	 torch.Size([100, 100])
# layers.hidden_2.bias 	 torch.Size([100])
# layers.hidden_3.weight 	 torch.Size([100, 100])
# layers.hidden_3.bias 	 torch.Size([100])
# layers.hidden_4.weight 	 torch.Size([100, 100])
# layers.hidden_4.bias 	 torch.Size([100])
# layers.hidden_5.weight 	 torch.Size([100, 100])
# layers.hidden_5.bias 	 torch.Size([100])
# layers.hidden_6.weight 	 torch.Size([100, 100])
# layers.hidden_6.bias 	 torch.Size([100])
# layers.hidden_7.weight 	 torch.Size([100, 100])
# layers.hidden_7.bias 	 torch.Size([100])
# layers.output.weight 	 torch.Size([1, 100])
# layers.output.bias 	 torch.Size([1])
# train with Adam optimizer
# it :00100, Data Loss :0.0010175877250730991,	 PDE Loss :0.09271251410245895, 	 Total Loss :0.09373009949922562
# it :00200, Data Loss :2.2815253032604232e-05,	 PDE Loss :0.0010531044099479914, 	 Total Loss :0.0010759197175502777
# it :00300, Data Loss :1.0522277989366557e-05,	 PDE Loss :0.000698064744938165, 	 Total Loss :0.0007085870020091534
# it :00400, Data Loss :9.451994628761895e-06,	 PDE Loss :0.0006264348630793393, 	 Total Loss :0.0006358868558891118
# it :00500, Data Loss :8.383167369174771e-06,	 PDE Loss :0.0005547007312998176, 	 Total Loss :0.000563083915039897
# it :00600, Data Loss :7.361192729149479e-06,	 PDE Loss :0.00048535893438383937, 	 Total Loss :0.0004927201080136001
# it :00700, Data Loss :6.409525667550042e-06,	 PDE Loss :0.0004200050316285342, 	 Total Loss :0.00042641456821002066
# it :00800, Data Loss :5.540749498322839e-06,	 PDE Loss :0.00035959359956905246, 	 Total Loss :0.00036513435770757496
# it :00900, Data Loss :4.760024239658378e-06,	 PDE Loss :0.00030463794246315956, 	 Total Loss :0.00030939796124584973
# it :01000, Data Loss :4.068544967594789e-06,	 PDE Loss :0.00025534507585689425, 	 Total Loss :0.0002594136167317629
# train with L-BFGs
# it :01100, Data Loss :2.2495132157018816e-07,	 PDE Loss :4.41119709648774e-06, 	 Total Loss :4.6361483327928e-06
# it :01200, Data Loss :7.126409240498788e-09,	 PDE Loss :3.1468007932744513e-07, 	 Total Loss :3.2180648190660577e-07
# it :01300, Data Loss :8.264798623258685e-09,	 PDE Loss :2.649224484230217e-07, 	 Total Loss :2.7318725415170775e-07
# it :01400, Data Loss :7.919281230783781e-09,	 PDE Loss :2.4294763534271624e-07, 	 Total Loss :2.5086691834985686e-07
# it :01500, Data Loss :7.88575515997536e-09,	 PDE Loss :2.424771139430959e-07, 	 Total Loss :2.5036285933310864e-07
# it :01600, Data Loss :7.869838114515915e-09,	 PDE Loss :2.42064004396525e-07, 	 Total Loss :2.499338336292567e-07
# it :01700, Data Loss :7.862171358397063e-09,	 PDE Loss :2.4168610934793833e-07, 	 Total Loss :2.4954829314083327e-07
# it :01800, Data Loss :7.853881989206002e-09,	 PDE Loss :2.412745629953861e-07, 	 Total Loss :2.4912844764912734e-07
# it :01900, Data Loss :7.84769582651279e-09,	 PDE Loss :2.408550585641933e-07, 	 Total Loss :2.4870274728527875e-07
# it :02000, Data Loss :7.842878346764337e-09,	 PDE Loss :2.404530050625908e-07, 	 Total Loss :2.482958905147825e-07
# it :02100, Data Loss :7.836611359834933e-09,	 PDE Loss :2.400874734576064e-07, 	 Total Loss :2.4792407771201397e-07
# it :02200, Data Loss :7.82829889800496e-09,	 PDE Loss :2.3958611450325407e-07, 	 Total Loss :2.4741441961850796e-07
# it :02300, Data Loss :7.821594039114643e-09,	 PDE Loss :2.391295765846735e-07, 	 Total Loss :2.469511741765018e-07
# it :02400, Data Loss :7.814664471084143e-09,	 PDE Loss :2.3866829224061803e-07, 	 Total Loss :2.4648295493534533e-07
# it :02500, Data Loss :7.808029778288983e-09,	 PDE Loss :2.3819467287466978e-07, 	 Total Loss :2.460027133110998e-07
# it :02600, Data Loss :7.803663493177737e-09,	 PDE Loss :2.3785706559920072e-07, 	 Total Loss :2.4566071488152375e-07
# it :02700, Data Loss :7.79965425579121e-09,	 PDE Loss :2.375708021418177e-07, 	 Total Loss :2.4537044396311103e-07
# it :02800, Data Loss :7.795437184654475e-09,	 PDE Loss :2.373031691149663e-07, 	 Total Loss :2.4509861873411865e-07
# it :02900, Data Loss :7.790263545359721e-09,	 PDE Loss :2.3701495877048728e-07, 	 Total Loss :2.448052214276686e-07
# it :03000, Data Loss :7.783922839621482e-09,	 PDE Loss :2.3667709569963336e-07, 	 Total Loss :2.4446100610475696e-07
# it :03100, Data Loss :7.779057398238365e-09,	 PDE Loss :2.3632469492440578e-07, 	 Total Loss :2.441037452172168e-07
# it :03200, Data Loss :7.772817056661552e-09,	 PDE Loss :2.3597374365635915e-07, 	 Total Loss :2.437465695948049e-07
# it :03300, Data Loss :7.76645414646282e-09,	 PDE Loss :2.3557983297450846e-07, 	 Total Loss :2.433462782391871e-07
# it :03400, Data Loss :7.75949171583079e-09,	 PDE Loss :2.3517253566751606e-07, 	 Total Loss :2.4293203182423895e-07
# it :03500, Data Loss :7.753266473287113e-09,	 PDE Loss :2.3479506694457086e-07, 	 Total Loss :2.425483387469285e-07
# it :03600, Data Loss :7.747424035642325e-09,	 PDE Loss :2.3438265372988099e-07, 	 Total Loss :2.4213008487095067e-07
# it :03700, Data Loss :7.74243247292361e-09,	 PDE Loss :2.3407076810144645e-07, 	 Total Loss :2.418132112325111e-07
# it :03800, Data Loss :8.55871462590585e-09,	 PDE Loss :2.2850760217352217e-07, 	 Total Loss :2.3706631679942802e-07
# it :03900, Data Loss :8.51476311680699e-09,	 PDE Loss :2.2762233697903866e-07, 	 Total Loss :2.361370974313104e-07
# it :04000, Data Loss :8.47385983604454e-09,	 PDE Loss :2.2684942280193354e-07, 	 Total Loss :2.3532328441433492e-07
# it :04100, Data Loss :8.438718168690684e-09,	 PDE Loss :2.260514264662561e-07, 	 Total Loss :2.3449014463494677e-07
# it :04200, Data Loss :8.407595508685972e-09,	 PDE Loss :2.2517102138408518e-07, 	 Total Loss :2.3357861778094957e-07
# it :04300, Data Loss :8.374717808123933e-09,	 PDE Loss :2.2419402512241504e-07, 	 Total Loss :2.3256873760146846e-07
# it :04400, Data Loss :8.349474001079216e-09,	 PDE Loss :2.232909679378281e-07, 	 Total Loss :2.3164044193890732e-07
# it :04500, Data Loss :8.330588663341132e-09,	 PDE Loss :2.2241232500164188e-07, 	 Total Loss :2.307429127768046e-07
# it :04600, Data Loss :8.313136845572444e-09,	 PDE Loss :2.2155340673180035e-07, 	 Total Loss :2.298665435773728e-07
# it :04700, Data Loss :8.29594171136705e-09,	 PDE Loss :2.206459583931064e-07, 	 Total Loss :2.2894190010447346e-07
# it :04800, Data Loss :8.280078844791205e-09,	 PDE Loss :2.197430148953572e-07, 	 Total Loss :2.2802309729286208e-07
# it :04900, Data Loss :8.264109396804997e-09,	 PDE Loss :2.1880950384911557e-07, 	 Total Loss :2.2707361324592057e-07
# it :05000, Data Loss :8.249626759493367e-09,	 PDE Loss :2.1789740856092976e-07, 	 Total Loss :2.2614703709677997e-07
# it :05100, Data Loss :8.235765847075527e-09,	 PDE Loss :2.1699365504446178e-07, 	 Total Loss :2.2522942799696466e-07
# it :05200, Data Loss :8.221150871179361e-09,	 PDE Loss :2.1610753719869535e-07, 	 Total Loss :2.243286871816963e-07
# it :05300, Data Loss :8.207079460476052e-09,	 PDE Loss :2.150848104065517e-07, 	 Total Loss :2.232918916433846e-07
# it :05400, Data Loss :8.190125910800816e-09,	 PDE Loss :2.1409144324024965e-07, 	 Total Loss :2.222815709274073e-07
# it :05500, Data Loss :8.179585897494235e-09,	 PDE Loss :2.1314160392194026e-07, 	 Total Loss :2.2132118715489923e-07
# it :05600, Data Loss :8.07851385786762e-09,	 PDE Loss :1.7394823714766972e-07, 	 Total Loss :1.8202675278189417e-07
# it :05700, Data Loss :7.98823407421878e-09,	 PDE Loss :1.7379564098973788e-07, 	 Total Loss :1.8178387506395666e-07

# %%
# 시각화
plt.figure(figsize=(10,3))
t_loss = np.log1p(net.total_loss_hist)
p_loss = np.log1p(net.pde_loss_hist)
d_loss = np.log1p(net.data_loss_hist)
epochs = range(1, 1+len(t_loss))
# xbins = range(0, len(t_loss)+1, 50)
# plt.plot(epochs[:100], t_loss[:100], lw=1,linestyle='-', label='Total Loss', c="k")
# plt.plot(epochs[:100], p_loss[:100], lw=1,linestyle='-', label='PDE Loss', c="r")
# plt.plot(epochs[:100], d_loss[:100], lw=1,linestyle='-', label='Data Loss', c="b")
plt.plot(epochs, t_loss, lw=1,linestyle='-', label='Total Loss', c="k")
plt.plot(epochs, p_loss, lw=1,linestyle='-', label='PDE Loss', c="r")
plt.plot(epochs, d_loss, lw=1,linestyle='-', label='Data Loss', c="b")
plt.legend()
plt.grid(True)
# plt.xticks(xbins)
plt.xlabel('per 100 Epochs')
plt.ylabel('Log Loss')
# x, y = epochs[-1], loss[-1]
# plt.text(x, y, y)
plt.show()

# %%
# 데이터 불러오기
# 데이터에 대해서는 ./make_dataset.ipynb 에서 확인
with open(f'./data/data_1_3_1.npy', 'rb') as f:
    data = np.load(f,allow_pickle=True)
x = data.T[0]
y = data.T[1]
X = data[:,:2]
f_true = data.T[2]


X = torch.tensor(X, dtype=torch.float)
X = X.to(net.X.device)

model = net.model
model.eval()
with torch.no_grad():
    f_pred = model(X).cpu().numpy().squeeze()

print("Test MSE Loss : ", np.mean(np.sqrt(np.square(f_true)-np.square(f_pred))))

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(7,3))
# grid
xi, yi = np.mgrid[x.min():x.max():500j, y.min():y.max():500j]

# f_true figure
rbf = scipy.interpolate.Rbf(x, y, f_true)
org = rbf(xi, yi)
img = ax[0].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[0].scatter(x, y, c=f_true)
ax[0].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

# f_pred figure
rbf = scipy.interpolate.Rbf(x, y, f_pred)
org = rbf(xi, yi)
img = ax[1].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[1].scatter(x, y, c=f_pred)
ax[1].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

plt.tight_layout()
# Out:
# Test MSE Loss :  0.40762235260201557

# %%
# model_1_3_1 save
torch.save(model.state_dict(), "./data/model_1_3_1.pt")

# %%
net = Net(C=3)
net.train()
# Out:
# Model's state_dict:
# layers.input.weight 	 torch.Size([100, 2])
# layers.input.bias 	 torch.Size([100])
# layers.hidden_0.weight 	 torch.Size([100, 100])
# layers.hidden_0.bias 	 torch.Size([100])
# layers.hidden_1.weight 	 torch.Size([100, 100])
# layers.hidden_1.bias 	 torch.Size([100])
# layers.hidden_2.weight 	 torch.Size([100, 100])
# layers.hidden_2.bias 	 torch.Size([100])
# layers.hidden_3.weight 	 torch.Size([100, 100])
# layers.hidden_3.bias 	 torch.Size([100])
# layers.hidden_4.weight 	 torch.Size([100, 100])
# layers.hidden_4.bias 	 torch.Size([100])
# layers.hidden_5.weight 	 torch.Size([100, 100])
# layers.hidden_5.bias 	 torch.Size([100])
# layers.hidden_6.weight 	 torch.Size([100, 100])
# layers.hidden_6.bias 	 torch.Size([100])
# layers.hidden_7.weight 	 torch.Size([100, 100])
# layers.hidden_7.bias 	 torch.Size([100])
# layers.output.weight 	 torch.Size([1, 100])
# layers.output.bias 	 torch.Size([1])
# train with Adam optimizer
# it :00100, Data Loss :6.534949352499098e-05,	 PDE Loss :0.003926853183656931, 	 Total Loss :0.003992202691733837
# it :00200, Data Loss :5.235327989794314e-06,	 PDE Loss :0.0002464877616148442, 	 Total Loss :0.00025172310415655375
# it :00300, Data Loss :4.61786021332955e-06,	 PDE Loss :0.0002081855054711923, 	 Total Loss :0.00021280336659401655
# it :00400, Data Loss :3.8832463360449765e-06,	 PDE Loss :0.00017118830874096602, 	 Total Loss :0.00017507156007923186
# it :00500, Data Loss :3.201354957127478e-06,	 PDE Loss :0.00013742948067374527, 	 Total Loss :0.00014063082926440984
# it :00600, Data Loss :2.5922004169842694e-06,	 PDE Loss :0.00010791997192427516, 	 Total Loss :0.00011051217006752267
# it :00700, Data Loss :2.062620978904306e-06,	 PDE Loss :8.297499880427495e-05, 	 Total Loss :8.503761637257412e-05
# it :00800, Data Loss :1.6139897525135893e-06,	 PDE Loss :6.250778824323788e-05, 	 Total Loss :6.412177754100412e-05
# it :00900, Data Loss :1.242845883098198e-06,	 PDE Loss :4.6196837502066046e-05, 	 Total Loss :4.7439683839911595e-05
# it :01000, Data Loss :9.426450446881063e-07,	 PDE Loss :3.35753575200215e-05, 	 Total Loss :3.4518001484684646e-05
# train with L-BFGs
# it :01100, Data Loss :5.347459008930855e-08,	 PDE Loss :2.1657051547663286e-06, 	 Total Loss :2.2191798052517697e-06
# it :01200, Data Loss :5.568417282830751e-09,	 PDE Loss :3.3212731409548724e-07, 	 Total Loss :3.376957238288014e-07
# it :01300, Data Loss :6.8223720006699295e-09,	 PDE Loss :2.264145990693578e-07, 	 Total Loss :2.332369746227414e-07
# it :01400, Data Loss :6.760251913817683e-09,	 PDE Loss :2.2550455014425097e-07, 	 Total Loss :2.3226479584081972e-07
# it :01500, Data Loss :6.713043010364572e-09,	 PDE Loss :2.2474125671578804e-07, 	 Total Loss :2.3145429395299288e-07
# it :01600, Data Loss :6.654877093836831e-09,	 PDE Loss :2.2394904419797967e-07, 	 Total Loss :2.306039164068352e-07
# it :01700, Data Loss :6.611293290603726e-09,	 PDE Loss :2.232590929907019e-07, 	 Total Loss :2.298703805081459e-07
# it :01800, Data Loss :6.5186007702777715e-09,	 PDE Loss :2.2232264029753424e-07, 	 Total Loss :2.2884124462052569e-07
# it :01900, Data Loss :6.5010876681981244e-09,	 PDE Loss :2.2172828550992563e-07, 	 Total Loss :2.2822936784905323e-07
# it :02000, Data Loss :6.46979358975841e-09,	 PDE Loss :2.2108692121491913e-07, 	 Total Loss :2.2755671125196386e-07
# it :02100, Data Loss :6.433988453125039e-09,	 PDE Loss :2.204674842687382e-07, 	 Total Loss :2.2690147716275533e-07
# it :02200, Data Loss :6.406111641155121e-09,	 PDE Loss :2.198741810843785e-07, 	 Total Loss :2.2628029228144442e-07
# it :02300, Data Loss :6.367163685183641e-09,	 PDE Loss :2.1923391102518508e-07, 	 Total Loss :2.2560107026947662e-07
# it :02400, Data Loss :6.330926893838296e-09,	 PDE Loss :2.1868284250103898e-07, 	 Total Loss :2.2501376406580675e-07
# it :02500, Data Loss :6.2953824375711065e-09,	 PDE Loss :2.1809343309087126e-07, 	 Total Loss :2.2438881330799632e-07
# it :02600, Data Loss :6.2441070092233986e-09,	 PDE Loss :2.1745900369296578e-07, 	 Total Loss :2.237031111462784e-07
# it :02700, Data Loss :6.2041403126045225e-09,	 PDE Loss :2.168261516999337e-07, 	 Total Loss :2.2303029822978715e-07
# it :02800, Data Loss :6.1817755359072635e-09,	 PDE Loss :2.163097718721474e-07, 	 Total Loss :2.2249155051667913e-07
# it :02900, Data Loss :6.135388641581585e-09,	 PDE Loss :2.1569097441442864e-07, 	 Total Loss :2.2182636882916995e-07
# it :03000, Data Loss :6.100468130654235e-09,	 PDE Loss :2.1510695091819798e-07, 	 Total Loss :2.2120741505204933e-07
# it :03100, Data Loss :6.048615386333722e-09,	 PDE Loss :2.1450789233767864e-07, 	 Total Loss :2.2055650106267422e-07
# it :03200, Data Loss :6.013215703148944e-09,	 PDE Loss :2.139102406317761e-07, 	 Total Loss :2.199234501176761e-07
# it :03300, Data Loss :5.995091534316543e-09,	 PDE Loss :2.1335068822736503e-07, 	 Total Loss :2.1934577887350315e-07
# it :03400, Data Loss :5.937140556966369e-09,	 PDE Loss :2.1273234551699716e-07, 	 Total Loss :2.1866948429760669e-07
# it :03500, Data Loss :3.756863264925414e-09,	 PDE Loss :1.9155710617724253e-07, 	 Total Loss :1.9531397299488162e-07
# it :03600, Data Loss :4.382669338554024e-09,	 PDE Loss :1.4411314452900115e-07, 	 Total Loss :1.484958147557336e-07
# it :03700, Data Loss :3.736364551087945e-09,	 PDE Loss :1.382257153181854e-07, 	 Total Loss :1.4196207587247045e-07
# it :03800, Data Loss :3.018378436081548e-09,	 PDE Loss :1.2768795443207637e-07, 	 Total Loss :1.3070632576273056e-07
# it :03900, Data Loss :2.9658577815894205e-09,	 PDE Loss :1.2684564865139691e-07, 	 Total Loss :1.2981151087387843e-07
# it :04000, Data Loss :2.9177043003869585e-09,	 PDE Loss :1.262435205262591e-07, 	 Total Loss :1.291612221621108e-07
# it :04100, Data Loss :2.8748621261343033e-09,	 PDE Loss :1.2575496555200516e-07, 	 Total Loss :1.2862982146089053e-07
# it :04200, Data Loss :2.8368525306632364e-09,	 PDE Loss :1.253350063734615e-07, 	 Total Loss :1.2817186245683843e-07
# it :04300, Data Loss :2.8011761799007218e-09,	 PDE Loss :1.2495056012085115e-07, 	 Total Loss :1.277517327480382e-07
# it :04400, Data Loss :2.765533135828946e-09,	 PDE Loss :1.2457553566491697e-07, 	 Total Loss :1.2734106746847829e-07
# it :04500, Data Loss :2.7285032011548083e-09,	 PDE Loss :1.2419428685461753e-07, 	 Total Loss :1.2692278517079103e-07
# it :04600, Data Loss :2.6929551921739403e-09,	 PDE Loss :1.238305173956178e-07, 	 Total Loss :1.2652347436414857e-07
# it :04700, Data Loss :2.658183673176495e-09,	 PDE Loss :1.2345094546617474e-07, 	 Total Loss :1.2610912847321742e-07
# it :04800, Data Loss :2.622772221627656e-09,	 PDE Loss :1.2302049867685128e-07, 	 Total Loss :1.2564326823394367e-07
# it :04900, Data Loss :2.586919123359621e-09,	 PDE Loss :1.2258931292308262e-07, 	 Total Loss :1.2517622849372856e-07
# it :05000, Data Loss :2.5591040397898723e-09,	 PDE Loss :1.2215286915306933e-07, 	 Total Loss :1.2471197408103762e-07
# it :05100, Data Loss :2.533920184788485e-09,	 PDE Loss :1.2173259733572195e-07, 	 Total Loss :1.242665206291349e-07
# it :05200, Data Loss :2.5134059278286713e-09,	 PDE Loss :1.2128130322253128e-07, 	 Total Loss :1.2379470604173548e-07
# it :05300, Data Loss :2.4932029774049624e-09,	 PDE Loss :1.2082415423719794e-07, 	 Total Loss :1.2331736343185185e-07
# it :05400, Data Loss :2.4789206243269746e-09,	 PDE Loss :1.203357840040553e-07, 	 Total Loss :1.2281471128972044e-07
# it :05500, Data Loss :2.4623547645319377e-09,	 PDE Loss :1.1983614456312353e-07, 	 Total Loss :1.2229850199219072e-07
# it :05600, Data Loss :2.4495894201947976e-09,	 PDE Loss :1.1938092825403146e-07, 	 Total Loss :1.218305243355644e-07
# it :05700, Data Loss :2.439325186287533e-09,	 PDE Loss :1.1894054097183471e-07, 	 Total Loss :1.2137986971083592e-07
# it :05800, Data Loss :2.429296319661489e-09,	 PDE Loss :1.1850798387058603e-07, 	 Total Loss :1.2093728685158567e-07
# it :05900, Data Loss :2.419099143224912e-09,	 PDE Loss :1.180901492148223e-07, 	 Total Loss :1.2050924169670907e-07
# it :06000, Data Loss :2.4114719110457372e-09,	 PDE Loss :1.176615356257571e-07, 	 Total Loss :1.200730110895165e-07
# it :06100, Data Loss :2.4010544663610744e-09,	 PDE Loss :1.171681986988915e-07, 	 Total Loss :1.1956925050071732e-07
# it :06200, Data Loss :2.3918425018365497e-09,	 PDE Loss :1.1672449318211875e-07, 	 Total Loss :1.1911633635008911e-07
# it :06300, Data Loss :2.387499531408821e-09,	 PDE Loss :1.1635117402875039e-07, 	 Total Loss :1.1873867578060526e-07
# it :06400, Data Loss :2.3790125425193764e-09,	 PDE Loss :1.159276195039638e-07, 	 Total Loss :1.1830663027012633e-07
# it :06500, Data Loss :2.3710424734701974e-09,	 PDE Loss :1.1545659361900107e-07, 	 Total Loss :1.1782763920109574e-07
# it :06600, Data Loss :2.3672666049634472e-09,	 PDE Loss :1.1505797914423965e-07, 	 Total Loss :1.1742524463898008e-07
# it :06700, Data Loss :2.3579360686198925e-09,	 PDE Loss :1.1456261006514978e-07, 	 Total Loss :1.1692054613376968e-07
# it :06800, Data Loss :2.34944286248151e-09,	 PDE Loss :1.1419530210332596e-07, 	 Total Loss :1.1654474718625352e-07
# it :06900, Data Loss :2.3472697119331087e-09,	 PDE Loss :1.1400387478488483e-07, 	 Total Loss :1.1635114560704096e-07
# it :07000, Data Loss :2.349170191706662e-09,	 PDE Loss :1.1374797281860083e-07, 	 Total Loss :1.1609714078986144e-07
# it :07100, Data Loss :2.3402719762088964e-09,	 PDE Loss :1.1348157613610965e-07, 	 Total Loss :1.1582184811231855e-07
# it :07200, Data Loss :2.3383486258410358e-09,	 PDE Loss :1.1329268545523519e-07, 	 Total Loss :1.1563103186063017e-07
# it :07300, Data Loss :2.335350801629943e-09,	 PDE Loss :1.1308968339562853e-07, 	 Total Loss :1.154250313106786e-07
# it :07400, Data Loss :2.3325412712438265e-09,	 PDE Loss :1.1289994006347115e-07, 	 Total Loss :1.1523248133471498e-07
# it :07500, Data Loss :2.3306636620645804e-09,	 PDE Loss :1.1270464028712013e-07, 	 Total Loss :1.1503530572554155e-07
# it :07600, Data Loss :2.3278512450986e-09,	 PDE Loss :1.1250275377960861e-07, 	 Total Loss :1.1483060546879642e-07
# it :07700, Data Loss :2.3256396808335467e-09,	 PDE Loss :1.123091948329602e-07, 	 Total Loss :1.146348367342398e-07
# it :07800, Data Loss :2.3242832103420596e-09,	 PDE Loss :1.1212518558068041e-07, 	 Total Loss :1.144494703453347e-07
# it :07900, Data Loss :2.321343561817457e-09,	 PDE Loss :1.1192337723286983e-07, 	 Total Loss :1.1424472035059807e-07
# it :08000, Data Loss :2.3173474250626214e-09,	 PDE Loss :1.1173889902238443e-07, 	 Total Loss :1.140562488899377e-07
# it :08100, Data Loss :2.001303123222442e-09,	 PDE Loss :1.2424985129655397e-07, 	 Total Loss :1.2625115175524115e-07

# %%
# 시각화
plt.figure(figsize=(10,3))
t_loss = np.log1p(net.total_loss_hist)
p_loss = np.log1p(net.pde_loss_hist)
d_loss = np.log1p(net.data_loss_hist)
epochs = range(1, 1+len(t_loss))
# xbins = range(0, len(t_loss)+1, 50)
# plt.plot(epochs[:100], t_loss[:100], lw=1,linestyle='-', label='Total Loss', c="k")
# plt.plot(epochs[:100], p_loss[:100], lw=1,linestyle='-', label='PDE Loss', c="r")
# plt.plot(epochs[:100], d_loss[:100], lw=1,linestyle='-', label='Data Loss', c="b")
plt.plot(epochs, t_loss, lw=1,linestyle='-', label='Total Loss', c="k")
plt.plot(epochs, p_loss, lw=1,linestyle='-', label='PDE Loss', c="r")
plt.plot(epochs, d_loss, lw=1,linestyle='-', label='Data Loss', c="b")
plt.legend()
plt.grid(True)
# plt.xticks(xbins)
plt.xlabel('per 100 Epochs')
plt.ylabel('Log Loss')
# x, y = epochs[-1], loss[-1]
# plt.text(x, y, y)
plt.show()

# %%
# 데이터 불러오기
# 데이터에 대해서는 ./make_dataset.ipynb 에서 확인
with open(f'./data/data_1_1_3.npy', 'rb') as f:
    data = np.load(f,allow_pickle=True)
x = data.T[0]
y = data.T[1]
X = data[:,:2]
f_true = data.T[2]


X = torch.tensor(X, dtype=torch.float)
X = X.to(net.X.device)

model = net.model
model.eval()
with torch.no_grad():
    f_pred = model(X).cpu().numpy().squeeze()

print("Test MSE Loss : ", np.mean(np.sqrt(np.square(f_true)-np.square(f_pred))))

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(7,3))
# grid
xi, yi = np.mgrid[x.min():x.max():500j, y.min():y.max():500j]

# f_true figure
rbf = scipy.interpolate.Rbf(x, y, f_true)
org = rbf(xi, yi)
img = ax[0].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[0].scatter(x, y, c=f_true)
ax[0].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

# f_pred figure
rbf = scipy.interpolate.Rbf(x, y, f_pred)
org = rbf(xi, yi)
img = ax[1].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[1].scatter(x, y, c=f_pred)
ax[1].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

plt.tight_layout()
# Out:
# Test MSE Loss :  0.405322571492285

# %%
# model_1_3_1 save
torch.save(model.state_dict(), "./data/model_1_1_3.pt")
