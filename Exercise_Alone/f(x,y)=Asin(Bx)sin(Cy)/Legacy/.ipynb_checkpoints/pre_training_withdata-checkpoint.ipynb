# %%
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import OrderedDict
from tqdm import tqdm
import scipy
import pyDOE

import torch
import torch.nn as nn

# %%
# Multi-layer Perceptron
class NN(nn.Module):
    def __init__(
        self,
        input_size,  
        hidden_size, 
        output_size, 
        depth,
        act=torch.nn.Tanh,
    ):
        super(NN, self).__init__()
        
        layers = [('input', torch.nn.Linear(input_size, hidden_size))]
        layers.append(('input_activation', act()))
        for i in range(depth): 
            layers.append(
                (f'hidden_{i}', torch.nn.Linear(hidden_size, hidden_size))
            )
            layers.append((f'activation_{i}', act()))
        layers.append(('output', torch.nn.Linear(hidden_size, output_size)))

        layerDict = OrderedDict(layers)
        self.layers = torch.nn.Sequential(layerDict)

    def forward(self, x):
        out = self.layers(x)
        return out

# %%
class Net:
    def __init__(self, A=1.0, B=1.0, C=1.0):
        device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

        self.model = NN(
            input_size=2,
            hidden_size=100,
            output_size=1,
            depth=8,
            act=torch.nn.Tanh
        ).to(device)
        
        # 간격
        self.h = 0.1
        self.k = 0.1
        # (x,y) 좌표점
        x = torch.arange(-np.pi, np.pi + self.h, self.h)
        y = torch.arange(-np.pi, np.pi + self.k, self.k)
        self.X = torch.stack(torch.meshgrid(x, y)).reshape(2, -1).T
        
        # u = f(x,y)=A*sin(B*x)*sin(C*y)
        self.A = torch.tensor([A,])
        self.B = torch.tensor([B,])
        self.C = torch.tensor([C,])
        
        # Boundary Conditions
        # 경계점은 mesh grid로 Data points를 생성
        bc1 = torch.stack(torch.meshgrid(x[0], y)).reshape(2, -1).T 
        bc2 = torch.stack(torch.meshgrid(x[-1], y)).reshape(2, -1).T
        self.X_train = torch.cat([bc1, bc2]) # X_train : Data BCs
        
        f_bc1 = torch.zeros(len(bc1))
        f_bc2 = torch.zeros(len(bc2))
        self.f_train = torch.cat([f_bc1, f_bc2]) # f_train : PDE BCs
        self.f_train = self.f_train.unsqueeze(1)
        
        # Domain Data points는 Latin Hypercube Sampling을 통해 생성
        sample_data = pyDOE.lhs(2, samples=3000)
        sample_data -= 0.5
        sample_data *= 2 * np.pi
        x = torch.tensor(sample_data.T[0], dtype=torch.float)
        y = torch.tensor(sample_data.T[1], dtype=torch.float)
        self.X = torch.cat([x, y]).reshape(2,-1).T
        self.f_true = self.func(x,y)
        
        self.X = self.X.to(device)
        self.X_train = self.X_train.to(device)
        self.f_train = self.f_train.to(device)
        self.f_true = self.f_true.to(device)
        self.X.requires_grad = True
        
        
        self.criterion = torch.nn.MSELoss()
        self.iter = 1
        
        self.optimizer = torch.optim.LBFGS(
            self.model.parameters(), 
            lr=1.0, 
            max_iter=50000, 
            max_eval=50000, 
            history_size=5,
            tolerance_grad=1e-13, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe",
        )
        self.adam = torch.optim.Adam(self.model.parameters(), lr=0.1)
        self.Domain_loss_hist = []
        self.BC_loss_hist = []
        self.pde_loss_hist = []
        self.total_loss_hist = []
        self.print_model_state()
        
        self.A = self.A.to(device)
        self.B = self.B.to(device)
        self.C = self.C.to(device)
        
    # this won't use
    def func(self, x,y):
        return self.A*torch.sin(self.B*x)*torch.sin(self.C*y)
    
    def print_model_state(self):
        print("Model's state_dict:")
        for param_tensor in self.model.state_dict():
            print(param_tensor, "\t", self.model.state_dict()[param_tensor].size())
            
    def loss_func(self):
        
        # 초기화
        self.adam.zero_grad()
        self.optimizer.zero_grad()
        
        # Boundary Conditions
        f_pred = self.model(self.X_train)
        loss_BC = self.criterion(f_pred, self.f_train)
        u = self.model(self.X)
        loss_Domain = self.criterion(u.squeeze(), self.f_true)
        
        du_dX = torch.autograd.grad(
            inputs=self.X, 
            outputs=u, 
            grad_outputs=torch.ones_like(u), 
            retain_graph=True, 
            create_graph=True
        )[0]
        
        du_dx = du_dX[:, 0]
        du_dy = du_dX[:, 1]
        du_dXX = torch.autograd.grad(
            inputs=self.X, 
            outputs=du_dX, 
            grad_outputs=torch.ones_like(du_dX), 
            retain_graph=True, 
            create_graph=True
        )[0]
        
        du_dxx = du_dXX[:,0]
        du_dyy = du_dXX[:,1]
        
        # u = f(x,y)=A*sin(B*x)*sin(C*y)
        # fxx + fyy + A*(B^2+C^2)*f = 0
        loss_pde = self.criterion( du_dxx + du_dyy , -self.A*(self.B*self.B+self.C*self.C)*u.squeeze() )

        loss = loss_pde + loss_BC + loss_Domain
        loss.backward()
        if self.iter % 100 == 0:

            print(f"it :{self.iter:04d}, BC Loss :{loss_BC.item():.4e},\t Domain Loss:{loss_Domain.item():.4e},\t PDE Loss :{loss_pde.item():.4e},\t Total Loss :{loss.item()}")
            self.total_loss_hist.append(loss.item())
            self.pde_loss_hist.append(loss_pde.item())
            self.BC_loss_hist.append(loss_BC.item())
            self.Domain_loss_hist.append(loss_Domain.item())
        self.iter = self.iter + 1
        return loss
    
    def train(self):
        self.model.train()
        print("train with Adam optimizer")
        for i in range(5000):
            self.adam.step(self.loss_func)
        print("train with L-BFGs")
        self.optimizer.step(self.loss_func)
        
    def eval_(self):
        self.model.eval()

# %%
net = Net()
# Out:
# Model's state_dict:
# layers.input.weight 	 torch.Size([100, 2])
# layers.input.bias 	 torch.Size([100])
# layers.hidden_0.weight 	 torch.Size([100, 100])
# layers.hidden_0.bias 	 torch.Size([100])
# layers.hidden_1.weight 	 torch.Size([100, 100])
# layers.hidden_1.bias 	 torch.Size([100])
# layers.hidden_2.weight 	 torch.Size([100, 100])
# layers.hidden_2.bias 	 torch.Size([100])
# layers.hidden_3.weight 	 torch.Size([100, 100])
# layers.hidden_3.bias 	 torch.Size([100])
# layers.hidden_4.weight 	 torch.Size([100, 100])
# layers.hidden_4.bias 	 torch.Size([100])
# layers.hidden_5.weight 	 torch.Size([100, 100])
# layers.hidden_5.bias 	 torch.Size([100])
# layers.hidden_6.weight 	 torch.Size([100, 100])
# layers.hidden_6.bias 	 torch.Size([100])
# layers.hidden_7.weight 	 torch.Size([100, 100])
# layers.hidden_7.bias 	 torch.Size([100])
# layers.output.weight 	 torch.Size([1, 100])
# layers.output.bias 	 torch.Size([1])
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
net.train()
# Out:
# train with Adam optimizer
# it :0100, BC Loss :2.3393e-05,	 Domain Loss:2.4496e-01,	 PDE Loss :5.8086e-05,	 Total Loss :0.24503932893276215
# it :0200, BC Loss :3.5207e-04,	 Domain Loss:2.3294e-01,	 PDE Loss :7.6645e-04,	 Total Loss :0.23406003415584564
# it :0300, BC Loss :6.3071e-03,	 Domain Loss:1.8914e-01,	 PDE Loss :1.2499e-02,	 Total Loss :0.20794375240802765
# it :0400, BC Loss :1.0951e-02,	 Domain Loss:1.6875e-01,	 PDE Loss :2.0757e-02,	 Total Loss :0.20046263933181763
# it :0500, BC Loss :1.1353e-02,	 Domain Loss:1.6274e-01,	 PDE Loss :2.2433e-02,	 Total Loss :0.1965218186378479
# it :0600, BC Loss :1.1020e-02,	 Domain Loss:1.5739e-01,	 PDE Loss :2.4064e-02,	 Total Loss :0.19247078895568848
# it :0700, BC Loss :1.0220e-02,	 Domain Loss:1.5083e-01,	 PDE Loss :2.5985e-02,	 Total Loss :0.18704047799110413
# it :0800, BC Loss :8.9341e-03,	 Domain Loss:1.4109e-01,	 PDE Loss :2.8466e-02,	 Total Loss :0.1784852296113968
# it :0900, BC Loss :7.7377e-03,	 Domain Loss:1.2440e-01,	 PDE Loss :3.1489e-02,	 Total Loss :0.16362518072128296
# it :1000, BC Loss :1.0458e-02,	 Domain Loss:1.0194e-01,	 PDE Loss :3.4480e-02,	 Total Loss :0.14687471091747284
# it :1100, BC Loss :1.3064e-02,	 Domain Loss:9.2726e-02,	 PDE Loss :3.5235e-02,	 Total Loss :0.14102530479431152
# it :1200, BC Loss :1.3606e-02,	 Domain Loss:8.9519e-02,	 PDE Loss :3.5000e-02,	 Total Loss :0.13812589645385742
# it :1300, BC Loss :1.3841e-02,	 Domain Loss:8.7242e-02,	 PDE Loss :3.4820e-02,	 Total Loss :0.13590312004089355
# it :1400, BC Loss :1.3926e-02,	 Domain Loss:8.5511e-02,	 PDE Loss :3.4618e-02,	 Total Loss :0.13405469059944153
# it :1500, BC Loss :1.4072e-02,	 Domain Loss:8.3839e-02,	 PDE Loss :3.4461e-02,	 Total Loss :0.13237246870994568
# it :1600, BC Loss :1.4133e-02,	 Domain Loss:8.2367e-02,	 PDE Loss :3.4290e-02,	 Total Loss :0.13079020380973816
# it :1700, BC Loss :1.4235e-02,	 Domain Loss:8.0890e-02,	 PDE Loss :3.4167e-02,	 Total Loss :0.12929272651672363
# it :1800, BC Loss :1.4262e-02,	 Domain Loss:7.9511e-02,	 PDE Loss :3.4040e-02,	 Total Loss :0.12781277298927307
# it :1900, BC Loss :1.4226e-02,	 Domain Loss:7.8187e-02,	 PDE Loss :3.3939e-02,	 Total Loss :0.12635169923305511
# it :2000, BC Loss :1.4270e-02,	 Domain Loss:7.6750e-02,	 PDE Loss :3.3875e-02,	 Total Loss :0.12489618360996246
# it :2100, BC Loss :1.4118e-02,	 Domain Loss:7.5548e-02,	 PDE Loss :3.3789e-02,	 Total Loss :0.12345518171787262
# it :2200, BC Loss :1.3875e-02,	 Domain Loss:7.4486e-02,	 PDE Loss :3.3708e-02,	 Total Loss :0.12206877022981644
# it :2300, BC Loss :1.3739e-02,	 Domain Loss:7.3409e-02,	 PDE Loss :3.3629e-02,	 Total Loss :0.12077667564153671
# it :2400, BC Loss :1.3532e-02,	 Domain Loss:7.2530e-02,	 PDE Loss :3.3544e-02,	 Total Loss :0.11960601806640625
# it :2500, BC Loss :1.3293e-02,	 Domain Loss:7.1838e-02,	 PDE Loss :3.3431e-02,	 Total Loss :0.11856147646903992
# it :2600, BC Loss :1.2989e-02,	 Domain Loss:7.1364e-02,	 PDE Loss :3.3333e-02,	 Total Loss :0.11768630892038345
# it :2700, BC Loss :1.2869e-02,	 Domain Loss:7.0884e-02,	 PDE Loss :3.3229e-02,	 Total Loss :0.11698143929243088
# it :2800, BC Loss :1.2604e-02,	 Domain Loss:7.0707e-02,	 PDE Loss :3.3078e-02,	 Total Loss :0.1163894385099411
# it :2900, BC Loss :1.2508e-02,	 Domain Loss:7.0436e-02,	 PDE Loss :3.2954e-02,	 Total Loss :0.11589835584163666
# it :3000, BC Loss :1.2299e-02,	 Domain Loss:7.0374e-02,	 PDE Loss :3.2824e-02,	 Total Loss :0.11549712717533112
# it :3100, BC Loss :1.2285e-02,	 Domain Loss:7.0187e-02,	 PDE Loss :3.2689e-02,	 Total Loss :0.11516036093235016
# it :3200, BC Loss :1.2144e-02,	 Domain Loss:7.0150e-02,	 PDE Loss :3.2582e-02,	 Total Loss :0.11487556993961334
# it :3300, BC Loss :1.2048e-02,	 Domain Loss:7.0114e-02,	 PDE Loss :3.2467e-02,	 Total Loss :0.11462957412004471
# it :3400, BC Loss :1.2003e-02,	 Domain Loss:7.0051e-02,	 PDE Loss :3.2361e-02,	 Total Loss :0.11441440880298615
# it :3500, BC Loss :1.1908e-02,	 Domain Loss:7.0058e-02,	 PDE Loss :3.2259e-02,	 Total Loss :0.11422526836395264
# it :3600, BC Loss :1.1525e-02,	 Domain Loss:7.0403e-02,	 PDE Loss :3.2190e-02,	 Total Loss :0.11411747336387634
# it :3700, BC Loss :1.1841e-02,	 Domain Loss:6.9999e-02,	 PDE Loss :3.2057e-02,	 Total Loss :0.11389689147472382
# it :3800, BC Loss :1.1823e-02,	 Domain Loss:6.9965e-02,	 PDE Loss :3.1993e-02,	 Total Loss :0.1137804314494133
# it :3900, BC Loss :1.1716e-02,	 Domain Loss:6.9994e-02,	 PDE Loss :3.1903e-02,	 Total Loss :0.11361268162727356
# it :4000, BC Loss :1.1686e-02,	 Domain Loss:6.9980e-02,	 PDE Loss :3.1823e-02,	 Total Loss :0.11348914355039597
# it :4100, BC Loss :1.1646e-02,	 Domain Loss:6.9973e-02,	 PDE Loss :3.1752e-02,	 Total Loss :0.11337101459503174
# it :4200, BC Loss :1.1589e-02,	 Domain Loss:6.9992e-02,	 PDE Loss :3.1680e-02,	 Total Loss :0.11326095461845398
# it :4300, BC Loss :1.1685e-02,	 Domain Loss:6.9862e-02,	 PDE Loss :3.1615e-02,	 Total Loss :0.1131625548005104
# it :4400, BC Loss :1.1472e-02,	 Domain Loss:7.0063e-02,	 PDE Loss :3.1525e-02,	 Total Loss :0.11306092143058777
# it :4500, BC Loss :1.1499e-02,	 Domain Loss:6.9972e-02,	 PDE Loss :3.1490e-02,	 Total Loss :0.11296066641807556
# it :4600, BC Loss :1.1852e-02,	 Domain Loss:6.9578e-02,	 PDE Loss :3.1516e-02,	 Total Loss :0.11294558644294739
# it :4700, BC Loss :1.1451e-02,	 Domain Loss:6.9968e-02,	 PDE Loss :3.1366e-02,	 Total Loss :0.11278410255908966
# it :4800, BC Loss :1.1490e-02,	 Domain Loss:6.9914e-02,	 PDE Loss :3.1314e-02,	 Total Loss :0.11271871626377106
# it :4900, BC Loss :1.1487e-02,	 Domain Loss:6.9857e-02,	 PDE Loss :3.1283e-02,	 Total Loss :0.11262684315443039
# it :5000, BC Loss :1.1333e-02,	 Domain Loss:6.9983e-02,	 PDE Loss :3.1225e-02,	 Total Loss :0.11254164576530457
# train with L-BFGs
# it :5100, BC Loss :1.0768e-02,	 Domain Loss:7.2112e-02,	 PDE Loss :2.8475e-02,	 Total Loss :0.11135537922382355
# it :5200, BC Loss :1.0362e-02,	 Domain Loss:7.0794e-02,	 PDE Loss :2.9468e-02,	 Total Loss :0.11062360554933548
# it :5300, BC Loss :1.0512e-02,	 Domain Loss:6.9647e-02,	 PDE Loss :2.9905e-02,	 Total Loss :0.11006420105695724
# it :5400, BC Loss :9.0553e-03,	 Domain Loss:7.1071e-02,	 PDE Loss :2.9149e-02,	 Total Loss :0.10927577316761017
# it :5500, BC Loss :9.0174e-03,	 Domain Loss:7.0541e-02,	 PDE Loss :2.9057e-02,	 Total Loss :0.108614981174469
# it :5600, BC Loss :8.9217e-03,	 Domain Loss:6.9997e-02,	 PDE Loss :2.9175e-02,	 Total Loss :0.10809406638145447
# it :5700, BC Loss :8.7855e-03,	 Domain Loss:7.0179e-02,	 PDE Loss :2.8977e-02,	 Total Loss :0.1079414039850235
# it :5800, BC Loss :9.0738e-03,	 Domain Loss:7.0019e-02,	 PDE Loss :2.8554e-02,	 Total Loss :0.10764701664447784
# it :5900, BC Loss :8.8669e-03,	 Domain Loss:6.9794e-02,	 PDE Loss :2.8883e-02,	 Total Loss :0.10754403471946716
# it :6000, BC Loss :8.9149e-03,	 Domain Loss:6.9982e-02,	 PDE Loss :2.8550e-02,	 Total Loss :0.10744644701480865
# it :6100, BC Loss :8.8950e-03,	 Domain Loss:6.9989e-02,	 PDE Loss :2.8495e-02,	 Total Loss :0.10737936943769455
# it :6200, BC Loss :8.8656e-03,	 Domain Loss:6.9573e-02,	 PDE Loss :2.8834e-02,	 Total Loss :0.10727208107709885
# it :6300, BC Loss :8.8747e-03,	 Domain Loss:6.9674e-02,	 PDE Loss :2.8636e-02,	 Total Loss :0.10718482732772827
# it :6400, BC Loss :9.1035e-03,	 Domain Loss:6.9662e-02,	 PDE Loss :2.8288e-02,	 Total Loss :0.10705354064702988
# it :6500, BC Loss :8.5900e-03,	 Domain Loss:6.9849e-02,	 PDE Loss :2.8416e-02,	 Total Loss :0.1068548783659935
# it :6600, BC Loss :9.0964e-03,	 Domain Loss:6.8240e-02,	 PDE Loss :2.8903e-02,	 Total Loss :0.10624025762081146
# it :6700, BC Loss :8.9172e-03,	 Domain Loss:6.8364e-02,	 PDE Loss :2.8748e-02,	 Total Loss :0.10602913796901703
# it :6800, BC Loss :8.8660e-03,	 Domain Loss:6.8300e-02,	 PDE Loss :2.8803e-02,	 Total Loss :0.10596903413534164
# it :6900, BC Loss :8.7998e-03,	 Domain Loss:6.8448e-02,	 PDE Loss :2.8611e-02,	 Total Loss :0.1058591902256012
# it :7000, BC Loss :8.6334e-03,	 Domain Loss:6.8434e-02,	 PDE Loss :2.8694e-02,	 Total Loss :0.10576146841049194
# it :7100, BC Loss :8.3805e-03,	 Domain Loss:6.8363e-02,	 PDE Loss :2.8907e-02,	 Total Loss :0.10565056651830673
# it :7200, BC Loss :8.3976e-03,	 Domain Loss:6.8506e-02,	 PDE Loss :2.8690e-02,	 Total Loss :0.10559308528900146
# it :7300, BC Loss :8.4188e-03,	 Domain Loss:6.8613e-02,	 PDE Loss :2.8505e-02,	 Total Loss :0.10553719103336334
# it :7400, BC Loss :8.4285e-03,	 Domain Loss:6.8341e-02,	 PDE Loss :2.8637e-02,	 Total Loss :0.10540737956762314
# it :7500, BC Loss :8.4217e-03,	 Domain Loss:6.8850e-02,	 PDE Loss :2.7991e-02,	 Total Loss :0.10526202619075775
# it :7600, BC Loss :8.4508e-03,	 Domain Loss:6.8394e-02,	 PDE Loss :2.8258e-02,	 Total Loss :0.10510249435901642
# it :7700, BC Loss :8.3165e-03,	 Domain Loss:6.8442e-02,	 PDE Loss :2.8301e-02,	 Total Loss :0.10505923628807068
# it :7800, BC Loss :8.3906e-03,	 Domain Loss:6.8289e-02,	 PDE Loss :2.8338e-02,	 Total Loss :0.10501819849014282

# %%
plt.figure(figsize=(10,3))
t_loss = np.log1p(net.total_loss_hist)
p_loss = np.log1p(net.pde_loss_hist)
b_loss = np.log1p(net.BC_loss_hist)
d_loss = np.log1p(net.Domain_loss_hist)
epochs = range(1, 1+len(t_loss))
xbins = range(0, len(t_loss)+1, 50)
plt.plot(epochs, t_loss, lw=1,linestyle='-', label='Total Loss', c="k")
plt.plot(epochs, p_loss, lw=1,linestyle='-', label='PDE Loss', c="r")
plt.plot(epochs, d_loss, lw=1,linestyle='-', label='BC Loss', c="b")
plt.plot(epochs, b_loss, lw=1,linestyle='-', label='Domain Loss', c="g")
plt.legend()
plt.grid(True)
# plt.xticks(xbins)
plt.xlabel('per 100 Epochs')
plt.ylabel('Log Loss')
# x, y = epochs[-1], loss[-1]
# plt.text(x, y, y)
plt.show()

# %%
# 데이터 불러오기
# 데이터에 대해서는 ./make_dataset.ipynb 에서 확인
with open(f'./data/data_1_1_1.npy', 'rb') as f:
    data = np.load(f,allow_pickle=True)
x = data.T[0]
y = data.T[1]
X = data[:,:2]
f_true = data.T[2]


X = torch.tensor(X, dtype=torch.float)
X = X.to(net.X.device)

model = net.model
model.eval()
with torch.no_grad():
    f_pred = model(X).cpu().numpy().squeeze()

print("Test MSE Loss : ", np.mean(np.sqrt(np.abs(np.square(f_true.reshape(-1))-np.square(f_pred.reshape(-1))))))

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(7,3))
# grid
xi, yi = np.mgrid[x.min():x.max():500j, y.min():y.max():500j]

# f_true figure
rbf = scipy.interpolate.Rbf(x, y, f_true)
org = rbf(xi, yi)
img = ax[0].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[0].scatter(x, y, c=f_true)
ax[0].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

# f_pred figure
rbf = scipy.interpolate.Rbf(x, y, f_pred)
org = rbf(xi, yi)
img = ax[1].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[1].scatter(x, y, c=f_pred)
ax[1].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

plt.tight_layout()
# Out:
# Test MSE Loss :  0.3444198392811673

# %%
# model_1_1_1 save
torch.save(model.state_dict(), "./data/model_withdata_1_1_1.pt")

# %%
net = Net(A=3)
net.train()
# Out:
# Model's state_dict:
# layers.input.weight 	 torch.Size([100, 2])
# layers.input.bias 	 torch.Size([100])
# layers.hidden_0.weight 	 torch.Size([100, 100])
# layers.hidden_0.bias 	 torch.Size([100])
# layers.hidden_1.weight 	 torch.Size([100, 100])
# layers.hidden_1.bias 	 torch.Size([100])
# layers.hidden_2.weight 	 torch.Size([100, 100])
# layers.hidden_2.bias 	 torch.Size([100])
# layers.hidden_3.weight 	 torch.Size([100, 100])
# layers.hidden_3.bias 	 torch.Size([100])
# layers.hidden_4.weight 	 torch.Size([100, 100])
# layers.hidden_4.bias 	 torch.Size([100])
# layers.hidden_5.weight 	 torch.Size([100, 100])
# layers.hidden_5.bias 	 torch.Size([100])
# layers.hidden_6.weight 	 torch.Size([100, 100])
# layers.hidden_6.bias 	 torch.Size([100])
# layers.hidden_7.weight 	 torch.Size([100, 100])
# layers.hidden_7.bias 	 torch.Size([100])
# layers.output.weight 	 torch.Size([1, 100])
# layers.output.bias 	 torch.Size([1])
# train with Adam optimizer
# it :0100, BC Loss :8.6174e-04,	 Domain Loss:2.2755e+00,	 PDE Loss :2.7630e-02,	 Total Loss :2.303955316543579
# it :0200, BC Loss :3.3385e-05,	 Domain Loss:2.2716e+00,	 PDE Loss :5.9196e-04,	 Total Loss :2.27221941947937
# it :0300, BC Loss :5.9101e-05,	 Domain Loss:2.2637e+00,	 PDE Loss :1.1168e-03,	 Total Loss :2.264849901199341
# it :0400, BC Loss :1.9706e-04,	 Domain Loss:2.2491e+00,	 PDE Loss :3.7178e-03,	 Total Loss :2.2530229091644287
# it :0500, BC Loss :7.0473e-04,	 Domain Loss:2.2211e+00,	 PDE Loss :1.3265e-02,	 Total Loss :2.235022783279419
# it :0600, BC Loss :1.9421e-03,	 Domain Loss:2.1813e+00,	 PDE Loss :3.6855e-02,	 Total Loss :2.220092535018921
# it :0700, BC Loss :2.7875e-03,	 Domain Loss:2.1596e+00,	 PDE Loss :5.3243e-02,	 Total Loss :2.2156014442443848
# it :0800, BC Loss :2.9779e-03,	 Domain Loss:2.1526e+00,	 PDE Loss :5.6986e-02,	 Total Loss :2.212596893310547
# it :0900, BC Loss :3.0941e-03,	 Domain Loss:2.1468e+00,	 PDE Loss :5.9246e-02,	 Total Loss :2.2091803550720215
# it :1000, BC Loss :3.2179e-03,	 Domain Loss:2.1402e+00,	 PDE Loss :6.1599e-02,	 Total Loss :2.2049922943115234
# it :1100, BC Loss :3.3599e-03,	 Domain Loss:2.1320e+00,	 PDE Loss :6.4175e-02,	 Total Loss :2.1994869709014893
# it :1200, BC Loss :3.5394e-03,	 Domain Loss:2.1210e+00,	 PDE Loss :6.7016e-02,	 Total Loss :2.191540241241455
# it :1300, BC Loss :3.8478e-03,	 Domain Loss:2.1044e+00,	 PDE Loss :7.0447e-02,	 Total Loss :2.1786630153656006
# it :1400, BC Loss :4.7079e-03,	 Domain Loss:2.0741e+00,	 PDE Loss :7.7457e-02,	 Total Loss :2.1563069820404053
# it :1500, BC Loss :7.0217e-03,	 Domain Loss:2.0186e+00,	 PDE Loss :9.7046e-02,	 Total Loss :2.1226646900177
# it :1600, BC Loss :1.1156e-02,	 Domain Loss:1.9529e+00,	 PDE Loss :1.3016e-01,	 Total Loss :2.0942203998565674
# it :1700, BC Loss :1.4878e-02,	 Domain Loss:1.9173e+00,	 PDE Loss :1.4799e-01,	 Total Loss :2.080186605453491
# it :1800, BC Loss :1.7487e-02,	 Domain Loss:1.8992e+00,	 PDE Loss :1.5397e-01,	 Total Loss :2.070650339126587
# it :1900, BC Loss :1.9667e-02,	 Domain Loss:1.8858e+00,	 PDE Loss :1.5733e-01,	 Total Loss :2.0627989768981934
# it :2000, BC Loss :2.1646e-02,	 Domain Loss:1.8744e+00,	 PDE Loss :1.5967e-01,	 Total Loss :2.055722713470459
# it :2100, BC Loss :2.3511e-02,	 Domain Loss:1.8641e+00,	 PDE Loss :1.6158e-01,	 Total Loss :2.0491464138031006
# it :2200, BC Loss :2.5301e-02,	 Domain Loss:1.8544e+00,	 PDE Loss :1.6302e-01,	 Total Loss :2.042738676071167
# it :2300, BC Loss :2.7101e-02,	 Domain Loss:1.8452e+00,	 PDE Loss :1.6421e-01,	 Total Loss :2.0364701747894287
# it :2400, BC Loss :2.8918e-02,	 Domain Loss:1.8361e+00,	 PDE Loss :1.6517e-01,	 Total Loss :2.030198335647583
# it :2500, BC Loss :3.0764e-02,	 Domain Loss:1.8272e+00,	 PDE Loss :1.6604e-01,	 Total Loss :2.024035692214966
# it :2600, BC Loss :3.2693e-02,	 Domain Loss:1.8184e+00,	 PDE Loss :1.6690e-01,	 Total Loss :2.018033981323242
# it :2700, BC Loss :3.4592e-02,	 Domain Loss:1.8101e+00,	 PDE Loss :1.6745e-01,	 Total Loss :2.012099266052246
# it :2800, BC Loss :3.6526e-02,	 Domain Loss:1.8018e+00,	 PDE Loss :1.6786e-01,	 Total Loss :2.0061826705932617
# it :2900, BC Loss :3.8499e-02,	 Domain Loss:1.7937e+00,	 PDE Loss :1.6831e-01,	 Total Loss :2.000544309616089
# it :3000, BC Loss :4.0378e-02,	 Domain Loss:1.7862e+00,	 PDE Loss :1.6852e-01,	 Total Loss :1.9951391220092773
# it :3100, BC Loss :4.2209e-02,	 Domain Loss:1.7792e+00,	 PDE Loss :1.6882e-01,	 Total Loss :1.9902076721191406
# it :3200, BC Loss :4.3921e-02,	 Domain Loss:1.7730e+00,	 PDE Loss :1.6896e-01,	 Total Loss :1.985902190208435
# it :3300, BC Loss :4.5457e-02,	 Domain Loss:1.7676e+00,	 PDE Loss :1.6907e-01,	 Total Loss :1.9821443557739258
# it :3400, BC Loss :4.6808e-02,	 Domain Loss:1.7628e+00,	 PDE Loss :1.6924e-01,	 Total Loss :1.9788154363632202
# it :3500, BC Loss :4.7920e-02,	 Domain Loss:1.7589e+00,	 PDE Loss :1.6930e-01,	 Total Loss :1.9760990142822266
# it :3600, BC Loss :4.9067e-02,	 Domain Loss:1.7553e+00,	 PDE Loss :1.6983e-01,	 Total Loss :1.9741731882095337
# it :3700, BC Loss :4.9821e-02,	 Domain Loss:1.7525e+00,	 PDE Loss :1.6953e-01,	 Total Loss :1.9718964099884033
# it :3800, BC Loss :5.0557e-02,	 Domain Loss:1.7500e+00,	 PDE Loss :1.6966e-01,	 Total Loss :1.9702571630477905
# it :3900, BC Loss :5.1172e-02,	 Domain Loss:1.7479e+00,	 PDE Loss :1.6967e-01,	 Total Loss :1.9687093496322632
# it :4000, BC Loss :5.1705e-02,	 Domain Loss:1.7459e+00,	 PDE Loss :1.6967e-01,	 Total Loss :1.96731436252594
# it :4100, BC Loss :5.2231e-02,	 Domain Loss:1.7441e+00,	 PDE Loss :1.6969e-01,	 Total Loss :1.9659855365753174
# it :4200, BC Loss :5.2688e-02,	 Domain Loss:1.7424e+00,	 PDE Loss :1.6964e-01,	 Total Loss :1.9647154808044434
# it :4300, BC Loss :5.3129e-02,	 Domain Loss:1.7407e+00,	 PDE Loss :1.6962e-01,	 Total Loss :1.9634736776351929
# it :4400, BC Loss :5.3532e-02,	 Domain Loss:1.7392e+00,	 PDE Loss :1.6954e-01,	 Total Loss :1.9622324705123901
# it :4500, BC Loss :5.3955e-02,	 Domain Loss:1.7376e+00,	 PDE Loss :1.6948e-01,	 Total Loss :1.960994839668274
# it :4600, BC Loss :5.4351e-02,	 Domain Loss:1.7360e+00,	 PDE Loss :1.6939e-01,	 Total Loss :1.9597837924957275
# it :4700, BC Loss :5.4760e-02,	 Domain Loss:1.7345e+00,	 PDE Loss :1.6924e-01,	 Total Loss :1.9585472345352173
# it :4800, BC Loss :5.5159e-02,	 Domain Loss:1.7330e+00,	 PDE Loss :1.6915e-01,	 Total Loss :1.9573248624801636
# it :4900, BC Loss :5.5564e-02,	 Domain Loss:1.7315e+00,	 PDE Loss :1.6907e-01,	 Total Loss :1.9561245441436768
# it :5000, BC Loss :5.5925e-02,	 Domain Loss:1.7301e+00,	 PDE Loss :1.6892e-01,	 Total Loss :1.954925775527954
# train with L-BFGs
# it :5100, BC Loss :5.7532e-02,	 Domain Loss:1.7074e+00,	 PDE Loss :1.7007e-01,	 Total Loss :1.9349853992462158
# it :5200, BC Loss :5.2348e-02,	 Domain Loss:1.7341e+00,	 PDE Loss :1.3525e-01,	 Total Loss :1.9217300415039062
# it :5300, BC Loss :7.1511e-02,	 Domain Loss:1.6757e+00,	 PDE Loss :1.5921e-01,	 Total Loss :1.90646231174469
# it :5400, BC Loss :7.0933e-02,	 Domain Loss:1.6828e+00,	 PDE Loss :1.4413e-01,	 Total Loss :1.8978461027145386
# it :5500, BC Loss :7.5594e-02,	 Domain Loss:1.6768e+00,	 PDE Loss :1.4064e-01,	 Total Loss :1.8930720090866089
# it :5600, BC Loss :7.9518e-02,	 Domain Loss:1.6629e+00,	 PDE Loss :1.4767e-01,	 Total Loss :1.8900673389434814
# it :5700, BC Loss :8.1181e-02,	 Domain Loss:1.6729e+00,	 PDE Loss :1.3349e-01,	 Total Loss :1.8875490427017212
# it :5800, BC Loss :8.0524e-02,	 Domain Loss:1.6606e+00,	 PDE Loss :1.4384e-01,	 Total Loss :1.8849482536315918
# it :5900, BC Loss :7.8104e-02,	 Domain Loss:1.6724e+00,	 PDE Loss :1.3207e-01,	 Total Loss :1.8826053142547607
# it :6000, BC Loss :7.8845e-02,	 Domain Loss:1.6694e+00,	 PDE Loss :1.3275e-01,	 Total Loss :1.881038784980774
# it :6100, BC Loss :8.5127e-02,	 Domain Loss:1.6563e+00,	 PDE Loss :1.3852e-01,	 Total Loss :1.87996244430542
# it :6200, BC Loss :8.1900e-02,	 Domain Loss:1.6636e+00,	 PDE Loss :1.3403e-01,	 Total Loss :1.879486322402954
# it :6300, BC Loss :8.2784e-02,	 Domain Loss:1.6616e+00,	 PDE Loss :1.3451e-01,	 Total Loss :1.8788611888885498
# it :6400, BC Loss :8.0213e-02,	 Domain Loss:1.6656e+00,	 PDE Loss :1.3227e-01,	 Total Loss :1.87810218334198
# it :6500, BC Loss :8.5738e-02,	 Domain Loss:1.6608e+00,	 PDE Loss :1.2546e-01,	 Total Loss :1.8720004558563232
# it :6600, BC Loss :8.6470e-02,	 Domain Loss:1.6584e+00,	 PDE Loss :1.2477e-01,	 Total Loss :1.8696521520614624
# it :6700, BC Loss :8.6455e-02,	 Domain Loss:1.6536e+00,	 PDE Loss :1.2897e-01,	 Total Loss :1.8690588474273682

# %%
plt.figure(figsize=(10,3))
t_loss = np.log1p(net.total_loss_hist)
p_loss = np.log1p(net.pde_loss_hist)
b_loss = np.log1p(net.BC_loss_hist)
d_loss = np.log1p(net.Domain_loss_hist)
epochs = range(1, 1+len(t_loss))
xbins = range(0, len(t_loss)+1, 50)
plt.plot(epochs, t_loss, lw=1,linestyle='-', label='Total Loss', c="k")
plt.plot(epochs, p_loss, lw=1,linestyle='-', label='PDE Loss', c="r")
plt.plot(epochs, d_loss, lw=1,linestyle='-', label='BC Loss', c="b")
plt.plot(epochs, b_loss, lw=1,linestyle='-', label='Domain Loss', c="g")
plt.legend()
plt.grid(True)
# plt.xticks(xbins)
plt.xlabel('per 100 Epochs')
plt.ylabel('Log Loss')
# x, y = epochs[-1], loss[-1]
# plt.text(x, y, y)
plt.show()

# %%
# 데이터 불러오기
# 데이터에 대해서는 ./make_dataset.ipynb 에서 확인
with open(f'./data/data_3_1_1.npy', 'rb') as f:
    data = np.load(f,allow_pickle=True)
x = data.T[0]
y = data.T[1]
X = data[:,:2]
f_true = data.T[2]


X = torch.tensor(X, dtype=torch.float)
X = X.to(net.X.device)

model = net.model
model.eval()
with torch.no_grad():
    f_pred = model(X).cpu().numpy().squeeze()

print("Test MSE Loss : ", np.mean(np.sqrt(np.abs(np.square(f_true.reshape(-1))-np.square(f_pred.reshape(-1))))))

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(7,3))
# grid
xi, yi = np.mgrid[x.min():x.max():500j, y.min():y.max():500j]

# f_true figure
rbf = scipy.interpolate.Rbf(x, y, f_true)
org = rbf(xi, yi)
img = ax[0].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[0].scatter(x, y, c=f_true)
ax[0].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

# f_pred figure
rbf = scipy.interpolate.Rbf(x, y, f_pred)
org = rbf(xi, yi)
img = ax[1].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[1].scatter(x, y, c=f_pred)
ax[1].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

plt.tight_layout()

# model_3_1_1 save
torch.save(model.state_dict(), "./data/model_withdata_3_1_1.pt")
# Out:
# Test MSE Loss :  1.2156348168505235

# %%
net = Net(B=3)
net.train()
# Out:
# Model's state_dict:
# layers.input.weight 	 torch.Size([100, 2])
# layers.input.bias 	 torch.Size([100])
# layers.hidden_0.weight 	 torch.Size([100, 100])
# layers.hidden_0.bias 	 torch.Size([100])
# layers.hidden_1.weight 	 torch.Size([100, 100])
# layers.hidden_1.bias 	 torch.Size([100])
# layers.hidden_2.weight 	 torch.Size([100, 100])
# layers.hidden_2.bias 	 torch.Size([100])
# layers.hidden_3.weight 	 torch.Size([100, 100])
# layers.hidden_3.bias 	 torch.Size([100])
# layers.hidden_4.weight 	 torch.Size([100, 100])
# layers.hidden_4.bias 	 torch.Size([100])
# layers.hidden_5.weight 	 torch.Size([100, 100])
# layers.hidden_5.bias 	 torch.Size([100])
# layers.hidden_6.weight 	 torch.Size([100, 100])
# layers.hidden_6.bias 	 torch.Size([100])
# layers.hidden_7.weight 	 torch.Size([100, 100])
# layers.hidden_7.bias 	 torch.Size([100])
# layers.output.weight 	 torch.Size([1, 100])
# layers.output.bias 	 torch.Size([1])
# train with Adam optimizer
# it :0100, BC Loss :4.9215e-04,	 Domain Loss:2.5285e-01,	 PDE Loss :4.1496e-02,	 Total Loss :0.29483747482299805
# it :0200, BC Loss :9.7324e-06,	 Domain Loss:2.5254e-01,	 PDE Loss :3.2790e-04,	 Total Loss :0.25287720561027527
# it :0300, BC Loss :5.1671e-06,	 Domain Loss:2.5253e-01,	 PDE Loss :2.2047e-04,	 Total Loss :0.2527545094490051
# it :0400, BC Loss :4.7929e-06,	 Domain Loss:2.5252e-01,	 PDE Loss :2.0275e-04,	 Total Loss :0.2527272701263428
# it :0500, BC Loss :4.4129e-06,	 Domain Loss:2.5251e-01,	 PDE Loss :1.8537e-04,	 Total Loss :0.25269970297813416
# it :0600, BC Loss :4.0484e-06,	 Domain Loss:2.5250e-01,	 PDE Loss :1.6878e-04,	 Total Loss :0.25267261266708374
# it :0700, BC Loss :3.7101e-06,	 Domain Loss:2.5249e-01,	 PDE Loss :1.5343e-04,	 Total Loss :0.2526467442512512
# it :0800, BC Loss :3.4055e-06,	 Domain Loss:2.5248e-01,	 PDE Loss :1.3957e-04,	 Total Loss :0.2526223957538605
# it :0900, BC Loss :3.1394e-06,	 Domain Loss:2.5247e-01,	 PDE Loss :1.2737e-04,	 Total Loss :0.2525997757911682
# it :1000, BC Loss :2.9152e-06,	 Domain Loss:2.5246e-01,	 PDE Loss :1.1688e-04,	 Total Loss :0.25257912278175354
# it :1100, BC Loss :2.7347e-06,	 Domain Loss:2.5245e-01,	 PDE Loss :1.0811e-04,	 Total Loss :0.2525603473186493
# it :1200, BC Loss :2.5986e-06,	 Domain Loss:2.5244e-01,	 PDE Loss :1.0100e-04,	 Total Loss :0.25254353880882263
# it :1300, BC Loss :2.5068e-06,	 Domain Loss:2.5243e-01,	 PDE Loss :9.5470e-05,	 Total Loss :0.25252851843833923
# it :1400, BC Loss :2.4579e-06,	 Domain Loss:2.5242e-01,	 PDE Loss :9.1395e-05,	 Total Loss :0.25251519680023193
# it :1500, BC Loss :2.4505e-06,	 Domain Loss:2.5241e-01,	 PDE Loss :8.8636e-05,	 Total Loss :0.2525033950805664
# it :1600, BC Loss :2.4816e-06,	 Domain Loss:2.5240e-01,	 PDE Loss :8.7039e-05,	 Total Loss :0.2524929642677307
# it :1700, BC Loss :2.5481e-06,	 Domain Loss:2.5239e-01,	 PDE Loss :8.6434e-05,	 Total Loss :0.252483606338501
# it :1800, BC Loss :2.6467e-06,	 Domain Loss:2.5239e-01,	 PDE Loss :8.6655e-05,	 Total Loss :0.25247514247894287
# it :1900, BC Loss :2.7743e-06,	 Domain Loss:2.5238e-01,	 PDE Loss :8.7552e-05,	 Total Loss :0.25246739387512207
# it :2000, BC Loss :2.9282e-06,	 Domain Loss:2.5237e-01,	 PDE Loss :8.9002e-05,	 Total Loss :0.2524600923061371
# it :2100, BC Loss :3.1063e-06,	 Domain Loss:2.5236e-01,	 PDE Loss :9.0907e-05,	 Total Loss :0.2524530589580536
# it :2200, BC Loss :3.3073e-06,	 Domain Loss:2.5235e-01,	 PDE Loss :9.3188e-05,	 Total Loss :0.25244614481925964
# it :2300, BC Loss :3.5309e-06,	 Domain Loss:2.5234e-01,	 PDE Loss :9.5802e-05,	 Total Loss :0.2524391710758209
# it :2400, BC Loss :3.7779e-06,	 Domain Loss:2.5233e-01,	 PDE Loss :9.8732e-05,	 Total Loss :0.2524321377277374
# it :2500, BC Loss :4.0499e-06,	 Domain Loss:2.5232e-01,	 PDE Loss :1.0199e-04,	 Total Loss :0.2524249255657196
# it :2600, BC Loss :4.3494e-06,	 Domain Loss:2.5231e-01,	 PDE Loss :1.0559e-04,	 Total Loss :0.2524174451828003
# it :2700, BC Loss :4.6796e-06,	 Domain Loss:2.5230e-01,	 PDE Loss :1.0960e-04,	 Total Loss :0.2524096965789795
# it :2800, BC Loss :5.0446e-06,	 Domain Loss:2.5228e-01,	 PDE Loss :1.1405e-04,	 Total Loss :0.2524017095565796
# it :2900, BC Loss :5.4485e-06,	 Domain Loss:2.5227e-01,	 PDE Loss :1.1900e-04,	 Total Loss :0.2523934543132782
# it :3000, BC Loss :5.8962e-06,	 Domain Loss:2.5225e-01,	 PDE Loss :1.2454e-04,	 Total Loss :0.2523849308490753
# it :3100, BC Loss :6.3924e-06,	 Domain Loss:2.5224e-01,	 PDE Loss :1.3072e-04,	 Total Loss :0.25237616896629333
# it :3200, BC Loss :6.9421e-06,	 Domain Loss:2.5222e-01,	 PDE Loss :1.3761e-04,	 Total Loss :0.252367228269577
# it :3300, BC Loss :7.5494e-06,	 Domain Loss:2.5221e-01,	 PDE Loss :1.4525e-04,	 Total Loss :0.2523581385612488
# it :3400, BC Loss :8.2177e-06,	 Domain Loss:2.5219e-01,	 PDE Loss :1.5368e-04,	 Total Loss :0.25234898924827576
# it :3500, BC Loss :8.9491e-06,	 Domain Loss:2.5217e-01,	 PDE Loss :1.6290e-04,	 Total Loss :0.25233975052833557
# it :3600, BC Loss :9.7436e-06,	 Domain Loss:2.5215e-01,	 PDE Loss :1.7284e-04,	 Total Loss :0.25233057141304016
# it :3700, BC Loss :1.0599e-05,	 Domain Loss:2.5213e-01,	 PDE Loss :1.8342e-04,	 Total Loss :0.25232142210006714
# it :3800, BC Loss :1.1511e-05,	 Domain Loss:2.5211e-01,	 PDE Loss :1.9448e-04,	 Total Loss :0.2523123025894165
# it :3900, BC Loss :1.2473e-05,	 Domain Loss:2.5208e-01,	 PDE Loss :2.0583e-04,	 Total Loss :0.25230327248573303
# it :4000, BC Loss :1.3478e-05,	 Domain Loss:2.5206e-01,	 PDE Loss :2.1725e-04,	 Total Loss :0.25229424238204956
# it :4100, BC Loss :1.4519e-05,	 Domain Loss:2.5204e-01,	 PDE Loss :2.2853e-04,	 Total Loss :0.2522851526737213
# it :4200, BC Loss :1.5590e-05,	 Domain Loss:2.5202e-01,	 PDE Loss :2.3950e-04,	 Total Loss :0.25227582454681396
# it :4300, BC Loss :1.6689e-05,	 Domain Loss:2.5200e-01,	 PDE Loss :2.5000e-04,	 Total Loss :0.2522662878036499
# it :4400, BC Loss :1.7818e-05,	 Domain Loss:2.5198e-01,	 PDE Loss :2.5997e-04,	 Total Loss :0.25225630402565
# it :4500, BC Loss :1.8982e-05,	 Domain Loss:2.5196e-01,	 PDE Loss :2.6939e-04,	 Total Loss :0.2522457540035248
# it :4600, BC Loss :2.0193e-05,	 Domain Loss:2.5194e-01,	 PDE Loss :2.7834e-04,	 Total Loss :0.2522346079349518
# it :4700, BC Loss :2.1468e-05,	 Domain Loss:2.5191e-01,	 PDE Loss :2.8691e-04,	 Total Loss :0.25222262740135193
# it :4800, BC Loss :2.2825e-05,	 Domain Loss:2.5189e-01,	 PDE Loss :2.9523e-04,	 Total Loss :0.25220978260040283
# it :4900, BC Loss :2.4291e-05,	 Domain Loss:2.5187e-01,	 PDE Loss :3.0348e-04,	 Total Loss :0.252195805311203
# it :5000, BC Loss :2.5893e-05,	 Domain Loss:2.5184e-01,	 PDE Loss :3.1181e-04,	 Total Loss :0.25218063592910767
# train with L-BFGs

# %%
plt.figure(figsize=(10,3))
t_loss = np.log1p(net.total_loss_hist)
p_loss = np.log1p(net.pde_loss_hist)
b_loss = np.log1p(net.BC_loss_hist)
d_loss = np.log1p(net.Domain_loss_hist)
epochs = range(1, 1+len(t_loss))
xbins = range(0, len(t_loss)+1, 50)
plt.plot(epochs, t_loss, lw=1,linestyle='-', label='Total Loss', c="k")
plt.plot(epochs, p_loss, lw=1,linestyle='-', label='PDE Loss', c="r")
plt.plot(epochs, d_loss, lw=1,linestyle='-', label='BC Loss', c="b")
plt.plot(epochs, b_loss, lw=1,linestyle='-', label='Domain Loss', c="g")
plt.legend()
plt.grid(True)
# plt.xticks(xbins)
plt.xlabel('per 100 Epochs')
plt.ylabel('Log Loss')
# x, y = epochs[-1], loss[-1]
# plt.text(x, y, y)
plt.show()

# %%
# 데이터 불러오기
# 데이터에 대해서는 ./make_dataset.ipynb 에서 확인
with open(f'./data/data_1_3_1.npy', 'rb') as f:
    data = np.load(f,allow_pickle=True)
x = data.T[0]
y = data.T[1]
X = data[:,:2]
f_true = data.T[2]


X = torch.tensor(X, dtype=torch.float)
X = X.to(net.X.device)

model = net.model
model.eval()
with torch.no_grad():
    f_pred = model(X).cpu().numpy().squeeze()

print("Test MSE Loss : ", np.mean(np.sqrt(np.abs(np.square(f_true.reshape(-1))-np.square(f_pred.reshape(-1))))))

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(7,3))
# grid
xi, yi = np.mgrid[x.min():x.max():500j, y.min():y.max():500j]

# f_true figure
rbf = scipy.interpolate.Rbf(x, y, f_true)
org = rbf(xi, yi)
img = ax[0].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[0].scatter(x, y, c=f_true)
ax[0].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

# f_pred figure
rbf = scipy.interpolate.Rbf(x, y, f_pred)
org = rbf(xi, yi)
img = ax[1].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[1].scatter(x, y, c=f_pred)
ax[1].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

plt.tight_layout()

# model_1_3_1 save
torch.save(model.state_dict(), "./data/model_withdata_1_3_1.pt")
# Out:
# Test MSE Loss :  0.4076037579699114

# %%
net = Net(C=3)
net.train()
# Out:
# Model's state_dict:
# layers.input.weight 	 torch.Size([100, 2])
# layers.input.bias 	 torch.Size([100])
# layers.hidden_0.weight 	 torch.Size([100, 100])
# layers.hidden_0.bias 	 torch.Size([100])
# layers.hidden_1.weight 	 torch.Size([100, 100])
# layers.hidden_1.bias 	 torch.Size([100])
# layers.hidden_2.weight 	 torch.Size([100, 100])
# layers.hidden_2.bias 	 torch.Size([100])
# layers.hidden_3.weight 	 torch.Size([100, 100])
# layers.hidden_3.bias 	 torch.Size([100])
# layers.hidden_4.weight 	 torch.Size([100, 100])
# layers.hidden_4.bias 	 torch.Size([100])
# layers.hidden_5.weight 	 torch.Size([100, 100])
# layers.hidden_5.bias 	 torch.Size([100])
# layers.hidden_6.weight 	 torch.Size([100, 100])
# layers.hidden_6.bias 	 torch.Size([100])
# layers.hidden_7.weight 	 torch.Size([100, 100])
# layers.hidden_7.bias 	 torch.Size([100])
# layers.output.weight 	 torch.Size([1, 100])
# layers.output.bias 	 torch.Size([1])
# train with Adam optimizer
# it :0100, BC Loss :2.2069e-07,	 Domain Loss:2.4804e-01,	 PDE Loss :9.7482e-06,	 Total Loss :0.24804578721523285
# it :0200, BC Loss :2.3756e-07,	 Domain Loss:2.4803e-01,	 PDE Loss :1.2322e-05,	 Total Loss :0.24803799390792847
# it :0300, BC Loss :2.5207e-07,	 Domain Loss:2.4801e-01,	 PDE Loss :1.5245e-05,	 Total Loss :0.24802912771701813
# it :0400, BC Loss :2.7483e-07,	 Domain Loss:2.4800e-01,	 PDE Loss :1.9202e-05,	 Total Loss :0.24801981449127197
# it :0500, BC Loss :3.0414e-07,	 Domain Loss:2.4799e-01,	 PDE Loss :2.4151e-05,	 Total Loss :0.2480105757713318
# it :0600, BC Loss :3.3763e-07,	 Domain Loss:2.4797e-01,	 PDE Loss :2.9967e-05,	 Total Loss :0.24800154566764832
# it :0700, BC Loss :3.7219e-07,	 Domain Loss:2.4796e-01,	 PDE Loss :3.6449e-05,	 Total Loss :0.24799279868602753
# it :0800, BC Loss :4.0415e-07,	 Domain Loss:2.4794e-01,	 PDE Loss :4.3348e-05,	 Total Loss :0.24798430502414703
# it :0900, BC Loss :4.2999e-07,	 Domain Loss:2.4793e-01,	 PDE Loss :5.0388e-05,	 Total Loss :0.2479759007692337
# it :1000, BC Loss :4.4678e-07,	 Domain Loss:2.4791e-01,	 PDE Loss :5.7327e-05,	 Total Loss :0.2479674518108368
# it :1100, BC Loss :4.5257e-07,	 Domain Loss:2.4789e-01,	 PDE Loss :6.3987e-05,	 Total Loss :0.24795867502689362
# it :1200, BC Loss :4.4664e-07,	 Domain Loss:2.4788e-01,	 PDE Loss :7.0297e-05,	 Total Loss :0.24794930219650269
# it :1300, BC Loss :4.2963e-07,	 Domain Loss:2.4786e-01,	 PDE Loss :7.6305e-05,	 Total Loss :0.2479391098022461
# it :1400, BC Loss :4.0337e-07,	 Domain Loss:2.4785e-01,	 PDE Loss :8.2166e-05,	 Total Loss :0.2479277402162552
# it :1500, BC Loss :3.7118e-07,	 Domain Loss:2.4783e-01,	 PDE Loss :8.8153e-05,	 Total Loss :0.24791502952575684
# it :1600, BC Loss :3.3848e-07,	 Domain Loss:2.4781e-01,	 PDE Loss :9.4651e-05,	 Total Loss :0.2479005604982376
# it :1700, BC Loss :3.1372e-07,	 Domain Loss:2.4778e-01,	 PDE Loss :1.0219e-04,	 Total Loss :0.2478840947151184
# it :1800, BC Loss :3.0999e-07,	 Domain Loss:2.4775e-01,	 PDE Loss :1.1148e-04,	 Total Loss :0.2478654533624649
# it :1900, BC Loss :3.4645e-07,	 Domain Loss:2.4772e-01,	 PDE Loss :1.2345e-04,	 Total Loss :0.24784456193447113
# it :2000, BC Loss :4.4782e-07,	 Domain Loss:2.4768e-01,	 PDE Loss :1.3921e-04,	 Total Loss :0.24782170355319977
# it :2100, BC Loss :6.3914e-07,	 Domain Loss:2.4764e-01,	 PDE Loss :1.5975e-04,	 Total Loss :0.24779757857322693
# it :2200, BC Loss :9.3297e-07,	 Domain Loss:2.4759e-01,	 PDE Loss :1.8539e-04,	 Total Loss :0.2477732002735138
# it :2300, BC Loss :1.3129e-06,	 Domain Loss:2.4753e-01,	 PDE Loss :2.1509e-04,	 Total Loss :0.24774952232837677
# it :2400, BC Loss :1.7284e-06,	 Domain Loss:2.4748e-01,	 PDE Loss :2.4635e-04,	 Total Loss :0.2477269470691681
# it :2500, BC Loss :2.1149e-06,	 Domain Loss:2.4743e-01,	 PDE Loss :2.7624e-04,	 Total Loss :0.24770492315292358
# it :2600, BC Loss :2.4284e-06,	 Domain Loss:2.4738e-01,	 PDE Loss :3.0286e-04,	 Total Loss :0.2476823329925537
# it :2700, BC Loss :2.6627e-06,	 Domain Loss:2.4733e-01,	 PDE Loss :3.2616e-04,	 Total Loss :0.24765780568122864
# it :2800, BC Loss :2.8405e-06,	 Domain Loss:2.4728e-01,	 PDE Loss :3.4735e-04,	 Total Loss :0.24763013422489166
# it :2900, BC Loss :2.9994e-06,	 Domain Loss:2.4723e-01,	 PDE Loss :3.6808e-04,	 Total Loss :0.2475980520248413
# it :3000, BC Loss :3.1938e-06,	 Domain Loss:2.4717e-01,	 PDE Loss :3.9003e-04,	 Total Loss :0.2475600391626358
# it :3100, BC Loss :3.5176e-06,	 Domain Loss:2.4710e-01,	 PDE Loss :4.1507e-04,	 Total Loss :0.24751469492912292
# it :3200, BC Loss :4.1552e-06,	 Domain Loss:2.4701e-01,	 PDE Loss :4.4574e-04,	 Total Loss :0.24746088683605194
# it :3300, BC Loss :5.4506e-06,	 Domain Loss:2.4691e-01,	 PDE Loss :4.8564e-04,	 Total Loss :0.24739868938922882
# it :3400, BC Loss :7.9031e-06,	 Domain Loss:2.4678e-01,	 PDE Loss :5.3829e-04,	 Total Loss :0.24733009934425354
# it :3500, BC Loss :1.1859e-05,	 Domain Loss:2.4664e-01,	 PDE Loss :6.0452e-04,	 Total Loss :0.2472587674856186
# it :3600, BC Loss :1.7010e-05,	 Domain Loss:2.4649e-01,	 PDE Loss :6.7692e-04,	 Total Loss :0.24718599021434784
# it :3700, BC Loss :2.2956e-05,	 Domain Loss:2.4634e-01,	 PDE Loss :7.5108e-04,	 Total Loss :0.24711014330387115
# it :3800, BC Loss :2.9012e-05,	 Domain Loss:2.4618e-01,	 PDE Loss :8.2010e-04,	 Total Loss :0.24702756106853485
# it :3900, BC Loss :3.5648e-05,	 Domain Loss:2.4601e-01,	 PDE Loss :8.9219e-04,	 Total Loss :0.2469344288110733
# it :4000, BC Loss :4.3086e-05,	 Domain Loss:2.4582e-01,	 PDE Loss :9.6900e-04,	 Total Loss :0.24682724475860596
# it :4100, BC Loss :5.1911e-05,	 Domain Loss:2.4560e-01,	 PDE Loss :1.0513e-03,	 Total Loss :0.24670298397541046
# it :4200, BC Loss :6.2579e-05,	 Domain Loss:2.4535e-01,	 PDE Loss :1.1487e-03,	 Total Loss :0.24656088650226593
# it :4300, BC Loss :7.5462e-05,	 Domain Loss:2.4507e-01,	 PDE Loss :1.2540e-03,	 Total Loss :0.246395543217659
# it :4400, BC Loss :9.1415e-05,	 Domain Loss:2.4474e-01,	 PDE Loss :1.3776e-03,	 Total Loss :0.24621403217315674
# it :4500, BC Loss :1.1047e-04,	 Domain Loss:2.4439e-01,	 PDE Loss :1.5106e-03,	 Total Loss :0.24601078033447266
# it :4600, BC Loss :1.3337e-04,	 Domain Loss:2.4399e-01,	 PDE Loss :1.6593e-03,	 Total Loss :0.245786651968956
# it :4700, BC Loss :1.6013e-04,	 Domain Loss:2.4357e-01,	 PDE Loss :1.8256e-03,	 Total Loss :0.2455526739358902
# it :4800, BC Loss :1.9053e-04,	 Domain Loss:2.4312e-01,	 PDE Loss :2.0073e-03,	 Total Loss :0.24531705677509308
# it :4900, BC Loss :2.2383e-04,	 Domain Loss:2.4267e-01,	 PDE Loss :2.1778e-03,	 Total Loss :0.24507266283035278
# it :5000, BC Loss :2.5946e-04,	 Domain Loss:2.4223e-01,	 PDE Loss :2.3583e-03,	 Total Loss :0.24484407901763916
# train with L-BFGs
# it :5100, BC Loss :6.0425e-04,	 Domain Loss:2.3829e-01,	 PDE Loss :4.1597e-03,	 Total Loss :0.24305757880210876
# it :5200, BC Loss :7.3672e-04,	 Domain Loss:2.3648e-01,	 PDE Loss :4.8872e-03,	 Total Loss :0.24210044741630554
# it :5300, BC Loss :7.4818e-04,	 Domain Loss:2.3541e-01,	 PDE Loss :5.1834e-03,	 Total Loss :0.24134176969528198
# it :5400, BC Loss :7.6797e-04,	 Domain Loss:2.3520e-01,	 PDE Loss :4.6568e-03,	 Total Loss :0.24062979221343994
# it :5500, BC Loss :1.2401e-03,	 Domain Loss:2.2936e-01,	 PDE Loss :7.7586e-03,	 Total Loss :0.2383585274219513
# it :5600, BC Loss :1.3396e-03,	 Domain Loss:2.2937e-01,	 PDE Loss :6.4537e-03,	 Total Loss :0.23715893924236298
# it :5700, BC Loss :1.3659e-03,	 Domain Loss:2.2848e-01,	 PDE Loss :6.7763e-03,	 Total Loss :0.23662473261356354
# it :5800, BC Loss :1.8766e-03,	 Domain Loss:2.2452e-01,	 PDE Loss :8.1880e-03,	 Total Loss :0.23458240926265717
# it :5900, BC Loss :2.1313e-03,	 Domain Loss:2.2346e-01,	 PDE Loss :7.5755e-03,	 Total Loss :0.23316283524036407
# it :6000, BC Loss :2.1602e-03,	 Domain Loss:2.2265e-01,	 PDE Loss :7.5015e-03,	 Total Loss :0.23231327533721924
# it :6100, BC Loss :2.2795e-03,	 Domain Loss:2.2238e-01,	 PDE Loss :7.3040e-03,	 Total Loss :0.2319636195898056
# it :6200, BC Loss :2.4365e-03,	 Domain Loss:2.2170e-01,	 PDE Loss :7.4282e-03,	 Total Loss :0.23156630992889404
# it :6300, BC Loss :2.4907e-03,	 Domain Loss:2.2115e-01,	 PDE Loss :7.6623e-03,	 Total Loss :0.23130595684051514
# it :6400, BC Loss :3.4321e-03,	 Domain Loss:2.1687e-01,	 PDE Loss :9.6382e-03,	 Total Loss :0.22994357347488403
# it :6500, BC Loss :3.3557e-03,	 Domain Loss:2.1712e-01,	 PDE Loss :8.5440e-03,	 Total Loss :0.22901523113250732
# it :6600, BC Loss :3.3941e-03,	 Domain Loss:2.1684e-01,	 PDE Loss :8.5329e-03,	 Total Loss :0.22876450419425964
# it :6700, BC Loss :3.5858e-03,	 Domain Loss:2.1546e-01,	 PDE Loss :9.2971e-03,	 Total Loss :0.22834289073944092
# it :6800, BC Loss :3.9339e-03,	 Domain Loss:2.1306e-01,	 PDE Loss :1.0116e-02,	 Total Loss :0.22711218893527985
# it :6900, BC Loss :4.1750e-03,	 Domain Loss:2.1183e-01,	 PDE Loss :1.0053e-02,	 Total Loss :0.22605621814727783
# it :7000, BC Loss :4.3439e-03,	 Domain Loss:2.1113e-01,	 PDE Loss :1.0237e-02,	 Total Loss :0.22570912539958954
# it :7100, BC Loss :4.4563e-03,	 Domain Loss:2.1068e-01,	 PDE Loss :1.0413e-02,	 Total Loss :0.2255447804927826
# it :7200, BC Loss :4.5871e-03,	 Domain Loss:2.1047e-01,	 PDE Loss :1.0333e-02,	 Total Loss :0.2253885418176651
# it :7300, BC Loss :5.1190e-03,	 Domain Loss:2.0899e-01,	 PDE Loss :1.0772e-02,	 Total Loss :0.2248796671628952
# it :7400, BC Loss :5.6099e-03,	 Domain Loss:2.0742e-01,	 PDE Loss :1.1288e-02,	 Total Loss :0.22432079911231995
# it :7500, BC Loss :6.0475e-03,	 Domain Loss:2.0622e-01,	 PDE Loss :1.1560e-02,	 Total Loss :0.2238299548625946
# it :7600, BC Loss :7.5456e-03,	 Domain Loss:2.0126e-01,	 PDE Loss :1.3761e-02,	 Total Loss :0.2225669026374817
# it :7700, BC Loss :7.7407e-03,	 Domain Loss:1.9925e-01,	 PDE Loss :1.4594e-02,	 Total Loss :0.221589133143425
# it :7800, BC Loss :8.0724e-03,	 Domain Loss:1.9786e-01,	 PDE Loss :1.4249e-02,	 Total Loss :0.22018498182296753
# it :7900, BC Loss :7.9191e-03,	 Domain Loss:1.9794e-01,	 PDE Loss :1.3838e-02,	 Total Loss :0.21970130503177643
# it :8000, BC Loss :7.7244e-03,	 Domain Loss:1.9790e-01,	 PDE Loss :1.3786e-02,	 Total Loss :0.21940571069717407
# it :8100, BC Loss :7.6635e-03,	 Domain Loss:1.9777e-01,	 PDE Loss :1.3522e-02,	 Total Loss :0.21895882487297058
# it :8200, BC Loss :7.4137e-03,	 Domain Loss:1.9820e-01,	 PDE Loss :1.3160e-02,	 Total Loss :0.21877163648605347
# it :8300, BC Loss :7.2701e-03,	 Domain Loss:1.9855e-01,	 PDE Loss :1.2830e-02,	 Total Loss :0.21864750981330872
# it :8400, BC Loss :7.6056e-03,	 Domain Loss:1.9744e-01,	 PDE Loss :1.3254e-02,	 Total Loss :0.21829535067081451
# it :8500, BC Loss :7.3609e-03,	 Domain Loss:1.9779e-01,	 PDE Loss :1.2899e-02,	 Total Loss :0.21805226802825928
# it :8600, BC Loss :7.3958e-03,	 Domain Loss:1.9798e-01,	 PDE Loss :1.2509e-02,	 Total Loss :0.21788093447685242
# it :8700, BC Loss :7.3368e-03,	 Domain Loss:1.9803e-01,	 PDE Loss :1.2424e-02,	 Total Loss :0.21779502928256989
# it :8800, BC Loss :7.5014e-03,	 Domain Loss:1.9735e-01,	 PDE Loss :1.2778e-02,	 Total Loss :0.21762880682945251
# it :8900, BC Loss :7.6772e-03,	 Domain Loss:1.9713e-01,	 PDE Loss :1.2612e-02,	 Total Loss :0.2174142301082611
# it :9000, BC Loss :7.6145e-03,	 Domain Loss:1.9722e-01,	 PDE Loss :1.2531e-02,	 Total Loss :0.21736545860767365

# %%
plt.figure(figsize=(10,3))
t_loss = np.log1p(net.total_loss_hist)
p_loss = np.log1p(net.pde_loss_hist)
b_loss = np.log1p(net.BC_loss_hist)
d_loss = np.log1p(net.Domain_loss_hist)
epochs = range(1, 1+len(t_loss))
xbins = range(0, len(t_loss)+1, 50)
plt.plot(epochs, t_loss, lw=1,linestyle='-', label='Total Loss', c="k")
plt.plot(epochs, p_loss, lw=1,linestyle='-', label='PDE Loss', c="r")
plt.plot(epochs, d_loss, lw=1,linestyle='-', label='BC Loss', c="b")
plt.plot(epochs, b_loss, lw=1,linestyle='-', label='Domain Loss', c="g")
plt.legend()
plt.grid(True)
# plt.xticks(xbins)
plt.xlabel('per 100 Epochs')
plt.ylabel('Log Loss')
# x, y = epochs[-1], loss[-1]
# plt.text(x, y, y)
plt.show()

# %%
# 데이터 불러오기
# 데이터에 대해서는 ./make_dataset.ipynb 에서 확인
with open(f'./data/data_1_1_3.npy', 'rb') as f:
    data = np.load(f,allow_pickle=True)
x = data.T[0]
y = data.T[1]
X = data[:,:2]
f_true = data.T[2]


X = torch.tensor(X, dtype=torch.float)
X = X.to(net.X.device)

model = net.model
model.eval()
with torch.no_grad():
    f_pred = model(X).cpu().numpy().squeeze()

print("Test MSE Loss : ", np.mean(np.sqrt(np.abs(np.square(f_true.reshape(-1))-np.square(f_pred.reshape(-1))))))

fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(7,3))
# grid
xi, yi = np.mgrid[-np.pi:np.pi:500j, -np.pi:np.pi:500j]

# f_true figure
rbf = scipy.interpolate.Rbf(x, y, f_true)
org = rbf(xi, yi)
img = ax[0].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[0].scatter(x, y, c=f_true)
ax[0].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

# f_pred figure
rbf = scipy.interpolate.Rbf(x, y, f_pred)
org = rbf(xi, yi)
img = ax[1].imshow(org.T, origin='lower',extent=[x.min(), x.max(), y.min(), y.max()])
ax[1].scatter(x, y, c=f_pred)
ax[1].set(xlabel='X', ylabel='Y')
# fig.colorbar(img,shrink=0.8)

plt.tight_layout()

# model_1_1_3 save
torch.save(model.state_dict(), "./data/model_withdata_1_1_3.pt")
# Out:
# Test MSE Loss :  0.4001326507666589
