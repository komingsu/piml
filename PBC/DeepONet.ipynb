# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

import pyDOE

import pandas as pd
import numpy as np

import logging
import datetime

import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
init_dict = {
    "Glorot uniform": torch.nn.init.xavier_uniform_,
    "He uniform": torch.nn.init.kaiming_uniform_,
    "zeros": torch.nn.init.zeros_,
    }

class MLP(nn.Module):
    def __init__(self, n_input, n_hidden, n_output, n_layers=1, act=nn.GELU(), residual=False):
        super(MLP, self).__init__()
        self.n_input = n_input # input layer dim
        self.n_hidden = n_hidden # hidden layer dim
        self.n_output = n_output # output layer dim
        self.n_layers = n_layers # count of hidden layers
        self.act = act # activation function
        self.residual = residual
        
        # layers
        self.linear_pre = nn.Linear(n_input, n_hidden)
        self.linears_hidden = nn.ModuleList([nn.Linear(n_hidden, n_hidden) for _ in range(n_layers)])
        self.linear_post = nn.Linear(n_hidden, n_output)
        
    def init_weights(self):
        weight_init = "He uniform" if self.act == nn.ReLU() else "Glorot uniform"
        weight_init = init_dict.get(weight_init)
        bias_init = init_dict.get("zeros")
        gain = nn.init.calculate_gain('leaky_relu') if isinstance(self.act, nn.LeakyReLU) else \
               nn.init.calculate_gain('tanh') if isinstance(self.act, nn.Tanh) else \
               nn.init.calculate_gain('linear')
        
        # weights init
        weight_init(self.linear_pre.weight, gain=gain)
        weight_init(self.linear_post.weight, gain=gain)
        for linear in self.linears_hidden:
            weight_init(linear.weight, gain=gain)
        
        # bias init
        bias_init(self.linear_pre.bias)
        bias_init(self.linear_post.bias)
        for linear in self.linears_hidden:
            bias_init(linear.bias)

    def forward(self, x):
        x = self.act(self.linear_pre(x))
        for i in range(self.n_layers):
            x = x + self.act(self.linears_hidden[i](x)) if self.residual else self.act(self.linears_hidden[i](x))
        x = self.linear_post(x)
        return x

class DeepONet(nn.Module):
    def __init__(self, branch_info, truck_info, act=nn.GELU(), residual=False):
        super(DeepONet, self).__init__()
        self.branch_info = branch_info
        self.truck_info = truck_info
        self.act = act
        self.residual = residual
    
        # branch and truck network
        self.branch_net = MLP(
            branch_info["n_input"],
            branch_info["n_hidden"],
            branch_info["n_output"],
            branch_info["n_layers"],
            self.act, self.residual)
        self.truck_net = MLP(
            truck_info["n_input"],
            truck_info["n_hidden"],
            truck_info["n_output"],
            truck_info["n_layers"],
            self.act, self.residual)
        
    def merge_branch_trunk(self, x_func, x_loc):
        y = torch.einsum('bi,bi->b', x_func, x_loc)
        y = torch.unsqueeze(y, dim=1)
        return y
    
    def forward(self, x_func, x_loc):
        x_branch = self.branch_net(x_func)
        x_truck = self.truck_net(x_loc)
        y = self.merge_branch_trunk(x_branch, x_truck)
        return y

# %%
def poisson_equation(x,y,a=1,b=1,c=1):
    return a * torch.sin(x/b) * torch.sin(y/c)

def make_deeponet_dataset(lb, ub, branch_samples, trunk_samples, coef):
    domain_length = ub - lb
    a,b,c = coef
    # trunk_data 생성: 예측할 [x, y] 위치를 생성합니다.
    trunk_data = pyDOE.lhs(2, samples=trunk_samples)
    trunk_data = trunk_data * domain_length - domain_length/2

    # trunk_data 위치에서의 실제 u(x, y) 값 계산
    y_true = torch.tensor([poisson_equation(torch.tensor(x[0]), torch.tensor(x[1]), a=a,b=b,c=c).item() for x in trunk_data], dtype=torch.float32)
    trunk_data = torch.tensor(trunk_data, dtype=torch.float32)
    
    # branch_data 생성: 함수 값 샘플을 생성합니다. 여기서는 더 많은 포인트를 사용합니다.
    branch_points = pyDOE.lhs(2, samples=branch_samples)
    branch_points = branch_points * domain_length - domain_length/2
    branch_data = torch.tensor([poisson_equation(torch.tensor(x[0]), torch.tensor(x[1]), a=a,b=b,c=c).item() for x in branch_points], dtype=torch.float32)

    return trunk_data, branch_data, y_true[:, None]

# %% [markdown]
# # Sample with Poisson equation
#
# ## Problem setting
#
# 학습하고자 하는 PDE는 아래와 같다.
#
# $$
# \begin{split}
# u_{xx}+u_{yy}=f & \ \text{in}\ \Omega \\
# % u=0 & \ \text{on} \ \partial \Omega
# \end{split}
# $$
#
# 이때 Original u가
#
# $$
# u =  a\sin(\frac{x}{b})\sin(\frac{y}{c})
# $$
# 일 때,
#
# $u_{xx}$와 $u_{yy}$ 는 다음과 같다.
#
# $$
# \begin{split}
# u_{xx} & = -\frac{a}{b^2} \sin\left(\frac{x}{b}\right) \sin\left(\frac{y}{c}\right) \\
# u_{yy} & = -\frac{a}{c^2} \sin\left(\frac{x}{b}\right) \sin\left(\frac{y}{c}\right)
# \end{split}
# $$
#
# 즉
#
# $$
# \begin{split}
# u_{xx}+u_{yy} &= -a \left(\frac{1}{b^2} + \frac{1}{c^2}\right) \sin\left(\frac{x}{b}\right) \sin\left(\frac{y}{c}\right)\\
# &= -\left(\frac{1}{b^2} + \frac{1}{c^2}\right) a \sin\left(\frac{x}{b}\right) \sin\left(\frac{y}{c}\right) \\
# &= -\left(\frac{1}{b^2} + \frac{1}{c^2}\right) u
# \end{split}
# $$
#
# 가 되어 PDE 문제가 된다.
#
# 따라서 PINN은 NN이 예측한 $f_\text{pred}$ 에 대하여 $f_{xx} + f_{yy} + \left(\frac{1}{b^2} + \frac{1}{c^2}\right) f = 0$ 에 대하여 Loss를 설정하여 학습한다.

# %%
# logging 설정
now = datetime.datetime.now()
log_filename = now.strftime("%Y%m%d%H%M%S") + "_training.log"
logging.basicConfig(filename=log_filename, level=logging.INFO, 
                    format='%(asctime)s:%(levelname)s:%(message)s')
logging.info("=============================== Start ===============================")

# 학습 device
print("Number of GPUs:", torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    print("GPU", i+1, ":", torch.cuda.get_device_name(i))
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}') # 1개의 gpu로 진행

# pde coefficient data
coef_df = pd.read_csv('NewABC_cluster_results_newsdist(0.1).csv').iloc[:,:3]

# hyperparameters
epochs = 100
batch_size = 100

lb = -2*torch.pi
ub = 2*torch.pi
branch_samples = 100
trunk_samples = 1000
coef = (3,1,1) # sample coefficient

branch_info = {
    "n_input": 100,
    "n_hidden": 64,
    "n_output": 32,
    "n_layers": 3,
    }
truck_info = {
    "n_input": 2,
    "n_hidden": 64,
    "n_output": 32,
    "n_layers": 3,
    }
act = nn.GELU()

# coef 반복
for idx, row in coef_df.iterrows():
    coef = (row["A"], row["B"], row["C"])
    logging.info(f"coef: {coef} training...")
    # 데이터셋 생성
    trunk_data, branch_data, y_true = make_deeponet_dataset(lb, ub, branch_samples, trunk_samples, coef)
    branch_data = branch_data.repeat(1000,1)
    dataset = TensorDataset(trunk_data, branch_data, y_true)
    data_loader = DataLoader(dataset, batch_size=50, shuffle=True, pin_memory=True, num_workers=2)

    # 모델 생성 및 컴파일
    deeponet = DeepONet(branch_info, truck_info, act=nn.GELU(), residual=False)
    # deeponet = torch.nn.DataParallel(deeponet) # multi-GPU 사용
    deeponet.to(device)  # 모델을 GPU로 이동
    
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(deeponet.parameters(), lr=0.001)

    # 학습
    for epoch in range(epochs):
        deeponet.train()
        total_loss = 0
        for trunk_input, branch_input, targets in data_loader:
            trunk_input = trunk_input.to(device)
            branch_input = branch_input.to(device)
            targets = targets.to(device)
            outputs = deeponet(branch_input, trunk_input)
            loss = criterion(outputs, targets)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        logging.info(f'Epoch {epoch+1}, Average Loss: {total_loss / len(data_loader)}')
        print(f'Epoch {epoch+1}, Average Loss: {total_loss / len(data_loader)}')
    logging.info(f"coef: {coef} training done!")
    logging.info("---------------------------------------------------------------")
    
    # test 시각화
    deeponet.to('cpu')
    
    input_list = []
    output_list = []

    deeponet.eval()
    for trunk_inputs, branch_input, targets in data_loader:
        outputs = deeponet(branch_input, trunk_inputs)
        input_list.append(trunk_inputs)
        output_list.append(outputs)
        
    input_list = torch.cat(input_list, dim=0).detach().numpy()
    output_list = torch.cat(output_list, dim=0).detach().numpy()
    
    grid_x, grid_y = np.mgrid[-2*np.pi:2*np.pi:100j, -2*np.pi:2*np.pi:100j] 
    grid_z = griddata((input_list[:,0], input_list[:,1]), output_list.reshape(-1), (grid_x, grid_y), method='cubic')

    plt.figure(figsize=(8, 8))
    plt.imshow(grid_z.T, extent=(-2*np.pi,2*np.pi, -2*np.pi,2*np.pi), origin='lower', cmap='viridis')
    plt.colorbar(label=f'f(x, y) = {row["A"]}*sin(x/{row["B"]}) * cos(y/{row["C"]})')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Interpolated Visualization of LHS Sampling and Function')
    plt.savefig(f'{row["A"]}_{row["B"]}_{row["C"]}.jpg')
    plt.close()
# Out:
# Number of GPUs: 2
# GPU 1 : NVIDIA TITAN Xp
# GPU 2 : NVIDIA TITAN Xp
# Using device: cuda
# Epoch 1, Average Loss: 0.1759501237422228
# Epoch 2, Average Loss: 0.06585810016840696
# Epoch 3, Average Loss: 0.024955237470567226
# Epoch 4, Average Loss: 0.013465915038250387
# Epoch 5, Average Loss: 0.010304639604873956
# Epoch 6, Average Loss: 0.00770927662961185
# Epoch 7, Average Loss: 0.006216852075885982
# Epoch 8, Average Loss: 0.005294714029878378
# Epoch 9, Average Loss: 0.003897534601856023
# Epoch 10, Average Loss: 0.0036875890800729394
# Epoch 11, Average Loss: 0.004160078731365502
# Epoch 12, Average Loss: 0.002064346871338785
# Epoch 13, Average Loss: 0.0011961141572101042
# Epoch 14, Average Loss: 0.0007033416230115108
# Epoch 15, Average Loss: 0.0005845902662258596
# Epoch 16, Average Loss: 0.0003601222197175957
# Epoch 17, Average Loss: 0.00036926124012097715
# Epoch 18, Average Loss: 0.00034923511921078896
# Epoch 19, Average Loss: 0.00039982391826924867
# Epoch 20, Average Loss: 0.00031600139118381776
# Epoch 21, Average Loss: 0.00032833132063387894
# Epoch 22, Average Loss: 0.00017504764546174555
# Epoch 23, Average Loss: 0.00021699405951949302
# Epoch 24, Average Loss: 0.00031332472499343564
# Epoch 25, Average Loss: 0.00023636458718101494
# Epoch 26, Average Loss: 0.0002226120137493126
# Epoch 27, Average Loss: 0.0001717688384815119
# Epoch 28, Average Loss: 0.00014588594931410625
# Epoch 29, Average Loss: 0.00020794229858438483
# Epoch 30, Average Loss: 0.00021991832654748577
# Epoch 31, Average Loss: 0.00015846132446313278
# Epoch 32, Average Loss: 0.00027590621830313465
# Epoch 33, Average Loss: 0.000609085012547439
# Epoch 34, Average Loss: 0.0017406081184162757
# Epoch 35, Average Loss: 0.0011390169223886915
# Epoch 36, Average Loss: 0.0010093201075505932
# Epoch 37, Average Loss: 0.0006654359589447267
# Epoch 38, Average Loss: 0.0005391469843743834
# Epoch 39, Average Loss: 0.00020930969803885092
# Epoch 40, Average Loss: 0.00018455470963090191
# Epoch 41, Average Loss: 0.00010128651847480796
# Epoch 42, Average Loss: 8.72567083206377e-05
# Epoch 43, Average Loss: 8.107752073556184e-05
# Epoch 44, Average Loss: 7.89923458796693e-05
# Epoch 45, Average Loss: 9.805748359212885e-05
# Epoch 46, Average Loss: 9.933401306625456e-05
# Epoch 47, Average Loss: 0.00010421374554425711
# Epoch 48, Average Loss: 0.00014950520708225667
# Epoch 49, Average Loss: 0.00018332130766793853
# Epoch 50, Average Loss: 0.0008984035754110664
# Epoch 51, Average Loss: 0.0009499060528469272
# Epoch 52, Average Loss: 0.0005953554136794992
# Epoch 53, Average Loss: 0.0002767003526969347
# Epoch 54, Average Loss: 0.00028739950321323706
# Epoch 55, Average Loss: 0.00016463092306366888
# Epoch 56, Average Loss: 0.00017774972584447824
# Epoch 57, Average Loss: 0.0001240908255567774
# Epoch 58, Average Loss: 0.00010900212037086021
# Epoch 59, Average Loss: 7.509055503760465e-05
# Epoch 60, Average Loss: 5.053526892879745e-05
# Epoch 61, Average Loss: 5.0284619646845385e-05
# Epoch 62, Average Loss: 9.144542000285582e-05
# Epoch 63, Average Loss: 9.884997562039643e-05
# Epoch 64, Average Loss: 0.00011856916753458791
# Epoch 65, Average Loss: 0.00012279722050152487
# Epoch 66, Average Loss: 0.00014198730896168853
# Epoch 67, Average Loss: 8.984033629531041e-05
# Epoch 68, Average Loss: 7.335991895160988e-05
# Epoch 69, Average Loss: 4.0153843292500825e-05
# Epoch 70, Average Loss: 6.104768872319254e-05
# Epoch 71, Average Loss: 7.717604603385553e-05
# Epoch 72, Average Loss: 4.598077393893618e-05
# Epoch 73, Average Loss: 5.698753138858592e-05
# Epoch 74, Average Loss: 0.00013373642486840253
# Epoch 75, Average Loss: 0.00010760011646198109
# Epoch 76, Average Loss: 8.592034328103182e-05
# Epoch 77, Average Loss: 5.4938187713560185e-05
# Epoch 78, Average Loss: 8.125016420308384e-05
# Epoch 79, Average Loss: 0.0001190044353279518
# Epoch 80, Average Loss: 0.00010978480077028507
# Epoch 81, Average Loss: 0.00010685145753086545
# Epoch 82, Average Loss: 0.00010439405077704578
# Epoch 83, Average Loss: 8.078807404672261e-05
# Epoch 84, Average Loss: 0.00018206773602287286
# Epoch 85, Average Loss: 0.0003515434407745488
# Epoch 86, Average Loss: 0.00044028343982063236
# Epoch 87, Average Loss: 0.0004233103361912072
# Epoch 88, Average Loss: 0.0004474404213397065
# Epoch 89, Average Loss: 0.0004077209821844008
# Epoch 90, Average Loss: 0.0002627285990456585
# Epoch 91, Average Loss: 0.0005891497668926605
# Epoch 92, Average Loss: 0.0002633868618431734
# Epoch 93, Average Loss: 0.0002387457287113648
# Epoch 94, Average Loss: 0.0001137852546889917
# Epoch 95, Average Loss: 7.148132535803598e-05
# Epoch 96, Average Loss: 5.069737671874464e-05
# Epoch 97, Average Loss: 3.383639086678159e-05
# Epoch 98, Average Loss: 3.277955811427091e-05
# Epoch 99, Average Loss: 6.109271071181865e-05
# Epoch 100, Average Loss: 7.439753717335407e-05
# Epoch 1, Average Loss: 0.06300574736669659
# Epoch 2, Average Loss: 0.019668656610883774
# Epoch 3, Average Loss: 0.008652603381779044
# Epoch 4, Average Loss: 0.004603002674411982
# Epoch 5, Average Loss: 0.0040764717035926875
# Epoch 6, Average Loss: 0.003480354300700128
# Epoch 7, Average Loss: 0.0033214988419786096
# Epoch 8, Average Loss: 0.0031626658281311395
# Epoch 9, Average Loss: 0.0025880140485242007
# Epoch 10, Average Loss: 0.0021869092830456792
# Epoch 11, Average Loss: 0.0021402452897746117
# Epoch 12, Average Loss: 0.001625967855216004
# Epoch 13, Average Loss: 0.0012475790194002912
# Epoch 14, Average Loss: 0.001202979707159102
# Epoch 15, Average Loss: 0.0011893143964698538
# Epoch 16, Average Loss: 0.0010583068229607306
# Epoch 17, Average Loss: 0.000640576753357891
# Epoch 18, Average Loss: 0.0004444803184014745
# Epoch 19, Average Loss: 0.0003719898100825958
# Epoch 20, Average Loss: 0.00027496529510244726
# Epoch 21, Average Loss: 0.0003072967469051946
# Epoch 22, Average Loss: 0.00029430469730868937
# Epoch 23, Average Loss: 0.00034414830879541113
# Epoch 24, Average Loss: 0.00021960448066238314
# Epoch 25, Average Loss: 0.00018436958234815392
# Epoch 26, Average Loss: 0.0001699751228443347
# Epoch 27, Average Loss: 0.00016276001442747657
# Epoch 28, Average Loss: 0.00016000189316400792
# Epoch 29, Average Loss: 0.00016098510532174258
# Epoch 30, Average Loss: 0.00012029509271087591
# Epoch 31, Average Loss: 0.0001661360736761708
# Epoch 32, Average Loss: 0.00016425354879174848
# Epoch 33, Average Loss: 0.00014183487619447987
# Epoch 34, Average Loss: 0.00016810775778139942
# Epoch 35, Average Loss: 0.00014023302137502469
# Epoch 36, Average Loss: 7.617888877575751e-05
# Epoch 37, Average Loss: 8.160621691786219e-05
# Epoch 38, Average Loss: 0.00028553120155265787
# Epoch 39, Average Loss: 0.001022401468071621
# Epoch 40, Average Loss: 0.00041026807521120644
# Epoch 41, Average Loss: 0.00017488527555542532
# Epoch 42, Average Loss: 9.333195457656984e-05
# Epoch 43, Average Loss: 7.78377587266732e-05
# Epoch 44, Average Loss: 6.591073870367836e-05
# Epoch 45, Average Loss: 0.00010918144016613951
# Epoch 46, Average Loss: 5.5069871632440484e-05
# Epoch 47, Average Loss: 5.14144650878734e-05
# Epoch 48, Average Loss: 4.347674557720893e-05
# Epoch 49, Average Loss: 3.220686703571118e-05
# Epoch 50, Average Loss: 4.5090087041899096e-05
# Epoch 51, Average Loss: 8.392418903895305e-05
# Epoch 52, Average Loss: 6.407788951037218e-05
# Epoch 53, Average Loss: 4.512681407504715e-05
# Epoch 54, Average Loss: 5.76753904169891e-05
# Epoch 55, Average Loss: 3.896692869602703e-05
# Epoch 56, Average Loss: 3.0102027449174783e-05
# Epoch 57, Average Loss: 3.503545203784597e-05
# Epoch 58, Average Loss: 4.5324747316044525e-05
# Epoch 59, Average Loss: 6.131585150797037e-05
# Epoch 60, Average Loss: 7.667987574677682e-05
# Epoch 61, Average Loss: 8.858669925757568e-05
# Epoch 62, Average Loss: 0.00016974982518149772
# Epoch 63, Average Loss: 0.00024132024263963104
# Epoch 64, Average Loss: 0.00022396401545847765
# Epoch 65, Average Loss: 0.0002912739852035884
# Epoch 66, Average Loss: 0.0003635172048234381
# Epoch 67, Average Loss: 0.00017868889481178484
# Epoch 68, Average Loss: 0.00011224245572520886
# Epoch 69, Average Loss: 6.173521487653488e-05
# Epoch 70, Average Loss: 3.95713630496175e-05
# Epoch 71, Average Loss: 6.995362946327077e-05
# Epoch 72, Average Loss: 6.928411394255818e-05
# Epoch 73, Average Loss: 6.313136454991764e-05
# Epoch 74, Average Loss: 8.633861170892487e-05
# Epoch 75, Average Loss: 4.723943366116146e-05
# Epoch 76, Average Loss: 2.70510394784651e-05
# Epoch 77, Average Loss: 2.7656966904032742e-05
# Epoch 78, Average Loss: 4.677125525631709e-05
# Epoch 79, Average Loss: 3.801663960985024e-05
# Epoch 80, Average Loss: 3.4304388327655035e-05
# Epoch 81, Average Loss: 4.0685145631869093e-05
# Epoch 82, Average Loss: 2.3342295207839925e-05
# Epoch 83, Average Loss: 2.4272898235722097e-05
# Epoch 84, Average Loss: 2.0754884235429927e-05
# Epoch 85, Average Loss: 2.087311340801534e-05
# Epoch 86, Average Loss: 2.8283994015509962e-05
# Epoch 87, Average Loss: 5.189418470763485e-05
# Epoch 88, Average Loss: 2.3783008009559127e-05
# Epoch 89, Average Loss: 1.570008928410971e-05
# Epoch 90, Average Loss: 1.663546936470084e-05
# Epoch 91, Average Loss: 2.993566704390105e-05
# Epoch 92, Average Loss: 3.330343806737801e-05
# Epoch 93, Average Loss: 1.7149000905192223e-05
# Epoch 94, Average Loss: 3.617057400333579e-05
# Epoch 95, Average Loss: 4.2738420870591656e-05
# Epoch 96, Average Loss: 7.444040220434544e-05
# Epoch 97, Average Loss: 6.543736117237131e-05
# Epoch 98, Average Loss: 0.00013017325327382422
# Epoch 99, Average Loss: 0.00012964877805643482
# Epoch 100, Average Loss: 9.242919732059818e-05
# Epoch 1, Average Loss: 0.02670187405310571
# Epoch 2, Average Loss: 0.008123124798294157
# Epoch 3, Average Loss: 0.0035208148881793024
# Epoch 4, Average Loss: 0.0025321179418824613
# Epoch 5, Average Loss: 0.0019451560161542147
# Epoch 6, Average Loss: 0.0017621747858356685
# Epoch 7, Average Loss: 0.0019281882821815088
# Epoch 8, Average Loss: 0.0016055789194069803
# Epoch 9, Average Loss: 0.0011186725445440971
# Epoch 10, Average Loss: 0.0009182297784718685
# Epoch 11, Average Loss: 0.0007988368946826085
# Epoch 12, Average Loss: 0.000615362700773403
# Epoch 13, Average Loss: 0.00041689154168125244
# Epoch 14, Average Loss: 0.0003297223876870703
# Epoch 15, Average Loss: 0.00033636546504567377
# Epoch 16, Average Loss: 0.0002975667106511537
# Epoch 17, Average Loss: 0.0004207334866805468
# Epoch 18, Average Loss: 0.000334443588508293
# Epoch 19, Average Loss: 0.00019137027193210087
# Epoch 20, Average Loss: 0.00014002617972437293
# Epoch 21, Average Loss: 0.00011495462931634392
# Epoch 22, Average Loss: 0.00014599601108784556
# Epoch 23, Average Loss: 0.00015608461289957632
# Epoch 24, Average Loss: 0.00014696987855131738
# Epoch 25, Average Loss: 0.0001051431876476272
# Epoch 26, Average Loss: 9.51477921262267e-05
# Epoch 27, Average Loss: 9.172262507490813e-05
# Epoch 28, Average Loss: 8.984763044281863e-05
# Epoch 29, Average Loss: 5.964851807220839e-05
# Epoch 30, Average Loss: 7.169716118369252e-05
# Epoch 31, Average Loss: 9.816129368118709e-05
# Epoch 32, Average Loss: 5.972590342935291e-05
# Epoch 33, Average Loss: 4.926116953356541e-05
# Epoch 34, Average Loss: 5.2475693337328266e-05
# Epoch 35, Average Loss: 6.436676148950937e-05
# Epoch 36, Average Loss: 6.143268055893713e-05
# Epoch 37, Average Loss: 9.115728398683132e-05
# Epoch 38, Average Loss: 0.00010716673041315517
# Epoch 39, Average Loss: 7.635202537130681e-05
# Epoch 40, Average Loss: 5.843377839482855e-05
# Epoch 41, Average Loss: 4.976650179742137e-05
# Epoch 42, Average Loss: 4.735968050226802e-05
# Epoch 43, Average Loss: 2.52962177455629e-05
# Epoch 44, Average Loss: 1.9954686922574184e-05
# Epoch 45, Average Loss: 2.4479003786836984e-05
# Epoch 46, Average Loss: 2.4433456928818487e-05
# Epoch 47, Average Loss: 3.449969726716517e-05
# Epoch 48, Average Loss: 4.0330899309992674e-05
# Epoch 49, Average Loss: 2.5286706659244373e-05
# Epoch 50, Average Loss: 2.0680435864051105e-05
# Epoch 51, Average Loss: 3.242895227231202e-05
# Epoch 52, Average Loss: 2.4706542626518056e-05
# Epoch 53, Average Loss: 1.8547668037172117e-05
# Epoch 54, Average Loss: 2.79809429684974e-05
# Epoch 55, Average Loss: 7.30811087123584e-05
# Epoch 56, Average Loss: 3.193496436324494e-05
# Epoch 57, Average Loss: 4.1728619362402244e-05
# Epoch 58, Average Loss: 3.579987046578026e-05
# Epoch 59, Average Loss: 3.5425260557531145e-05
# Epoch 60, Average Loss: 3.389485646039247e-05
# Epoch 61, Average Loss: 6.735556216881377e-05
# Epoch 62, Average Loss: 5.53572824173898e-05
# Epoch 63, Average Loss: 4.357897896625218e-05
# Epoch 64, Average Loss: 2.841165614881902e-05
# Epoch 65, Average Loss: 3.37109776410216e-05
# Epoch 66, Average Loss: 4.106600381419412e-05
# Epoch 67, Average Loss: 7.06007319422497e-05
# Epoch 68, Average Loss: 6.267584913075553e-05
# Epoch 69, Average Loss: 2.993767625412147e-05
# Epoch 70, Average Loss: 4.6368708899535706e-05
# Epoch 71, Average Loss: 7.118454022929655e-05
# Epoch 72, Average Loss: 6.411939330064342e-05
# Epoch 73, Average Loss: 2.014556309859472e-05
# Epoch 74, Average Loss: 2.9433975942083635e-05
# Epoch 75, Average Loss: 1.987442819881835e-05
# Epoch 76, Average Loss: 3.117038509117265e-05
# Epoch 77, Average Loss: 3.9035700115164215e-05
# Epoch 78, Average Loss: 5.996642230456928e-05
# Epoch 79, Average Loss: 2.486499106453266e-05
# Epoch 80, Average Loss: 1.6977469749690498e-05
# Epoch 81, Average Loss: 2.65416405909491e-05
# Epoch 82, Average Loss: 4.0280100256495645e-05
# Epoch 83, Average Loss: 6.476493290392682e-05
# Epoch 84, Average Loss: 5.297709021760966e-05
# Epoch 85, Average Loss: 6.156584586278769e-05
# Epoch 86, Average Loss: 5.1818624342558905e-05
# Epoch 87, Average Loss: 4.182619763923867e-05
# Epoch 88, Average Loss: 3.2043556620919845e-05
# Epoch 89, Average Loss: 3.2085382031254994e-05
# Epoch 90, Average Loss: 2.359270911256317e-05
# Epoch 91, Average Loss: 2.001915254368214e-05
# Epoch 92, Average Loss: 5.127378481120104e-05
# Epoch 93, Average Loss: 6.783318831367069e-05
# Epoch 94, Average Loss: 3.982857106166193e-05
# Epoch 95, Average Loss: 3.5265330188849477e-05
# Epoch 96, Average Loss: 2.658768121364119e-05
# Epoch 97, Average Loss: 5.8726509269035884e-05
# Epoch 98, Average Loss: 3.0088997391430894e-05
# Epoch 99, Average Loss: 3.096906716564263e-05
# Epoch 100, Average Loss: 5.439102319542144e-05
# Epoch 1, Average Loss: 0.07119896532967687
# Epoch 2, Average Loss: 0.007271223596762866
# Epoch 3, Average Loss: 0.0021614617260638626
# Epoch 4, Average Loss: 0.000871312161325477
# Epoch 5, Average Loss: 0.000469708455784712
# Epoch 6, Average Loss: 0.0003856546099996194
# Epoch 7, Average Loss: 0.00033592049367143774
# Epoch 8, Average Loss: 0.000316440430469811
# Epoch 9, Average Loss: 0.00027858385947183707
# Epoch 10, Average Loss: 0.00030644220823887735
# Epoch 11, Average Loss: 0.00024522615130990745
# Epoch 12, Average Loss: 0.00020613803062587976
# Epoch 13, Average Loss: 0.0002373389943386428
# Epoch 14, Average Loss: 0.00020793491312360858
# Epoch 15, Average Loss: 0.00019315921817906201
# Epoch 16, Average Loss: 0.00018782132901833392
# Epoch 17, Average Loss: 0.00014827726408839226
# Epoch 18, Average Loss: 0.0001391413992678281
# Epoch 19, Average Loss: 0.00016725555578886997
# Epoch 20, Average Loss: 0.00014293073618318886
# Epoch 21, Average Loss: 0.00012527841536211782
# Epoch 22, Average Loss: 0.00012134648841310991
# Epoch 23, Average Loss: 0.0001447067053959472
# Epoch 24, Average Loss: 0.00011782628625951474
# Epoch 25, Average Loss: 0.00012595474399859085
# Epoch 26, Average Loss: 0.00017077885295293526
# Epoch 27, Average Loss: 0.00012583509742398747
# Epoch 28, Average Loss: 7.021387418717495e-05
# Epoch 29, Average Loss: 6.589631884708069e-05
# Epoch 30, Average Loss: 9.102037838601973e-05
# Epoch 31, Average Loss: 0.0001462846623326186
# Epoch 32, Average Loss: 0.00010106356194228283
# Epoch 33, Average Loss: 6.853236682218267e-05
# Epoch 34, Average Loss: 5.2290036728663834e-05
# Epoch 35, Average Loss: 5.103453167976113e-05
# Epoch 36, Average Loss: 5.2178933310642604e-05
# Epoch 37, Average Loss: 6.336937867672532e-05
# Epoch 38, Average Loss: 0.00010193934231210733
# Epoch 39, Average Loss: 8.613911631982774e-05
# Epoch 40, Average Loss: 7.44515708902327e-05
# Epoch 41, Average Loss: 4.455463399608561e-05
# Epoch 42, Average Loss: 6.133391352705075e-05
# Epoch 43, Average Loss: 4.213369966237224e-05
# Epoch 44, Average Loss: 4.3433820883365117e-05
# Epoch 45, Average Loss: 4.2147260683123025e-05
# Epoch 46, Average Loss: 4.3228295544395225e-05
# Epoch 47, Average Loss: 3.214598996237328e-05
# Epoch 48, Average Loss: 3.8548180327779846e-05
# Epoch 49, Average Loss: 4.3459824883029793e-05
# Epoch 50, Average Loss: 3.7272871759341796e-05
# Epoch 51, Average Loss: 3.771228612095001e-05
# Epoch 52, Average Loss: 3.511911681925994e-05
# Epoch 53, Average Loss: 6.138971166365081e-05
# Epoch 54, Average Loss: 7.316081091630622e-05
# Epoch 55, Average Loss: 3.954664007324027e-05
# Epoch 56, Average Loss: 4.2635961290216076e-05
# Epoch 57, Average Loss: 4.9908563869394126e-05
# Epoch 58, Average Loss: 7.987022509041708e-05
# Epoch 59, Average Loss: 0.00010634867430781014
# Epoch 60, Average Loss: 9.08807272935519e-05
# Epoch 61, Average Loss: 7.736650377410115e-05
# Epoch 62, Average Loss: 7.382735620922176e-05
# Epoch 63, Average Loss: 4.775150182467769e-05
# Epoch 64, Average Loss: 3.9976389507501155e-05
# Epoch 65, Average Loss: 3.305879818071844e-05
# Epoch 66, Average Loss: 3.480287150523509e-05
# Epoch 67, Average Loss: 2.850528671842767e-05
# Epoch 68, Average Loss: 3.567705448404013e-05
# Epoch 69, Average Loss: 6.932639143997221e-05
# Epoch 70, Average Loss: 6.045069112587953e-05
# Epoch 71, Average Loss: 3.829900078926585e-05
# Epoch 72, Average Loss: 4.892062152066501e-05
# Epoch 73, Average Loss: 6.471828510257183e-05
# Epoch 74, Average Loss: 3.843432177745854e-05
# Epoch 75, Average Loss: 3.358949643370579e-05
# Epoch 76, Average Loss: 2.709575269363995e-05
# Epoch 77, Average Loss: 3.371149941813201e-05
# Epoch 78, Average Loss: 4.206110893392179e-05
# Epoch 79, Average Loss: 4.099464981663914e-05
# Epoch 80, Average Loss: 4.548617603177263e-05
# Epoch 81, Average Loss: 6.841911426818115e-05
# Epoch 82, Average Loss: 2.9944115522084757e-05
# Epoch 83, Average Loss: 2.7983850577584236e-05
# Epoch 84, Average Loss: 3.327433601043595e-05
# Epoch 85, Average Loss: 2.4389115333178778e-05
# Epoch 86, Average Loss: 2.3123908113120707e-05
# Epoch 87, Average Loss: 2.029777324423776e-05
# Epoch 88, Average Loss: 2.8361323074932443e-05
# Epoch 89, Average Loss: 4.264962908564485e-05
# Epoch 90, Average Loss: 3.776369276238256e-05
# Epoch 91, Average Loss: 3.0528504157700806e-05
# Epoch 92, Average Loss: 3.1925227131068826e-05
# Epoch 93, Average Loss: 3.0560618779418294e-05
# Epoch 94, Average Loss: 2.914136225626862e-05
# Epoch 95, Average Loss: 3.312131802886142e-05
# Epoch 96, Average Loss: 2.9108676835676305e-05
# Epoch 97, Average Loss: 2.3819507805455942e-05
# Epoch 98, Average Loss: 5.248030338407261e-05
# Epoch 99, Average Loss: 5.9719062846852466e-05
# Epoch 100, Average Loss: 4.300500395402196e-05
# Epoch 1, Average Loss: 0.020336311089340597
# Epoch 2, Average Loss: 0.001941959504620172
# Epoch 3, Average Loss: 0.000556424017122481
# Epoch 4, Average Loss: 0.0001751646530465223
# Epoch 5, Average Loss: 4.852685860896599e-05
# Epoch 6, Average Loss: 2.1511969953280642e-05
# Epoch 7, Average Loss: 1.2400975174386986e-05
# Epoch 8, Average Loss: 7.491592282349302e-06
# Epoch 9, Average Loss: 6.3580229380022505e-06
# Epoch 10, Average Loss: 5.251290110663831e-06
# Epoch 11, Average Loss: 4.506160792061564e-06
# Epoch 12, Average Loss: 3.2751145226939116e-06
# Epoch 13, Average Loss: 2.759940355190338e-06
# Epoch 14, Average Loss: 3.13383185357452e-06
# Epoch 15, Average Loss: 2.606028226637136e-06
# Epoch 16, Average Loss: 2.64741154865078e-06
# Epoch 17, Average Loss: 2.7489832120863867e-06
# Epoch 18, Average Loss: 2.0218258725890336e-06
# Epoch 19, Average Loss: 1.8352927611431368e-06
# Epoch 20, Average Loss: 1.5283442223790188e-06
# Epoch 21, Average Loss: 1.7377615279201565e-06
# Epoch 22, Average Loss: 1.8745342174497636e-06
# Epoch 23, Average Loss: 2.3511609242632402e-06
# Epoch 24, Average Loss: 2.0708974176386618e-06
# Epoch 25, Average Loss: 1.8467268603217235e-06
# Epoch 26, Average Loss: 1.4082376054602718e-06
# Epoch 27, Average Loss: 1.1799358475172994e-06
# Epoch 28, Average Loss: 9.763519784655727e-07
# Epoch 29, Average Loss: 7.769787046640886e-07
# Epoch 30, Average Loss: 8.248254829368306e-07
# Epoch 31, Average Loss: 1.0314797265209563e-06
# Epoch 32, Average Loss: 8.378028155675565e-07
# Epoch 33, Average Loss: 8.89102994960922e-07
# Epoch 34, Average Loss: 8.691341733424451e-07
# Epoch 35, Average Loss: 1.951501886310325e-06
# Epoch 36, Average Loss: 1.1970674393069204e-06
# Epoch 37, Average Loss: 2.189494909998757e-06
# Epoch 38, Average Loss: 3.1751874132623927e-06
# Epoch 39, Average Loss: 2.2831143041912584e-06
# Epoch 40, Average Loss: 2.061866007352364e-06
# Epoch 41, Average Loss: 9.443457230418062e-07
# Epoch 42, Average Loss: 8.111793235343611e-07
# Epoch 43, Average Loss: 8.655982895788839e-07
# Epoch 44, Average Loss: 8.376975429769118e-07
# Epoch 45, Average Loss: 9.913765438795964e-07
# Epoch 46, Average Loss: 8.502060907744635e-07
# Epoch 47, Average Loss: 4.4190555712475545e-07
# Epoch 48, Average Loss: 5.324374527049258e-07
# Epoch 49, Average Loss: 5.772897722522429e-07
# Epoch 50, Average Loss: 7.458245818270371e-07
# Epoch 51, Average Loss: 4.066530088664422e-07
# Epoch 52, Average Loss: 2.6646387894402325e-06
# Epoch 53, Average Loss: 9.667794586221135e-06
# Epoch 54, Average Loss: 4.192691085336264e-06
# Epoch 55, Average Loss: 2.886017125547369e-06
# Epoch 56, Average Loss: 2.932877191597072e-06
# Epoch 57, Average Loss: 2.0209767853884842e-06
# Epoch 58, Average Loss: 3.1067648592397744e-06
# Epoch 59, Average Loss: 1.868875520472102e-06
# Epoch 60, Average Loss: 2.2937424589031254e-06
# Epoch 61, Average Loss: 3.6947905613260447e-06
# Epoch 62, Average Loss: 3.1041811979548583e-06
# Epoch 63, Average Loss: 3.3440905042425582e-06
# Epoch 64, Average Loss: 1.6715681255163872e-06
# Epoch 65, Average Loss: 9.527191934921575e-07
# Epoch 66, Average Loss: 2.0471951444278603e-06
# Epoch 67, Average Loss: 2.421472274249936e-06
# Epoch 68, Average Loss: 3.674297317957098e-06
# Epoch 69, Average Loss: 3.7644782949541876e-06
# Epoch 70, Average Loss: 5.187560566355387e-06
# Epoch 71, Average Loss: 1.3080264380960216e-06
# Epoch 72, Average Loss: 4.067412632480227e-07
# Epoch 73, Average Loss: 4.769613610733359e-07
# Epoch 74, Average Loss: 8.53525735067251e-07
# Epoch 75, Average Loss: 1.1587398120127546e-06
# Epoch 76, Average Loss: 1.880631007793454e-05
# Epoch 77, Average Loss: 3.260333430716855e-05
# Epoch 78, Average Loss: 5.4014774923416554e-05
# Epoch 79, Average Loss: 7.565243968201684e-05
# Epoch 80, Average Loss: 7.340852425841149e-05
# Epoch 81, Average Loss: 1.4698743927965553e-05
# Epoch 82, Average Loss: 7.242095568926743e-06
# Epoch 83, Average Loss: 2.06796889585803e-06
# Epoch 84, Average Loss: 7.921381978803766e-07
# Epoch 85, Average Loss: 5.903963440800907e-07
# Epoch 86, Average Loss: 5.549930691017834e-07
# Epoch 87, Average Loss: 6.612601964661735e-07
# Epoch 88, Average Loss: 8.329054558942062e-07
# Epoch 89, Average Loss: 6.660839204641889e-07
# Epoch 90, Average Loss: 5.549043621044803e-07
# Epoch 91, Average Loss: 9.601049420382423e-07
# Epoch 92, Average Loss: 1.6207740628715329e-06
# Epoch 93, Average Loss: 7.390699991560723e-07
# Epoch 94, Average Loss: 3.761198712481928e-07
# Epoch 95, Average Loss: 3.6864093218014203e-07
# Epoch 96, Average Loss: 2.6876284238142033e-07
# Epoch 97, Average Loss: 4.20064118600294e-07
# Epoch 98, Average Loss: 4.513630088354148e-07
# Epoch 99, Average Loss: 4.350055839097422e-07
# Epoch 100, Average Loss: 3.062865967962125e-07
# Epoch 1, Average Loss: 0.007837405218742788
# Epoch 2, Average Loss: 0.0007131072408810724
# Epoch 3, Average Loss: 0.00023425546278303954
# Epoch 4, Average Loss: 7.96365640781005e-05
# Epoch 5, Average Loss: 2.789059358292434e-05
# Epoch 6, Average Loss: 1.0696224967432499e-05
# Epoch 7, Average Loss: 5.486543705046642e-06
# Epoch 8, Average Loss: 3.956434750307381e-06
# Epoch 9, Average Loss: 3.3626424624344507e-06
# Epoch 10, Average Loss: 3.1418065077559732e-06
# Epoch 11, Average Loss: 3.5200610170704747e-06
# Epoch 12, Average Loss: 2.762789330290616e-06
# Epoch 13, Average Loss: 2.3398705423005594e-06
# Epoch 14, Average Loss: 2.3065689163104253e-06
# Epoch 15, Average Loss: 1.9834930753859227e-06
# Epoch 16, Average Loss: 1.7719840343488614e-06
# Epoch 17, Average Loss: 1.6259000005902636e-06
# Epoch 18, Average Loss: 1.7673929960437817e-06
# Epoch 19, Average Loss: 1.5569272079574149e-06
# Epoch 20, Average Loss: 1.7463054405197908e-06
# Epoch 21, Average Loss: 1.8190452863109386e-06
# Epoch 22, Average Loss: 1.5128962104427047e-06
# Epoch 23, Average Loss: 1.5444420711219209e-06
# Epoch 24, Average Loss: 1.2025026563833307e-06
# Epoch 25, Average Loss: 9.384138508039542e-07
# Epoch 26, Average Loss: 8.750102267640613e-07
# Epoch 27, Average Loss: 1.1587657297695842e-06
# Epoch 28, Average Loss: 1.7977569456206765e-06
# Epoch 29, Average Loss: 1.391846998899382e-06
# Epoch 30, Average Loss: 1.6460983786714678e-06
# Epoch 31, Average Loss: 1.6028571891979482e-06
# Epoch 32, Average Loss: 2.1851886799595375e-06
# Epoch 33, Average Loss: 1.9995716797893692e-06
# Epoch 34, Average Loss: 1.4395288786772654e-06
# Epoch 35, Average Loss: 8.912865610000154e-07
# Epoch 36, Average Loss: 1.0397613067425483e-06
# Epoch 37, Average Loss: 1.4407495172008567e-06
# Epoch 38, Average Loss: 1.5430680718964141e-06
# Epoch 39, Average Loss: 1.2937592671846688e-06
# Epoch 40, Average Loss: 1.0912436266607982e-06
# Epoch 41, Average Loss: 2.0567933518123025e-06
# Epoch 42, Average Loss: 9.82710116659291e-07
# Epoch 43, Average Loss: 1.0755579410215431e-06
# Epoch 44, Average Loss: 7.163538910504031e-07
# Epoch 45, Average Loss: 4.3812969039436214e-07
# Epoch 46, Average Loss: 7.324674392350517e-07
# Epoch 47, Average Loss: 7.680672069909633e-07
# Epoch 48, Average Loss: 6.521845349993783e-07
# Epoch 49, Average Loss: 7.199501496302218e-07
# Epoch 50, Average Loss: 3.614208935687202e-07
# Epoch 51, Average Loss: 2.95581184417415e-07
# Epoch 52, Average Loss: 3.748510806644845e-07
# Epoch 53, Average Loss: 8.295412698089421e-07
# Epoch 54, Average Loss: 8.800265703712285e-07
# Epoch 55, Average Loss: 5.791069014549066e-07
# Epoch 56, Average Loss: 1.2620365154702995e-06
# Epoch 57, Average Loss: 3.762427763831511e-06
# Epoch 58, Average Loss: 3.126181900370284e-06
# Epoch 59, Average Loss: 1.8094998040396603e-06
# Epoch 60, Average Loss: 7.860160962991358e-07
# Epoch 61, Average Loss: 8.094542738490419e-06
# Epoch 62, Average Loss: 6.132040272177619e-06
# Epoch 63, Average Loss: 6.524062445123491e-06
# Epoch 64, Average Loss: 4.389165735574352e-06
# Epoch 65, Average Loss: 3.077186423183775e-06
# Epoch 66, Average Loss: 1.3960554142045111e-06
# Epoch 67, Average Loss: 1.0612935881226804e-06
# Epoch 68, Average Loss: 6.74202357942022e-07
# Epoch 69, Average Loss: 1.9250519386559973e-06
# Epoch 70, Average Loss: 7.224887454526652e-07
# Epoch 71, Average Loss: 8.061375211809718e-07
# Epoch 72, Average Loss: 1.2329750319395315e-06
# Epoch 73, Average Loss: 9.255444567202176e-07
# Epoch 74, Average Loss: 1.9597094365053636e-06
# Epoch 75, Average Loss: 2.9343827918637544e-06
# Epoch 76, Average Loss: 3.0725817850907332e-06
# Epoch 77, Average Loss: 1.7339155675699658e-06
# Epoch 78, Average Loss: 1.9180910555860466e-06
# Epoch 79, Average Loss: 5.023372813184323e-06
# Epoch 80, Average Loss: 1.981550070695448e-06
# Epoch 81, Average Loss: 1.955186911573037e-06
# Epoch 82, Average Loss: 4.390157766920311e-06
# Epoch 83, Average Loss: 3.989301995943606e-06
# Epoch 84, Average Loss: 1.1408430270876125e-05
# Epoch 85, Average Loss: 1.821021187424776e-05
# Epoch 86, Average Loss: 0.00019690168301167432
# Epoch 87, Average Loss: 0.00023545396925328532
# Epoch 88, Average Loss: 0.00013291229697642848
# Epoch 89, Average Loss: 7.711694829595216e-05
# Epoch 90, Average Loss: 1.6668717853463023e-05
# Epoch 91, Average Loss: 8.41201805314995e-06
# Epoch 92, Average Loss: 4.528776969436876e-06
# Epoch 93, Average Loss: 2.5542164451053394e-06
# Epoch 94, Average Loss: 2.694220216881149e-06
# Epoch 95, Average Loss: 2.070755363092758e-06
# Epoch 96, Average Loss: 1.5099584743438753e-06
# Epoch 97, Average Loss: 1.9432584991818656e-06
# Epoch 98, Average Loss: 1.3091610242099705e-06
# Epoch 99, Average Loss: 1.5260662053151464e-06
# Epoch 100, Average Loss: 1.1459126014301547e-06
# Epoch 1, Average Loss: 0.02044975316384807
# Epoch 2, Average Loss: 0.0021310648211510853
# Epoch 3, Average Loss: 0.0004382909952255432
# Epoch 4, Average Loss: 0.00019832471189147328
# Epoch 5, Average Loss: 0.00016319597671099473
# Epoch 6, Average Loss: 0.00014821297663729637
# Epoch 7, Average Loss: 0.000142772378421796
# Epoch 8, Average Loss: 0.00013272555988805835
# Epoch 9, Average Loss: 0.00013129369726812002
# Epoch 10, Average Loss: 0.00012579992380779004
# Epoch 11, Average Loss: 0.000128493272131891
# Epoch 12, Average Loss: 0.00012566615514515435
# Epoch 13, Average Loss: 0.00010244951899949229
# Epoch 14, Average Loss: 8.681460039952071e-05
# Epoch 15, Average Loss: 9.515860547253397e-05
# Epoch 16, Average Loss: 8.065727306529879e-05
# Epoch 17, Average Loss: 7.205752244772156e-05
# Epoch 18, Average Loss: 5.677794815710513e-05
# Epoch 19, Average Loss: 5.361917428672314e-05
# Epoch 20, Average Loss: 4.5510917061619693e-05
# Epoch 21, Average Loss: 4.273322119843215e-05
# Epoch 22, Average Loss: 3.465747731752344e-05
# Epoch 23, Average Loss: 3.847578427667031e-05
# Epoch 24, Average Loss: 4.580959002851159e-05
# Epoch 25, Average Loss: 3.483435793896206e-05
# Epoch 26, Average Loss: 3.989165138591488e-05
# Epoch 27, Average Loss: 3.32467267071479e-05
# Epoch 28, Average Loss: 4.0018390154727965e-05
# Epoch 29, Average Loss: 3.0497917578031775e-05
# Epoch 30, Average Loss: 3.2445976285089276e-05
# Epoch 31, Average Loss: 2.6257538547724834e-05
# Epoch 32, Average Loss: 2.571133763922262e-05
# Epoch 33, Average Loss: 2.460550031173625e-05
# Epoch 34, Average Loss: 1.981630380214483e-05
# Epoch 35, Average Loss: 3.901637783201295e-05
# Epoch 36, Average Loss: 3.3828198047558546e-05
# Epoch 37, Average Loss: 2.4538560728615268e-05
# Epoch 38, Average Loss: 1.750758715388656e-05
# Epoch 39, Average Loss: 1.825383346840681e-05
# Epoch 40, Average Loss: 3.0081944623816524e-05
# Epoch 41, Average Loss: 3.555298781066085e-05
# Epoch 42, Average Loss: 2.8796339665859706e-05
# Epoch 43, Average Loss: 2.5093204521908773e-05
# Epoch 44, Average Loss: 4.0276795243698873e-05
# Epoch 45, Average Loss: 5.34869781404268e-05
# Epoch 46, Average Loss: 7.313787882594625e-05
# Epoch 47, Average Loss: 5.579652138294477e-05
# Epoch 48, Average Loss: 2.437353514324059e-05
# Epoch 49, Average Loss: 2.226156861979689e-05
# Epoch 50, Average Loss: 2.228855985322298e-05
# Epoch 51, Average Loss: 2.618851531224209e-05
# Epoch 52, Average Loss: 1.7645376283326185e-05
# Epoch 53, Average Loss: 2.2696567793900612e-05
# Epoch 54, Average Loss: 2.384301333222538e-05
# Epoch 55, Average Loss: 1.539188990591356e-05
# Epoch 56, Average Loss: 1.993771759316587e-05
# Epoch 57, Average Loss: 1.6466719353047664e-05
# Epoch 58, Average Loss: 1.86777064755006e-05
# Epoch 59, Average Loss: 1.503279636381194e-05
# Epoch 60, Average Loss: 2.2183468945513597e-05
# Epoch 61, Average Loss: 2.2768610187995363e-05
# Epoch 62, Average Loss: 1.7802890033635778e-05
# Epoch 63, Average Loss: 1.2821119798900327e-05
# Epoch 64, Average Loss: 1.2576929111673963e-05
# Epoch 65, Average Loss: 1.2857588944825694e-05
# Epoch 66, Average Loss: 1.4567375001206528e-05
# Epoch 67, Average Loss: 1.682437259660219e-05
# Epoch 68, Average Loss: 1.5384834773612967e-05
# Epoch 69, Average Loss: 1.3632702439281274e-05
# Epoch 70, Average Loss: 1.5026386222416477e-05
# Epoch 71, Average Loss: 1.7021480243784026e-05
# Epoch 72, Average Loss: 1.8382898269919677e-05
# Epoch 73, Average Loss: 6.81650736623851e-05
# Epoch 74, Average Loss: 0.00014781222816964145
# Epoch 75, Average Loss: 5.728888463636394e-05
# Epoch 76, Average Loss: 3.205215189154842e-05
# Epoch 77, Average Loss: 3.306176618025347e-05
# Epoch 78, Average Loss: 1.9752545654228015e-05
# Epoch 79, Average Loss: 1.1776688779718825e-05
# Epoch 80, Average Loss: 1.292471090437175e-05
# Epoch 81, Average Loss: 9.841829046308703e-06
# Epoch 82, Average Loss: 1.862093465661019e-05
# Epoch 83, Average Loss: 3.3547868542882495e-05
# Epoch 84, Average Loss: 1.5194332047485658e-05
# Epoch 85, Average Loss: 9.717018565424951e-06
# Epoch 86, Average Loss: 1.0524264644118375e-05
# Epoch 87, Average Loss: 1.4627109862885845e-05
# Epoch 88, Average Loss: 1.4977044236275105e-05
# Epoch 89, Average Loss: 9.820002469496103e-06
# Epoch 90, Average Loss: 1.3633478374686092e-05
# Epoch 91, Average Loss: 8.919573792809387e-06
# Epoch 92, Average Loss: 1.0113443443060532e-05
# Epoch 93, Average Loss: 1.9557188988983398e-05
# Epoch 94, Average Loss: 1.982451174171729e-05
# Epoch 95, Average Loss: 1.1746082134322932e-05
# Epoch 96, Average Loss: 9.236362268438825e-06
# Epoch 97, Average Loss: 1.3171386422072829e-05
# Epoch 98, Average Loss: 1.2568668216772494e-05
# Epoch 99, Average Loss: 8.963817344920244e-06
# Epoch 100, Average Loss: 8.814897489628492e-06
# Epoch 1, Average Loss: 0.0076772371889092025
# Epoch 2, Average Loss: 0.0008462224650429562
# Epoch 3, Average Loss: 0.00023399821693601553
# Epoch 4, Average Loss: 0.0001044182285113493
# Epoch 5, Average Loss: 3.351588702571462e-05
# Epoch 6, Average Loss: 1.4599982910112885e-05
# Epoch 7, Average Loss: 7.896482100022694e-06
# Epoch 8, Average Loss: 4.296185079510906e-06
# Epoch 9, Average Loss: 3.5359430853532104e-06
# Epoch 10, Average Loss: 2.9038167554062967e-06
# Epoch 11, Average Loss: 3.181971186450028e-06
# Epoch 12, Average Loss: 2.565426854062025e-06
# Epoch 13, Average Loss: 2.3298479220557057e-06
# Epoch 14, Average Loss: 2.1941855607110484e-06
# Epoch 15, Average Loss: 1.975591754899142e-06
# Epoch 16, Average Loss: 1.827833949619162e-06
# Epoch 17, Average Loss: 1.857553155559799e-06
# Epoch 18, Average Loss: 1.5018563345847725e-06
# Epoch 19, Average Loss: 1.850694926019969e-06
# Epoch 20, Average Loss: 1.635356096585383e-06
# Epoch 21, Average Loss: 1.5153653890820352e-06
# Epoch 22, Average Loss: 1.3828271931970448e-06
# Epoch 23, Average Loss: 1.6380534049176276e-06
# Epoch 24, Average Loss: 1.5237288096159318e-06
# Epoch 25, Average Loss: 1.8832325054063404e-06
# Epoch 26, Average Loss: 1.0935820029089883e-06
# Epoch 27, Average Loss: 1.5658582185551496e-06
# Epoch 28, Average Loss: 1.1726325055860797e-06
# Epoch 29, Average Loss: 1.4115208529119627e-06
# Epoch 30, Average Loss: 1.692349610493693e-06
# Epoch 31, Average Loss: 1.0898126532765672e-06
# Epoch 32, Average Loss: 9.76902640559274e-07
# Epoch 33, Average Loss: 9.630657231696205e-07
# Epoch 34, Average Loss: 1.1895287173047109e-06
# Epoch 35, Average Loss: 1.5045211640085655e-06
# Epoch 36, Average Loss: 1.099415041494467e-06
# Epoch 37, Average Loss: 6.164941524389178e-07
# Epoch 38, Average Loss: 5.385538727864514e-07
# Epoch 39, Average Loss: 9.765942365902447e-07
# Epoch 40, Average Loss: 1.370615697737776e-06
# Epoch 41, Average Loss: 9.922256481331714e-07
# Epoch 42, Average Loss: 6.204690023992043e-07
# Epoch 43, Average Loss: 9.007212995015835e-07
# Epoch 44, Average Loss: 9.897259459989983e-07
# Epoch 45, Average Loss: 1.1238945532454636e-06
# Epoch 46, Average Loss: 2.094096646487742e-06
# Epoch 47, Average Loss: 1.9774422582941043e-06
# Epoch 48, Average Loss: 4.907469826775923e-06
# Epoch 49, Average Loss: 3.992537517660821e-06
# Epoch 50, Average Loss: 3.2054393471980803e-06
# Epoch 51, Average Loss: 9.934214901363703e-07
# Epoch 52, Average Loss: 9.292257672655068e-07
# Epoch 53, Average Loss: 8.20332321893602e-07
# Epoch 54, Average Loss: 8.011482236724987e-07
# Epoch 55, Average Loss: 9.656096409571546e-07
# Epoch 56, Average Loss: 1.0177907626029991e-06
# Epoch 57, Average Loss: 7.664899598580632e-07
# Epoch 58, Average Loss: 7.200831390719032e-07
# Epoch 59, Average Loss: 1.2892634131844715e-06
# Epoch 60, Average Loss: 1.081490818819475e-05
# Epoch 61, Average Loss: 7.871797402003722e-06
# Epoch 62, Average Loss: 2.368639703718145e-05
# Epoch 63, Average Loss: 1.6349798204373656e-05
# Epoch 64, Average Loss: 6.891179532431125e-06
# Epoch 65, Average Loss: 3.7131128181044915e-06
# Epoch 66, Average Loss: 4.781492705774326e-06
# Epoch 67, Average Loss: 7.737678299690742e-06
# Epoch 68, Average Loss: 2.3391448820575535e-06
# Epoch 69, Average Loss: 1.7180371202130117e-06
# Epoch 70, Average Loss: 1.3168906605187658e-06
# Epoch 71, Average Loss: 2.5358491910765224e-06
# Epoch 72, Average Loss: 4.2363710520021415e-06
# Epoch 73, Average Loss: 1.7432861824318025e-06
# Epoch 74, Average Loss: 6.472418689895676e-07
# Epoch 75, Average Loss: 2.922165185736958e-06
# Epoch 76, Average Loss: 6.790231208242403e-06
# Epoch 77, Average Loss: 3.166329361192766e-06
# Epoch 78, Average Loss: 4.888178793294173e-06
# Epoch 79, Average Loss: 7.789061567109456e-06
# Epoch 80, Average Loss: 1.1895483874013735e-05
# Epoch 81, Average Loss: 7.861576432333094e-06
# Epoch 82, Average Loss: 5.90342957593748e-06
# Epoch 83, Average Loss: 5.376696060466202e-06
# Epoch 84, Average Loss: 1.6312566657461502e-06
# Epoch 85, Average Loss: 1.3700366054081315e-06
# Epoch 86, Average Loss: 2.433539160051623e-06
# Epoch 87, Average Loss: 2.0815839548049555e-06
# Epoch 88, Average Loss: 1.59370029564343e-06
# Epoch 89, Average Loss: 4.661600328859095e-06
# Epoch 90, Average Loss: 5.890823911158805e-06
# Epoch 91, Average Loss: 1.0691280328956054e-05
# Epoch 92, Average Loss: 9.709193028584195e-06
# Epoch 93, Average Loss: 1.7573416414506937e-05
# Epoch 94, Average Loss: 7.86835200869973e-06
# Epoch 95, Average Loss: 1.782850263225555e-05
# Epoch 96, Average Loss: 3.552151956682792e-05
# Epoch 97, Average Loss: 2.714454976739944e-05
# Epoch 98, Average Loss: 2.6884318094744232e-05
# Epoch 99, Average Loss: 2.676757624158199e-05
# Epoch 100, Average Loss: 1.5525350977441122e-05
# Epoch 1, Average Loss: 0.004177435228484683
# Epoch 2, Average Loss: 0.0003461063653958263
# Epoch 3, Average Loss: 9.215148966177367e-05
# Epoch 4, Average Loss: 3.570733920241764e-05
# Epoch 5, Average Loss: 1.6313575611093255e-05
# Epoch 6, Average Loss: 7.627941045029729e-06
# Epoch 7, Average Loss: 5.810464085698186e-06
# Epoch 8, Average Loss: 3.740439979083021e-06
# Epoch 9, Average Loss: 2.775043725478099e-06
# Epoch 10, Average Loss: 2.4248483498467975e-06
# Epoch 11, Average Loss: 2.107167020426459e-06
# Epoch 12, Average Loss: 3.4968795091572246e-06
# Epoch 13, Average Loss: 3.75749646082113e-06
# Epoch 14, Average Loss: 1.5361182022388675e-06
# Epoch 15, Average Loss: 1.2195205243870077e-06
# Epoch 16, Average Loss: 1.0089065170859612e-06
# Epoch 17, Average Loss: 1.155589478685215e-06
# Epoch 18, Average Loss: 1.0386299607034744e-06
# Epoch 19, Average Loss: 1.4505262271313768e-06
# Epoch 20, Average Loss: 1.6458587168699523e-06
# Epoch 21, Average Loss: 5.324640505932621e-06
# Epoch 22, Average Loss: 2.1320467396890307e-06
# Epoch 23, Average Loss: 1.963033673746395e-06
# Epoch 24, Average Loss: 1.5696437657197747e-06
# Epoch 25, Average Loss: 1.4532703076497455e-06
# Epoch 26, Average Loss: 1.016868213810085e-06
# Epoch 27, Average Loss: 1.5027018790192414e-06
# Epoch 28, Average Loss: 1.1361370482632082e-06
# Epoch 29, Average Loss: 6.027272249298221e-07
# Epoch 30, Average Loss: 9.190148759330441e-07
# Epoch 31, Average Loss: 7.347379337829807e-07
# Epoch 32, Average Loss: 1.694712281619104e-06
# Epoch 33, Average Loss: 1.940072189654529e-06
# Epoch 34, Average Loss: 6.464788384619169e-07
# Epoch 35, Average Loss: 1.5517969188749704e-06
# Epoch 36, Average Loss: 7.588432410443602e-07
# Epoch 37, Average Loss: 4.4916273367334725e-07
# Epoch 38, Average Loss: 7.190868359430169e-07
# Epoch 39, Average Loss: 8.206449585657083e-07
# Epoch 40, Average Loss: 9.469162066011449e-07
# Epoch 41, Average Loss: 9.112312326919891e-07
# Epoch 42, Average Loss: 4.642800135457037e-07
# Epoch 43, Average Loss: 2.6735438822811376e-07
# Epoch 44, Average Loss: 4.207391341992661e-07
# Epoch 45, Average Loss: 1.2968462840490248e-06
# Epoch 46, Average Loss: 6.753910376744443e-07
# Epoch 47, Average Loss: 5.069919964739711e-07
# Epoch 48, Average Loss: 8.205858549104051e-07
# Epoch 49, Average Loss: 1.1853281904450342e-06
# Epoch 50, Average Loss: 4.7564930980570355e-07
# Epoch 51, Average Loss: 8.932779671511071e-07
# Epoch 52, Average Loss: 6.283520448846502e-07
# Epoch 53, Average Loss: 9.86729963869948e-07
# Epoch 54, Average Loss: 6.727221034452669e-07
# Epoch 55, Average Loss: 8.533395835286228e-07
# Epoch 56, Average Loss: 1.6257937545560707e-06
# Epoch 57, Average Loss: 3.0232744222757902e-06
# Epoch 58, Average Loss: 3.0078502334163203e-06
# Epoch 59, Average Loss: 1.923725538688359e-06
# Epoch 60, Average Loss: 2.2663283886004137e-06
# Epoch 61, Average Loss: 1.5353976863252683e-06
# Epoch 62, Average Loss: 2.765838289064959e-06
# Epoch 63, Average Loss: 6.842649094096487e-06
# Epoch 64, Average Loss: 2.2812941736560787e-06
# Epoch 65, Average Loss: 6.291806158742474e-07
# Epoch 66, Average Loss: 7.162650604186637e-07
# Epoch 67, Average Loss: 4.698123639457208e-07
# Epoch 68, Average Loss: 3.499181545407737e-07
# Epoch 69, Average Loss: 9.575640461889635e-07
# Epoch 70, Average Loss: 7.305657781842001e-07
# Epoch 71, Average Loss: 1.3075653470195903e-06
# Epoch 72, Average Loss: 1.355432527816447e-06
# Epoch 73, Average Loss: 2.0068960509433966e-06
# Epoch 74, Average Loss: 3.069811558020774e-06
# Epoch 75, Average Loss: 1.4929335071656169e-05
# Epoch 76, Average Loss: 2.0691772897407644e-05
# Epoch 77, Average Loss: 1.676116557973728e-05
# Epoch 78, Average Loss: 1.5202251893242646e-05
# Epoch 79, Average Loss: 1.3503996592589829e-05
# Epoch 80, Average Loss: 6.696216598811589e-06
# Epoch 81, Average Loss: 3.844993130996954e-06
# Epoch 82, Average Loss: 2.191110212379499e-06
# Epoch 83, Average Loss: 2.0600036890527917e-06
# Epoch 84, Average Loss: 1.0977248919630255e-06
# Epoch 85, Average Loss: 5.363423986182169e-06
# Epoch 86, Average Loss: 8.976115441328148e-06
# Epoch 87, Average Loss: 5.950889607220233e-06
# Epoch 88, Average Loss: 2.9017584800783426e-06
# Epoch 89, Average Loss: 5.1598807260688774e-06
# Epoch 90, Average Loss: 3.5538344306473847e-06
# Epoch 91, Average Loss: 5.047041543093655e-06
# Epoch 92, Average Loss: 1.2665712802117924e-06
# Epoch 93, Average Loss: 9.58125065153581e-07
# Epoch 94, Average Loss: 1.2281334790031905e-06
# Epoch 95, Average Loss: 2.5198612235044495e-06
# Epoch 96, Average Loss: 2.3269690615279614e-06
# Epoch 97, Average Loss: 1.7650034763505572e-06
# Epoch 98, Average Loss: 9.231681829646732e-07
# Epoch 99, Average Loss: 1.2995779627544835e-06
# Epoch 100, Average Loss: 9.384510057941498e-07
# Epoch 1, Average Loss: 10.728976774215699
# Epoch 2, Average Loss: 3.8123341262340547
# Epoch 3, Average Loss: 1.7935646504163743
# Epoch 4, Average Loss: 0.8192381113767624
# Epoch 5, Average Loss: 0.5372929349541664
# Epoch 6, Average Loss: 0.4231597870588303
# Epoch 7, Average Loss: 0.31500489115715025
# Epoch 8, Average Loss: 0.22296061366796494
# Epoch 9, Average Loss: 0.16095768548548223
# Epoch 10, Average Loss: 0.1598039399832487
# Epoch 11, Average Loss: 0.09363355152308941
# Epoch 12, Average Loss: 0.0927733026444912
# Epoch 13, Average Loss: 0.0642079560086131
# Epoch 14, Average Loss: 0.05263256346806884
# Epoch 15, Average Loss: 0.051809544675052166
# Epoch 16, Average Loss: 0.05849972553551197
# Epoch 17, Average Loss: 0.030988254863768817
# Epoch 18, Average Loss: 0.02213016846217215
# Epoch 19, Average Loss: 0.0165749600622803
# Epoch 20, Average Loss: 0.016563427913933993
# Epoch 21, Average Loss: 0.016464164573699237
# Epoch 22, Average Loss: 0.02739885961636901
# Epoch 23, Average Loss: 0.028453834005631506
# Epoch 24, Average Loss: 0.02839186703786254
# Epoch 25, Average Loss: 0.017269829823635518
# Epoch 26, Average Loss: 0.01306348443031311
# Epoch 27, Average Loss: 0.01181536668445915
# Epoch 28, Average Loss: 0.0140163017436862
# Epoch 29, Average Loss: 0.02710462175309658
# Epoch 30, Average Loss: 0.015705258306115865
# Epoch 31, Average Loss: 0.012139758886769414
# Epoch 32, Average Loss: 0.009404713264666497
# Epoch 33, Average Loss: 0.005419222894124687
# Epoch 34, Average Loss: 0.004275947291171178
# Epoch 35, Average Loss: 0.005639461381360888
# Epoch 36, Average Loss: 0.01239266770426184
# Epoch 37, Average Loss: 0.007136067433748394
# Epoch 38, Average Loss: 0.009201337688136847
# Epoch 39, Average Loss: 0.017267157835885883
# Epoch 40, Average Loss: 0.0183389495825395
# Epoch 41, Average Loss: 0.011287102149799466
# Epoch 42, Average Loss: 0.006799892662093044
# Epoch 43, Average Loss: 0.005522711481899023
# Epoch 44, Average Loss: 0.005561735067749396
# Epoch 45, Average Loss: 0.012320659263059497
# Epoch 46, Average Loss: 0.021088317083194853
# Epoch 47, Average Loss: 0.023023494915105403
# Epoch 48, Average Loss: 0.02457110055256635
# Epoch 49, Average Loss: 0.019363668747246265
# Epoch 50, Average Loss: 0.006789245002437383
# Epoch 51, Average Loss: 0.00434815205517225
# Epoch 52, Average Loss: 0.0035622705589048566
# Epoch 53, Average Loss: 0.0027235189452767374
# Epoch 54, Average Loss: 0.005294919206062332
# Epoch 55, Average Loss: 0.005227638495853171
# Epoch 56, Average Loss: 0.004091284133028239
# Epoch 57, Average Loss: 0.004019566741771996
# Epoch 58, Average Loss: 0.003663934097858146
# Epoch 59, Average Loss: 0.007172534335404634
# Epoch 60, Average Loss: 0.00716332244919613
# Epoch 61, Average Loss: 0.009202049567829818
# Epoch 62, Average Loss: 0.009069046622607857
# Epoch 63, Average Loss: 0.012116656545549631
# Epoch 64, Average Loss: 0.0180737265618518
# Epoch 65, Average Loss: 0.021909059025347233
# Epoch 66, Average Loss: 0.014714796864427625
# Epoch 67, Average Loss: 0.009597623511217535
# Epoch 68, Average Loss: 0.01369177340529859
# Epoch 69, Average Loss: 0.01093109855428338
# Epoch 70, Average Loss: 0.007845244300551713
# Epoch 71, Average Loss: 0.005083152477163821
# Epoch 72, Average Loss: 0.00407362095429562
# Epoch 73, Average Loss: 0.0035180407168809323
# Epoch 74, Average Loss: 0.002460210822755471
# Epoch 75, Average Loss: 0.00430276351980865
# Epoch 76, Average Loss: 0.0038656862336210905
# Epoch 77, Average Loss: 0.007910115842241794
# Epoch 78, Average Loss: 0.010281897720415146
# Epoch 79, Average Loss: 0.015969165740534662
# Epoch 80, Average Loss: 0.009025482868310064
# Epoch 81, Average Loss: 0.009135343157686293
# Epoch 82, Average Loss: 0.007218775933142752
# Epoch 83, Average Loss: 0.004880189604591578
# Epoch 84, Average Loss: 0.002946441707899794
# Epoch 85, Average Loss: 0.00930956580559723
# Epoch 86, Average Loss: 0.0059752311790362
# Epoch 87, Average Loss: 0.024601454567164182
# Epoch 88, Average Loss: 0.06974159674718976
# Epoch 89, Average Loss: 0.053768896404653786
# Epoch 90, Average Loss: 0.04209492895752191
# Epoch 91, Average Loss: 0.014755127672106027
# Epoch 92, Average Loss: 0.005976208945503459
# Epoch 93, Average Loss: 0.009005587268620729
# Epoch 94, Average Loss: 0.006327266141306609
# Epoch 95, Average Loss: 0.0033289109647739678
# Epoch 96, Average Loss: 0.0022325393103528766
# Epoch 97, Average Loss: 0.001879598235245794
# Epoch 98, Average Loss: 0.004082396248122677
# Epoch 99, Average Loss: 0.004565751412883401
# Epoch 100, Average Loss: 0.004605293372878805
# Epoch 1, Average Loss: 3.961193877458572
# Epoch 2, Average Loss: 1.2173039883375167
# Epoch 3, Average Loss: 0.4883507385849953
# Epoch 4, Average Loss: 0.32928775176405906
# Epoch 5, Average Loss: 0.22082572504878045
# Epoch 6, Average Loss: 0.1850836645811796
# Epoch 7, Average Loss: 0.15010831244289874
# Epoch 8, Average Loss: 0.13734469413757325
# Epoch 9, Average Loss: 0.11790424697101116
# Epoch 10, Average Loss: 0.11120322588831186
# Epoch 11, Average Loss: 0.07632684204727411
# Epoch 12, Average Loss: 0.06913911867886782
# Epoch 13, Average Loss: 0.03649384872987867
# Epoch 14, Average Loss: 0.027916694432497023
# Epoch 15, Average Loss: 0.020043610641732813
# Epoch 16, Average Loss: 0.021564356796443463
# Epoch 17, Average Loss: 0.019255015649832785
# Epoch 18, Average Loss: 0.015618920233100653
# Epoch 19, Average Loss: 0.013177854451350867
# Epoch 20, Average Loss: 0.01296494179405272
# Epoch 21, Average Loss: 0.01370178391225636
# Epoch 22, Average Loss: 0.02716727149672806
# Epoch 23, Average Loss: 0.012337587075307965
# Epoch 24, Average Loss: 0.007197963492944837
# Epoch 25, Average Loss: 0.010564675880596041
# Epoch 26, Average Loss: 0.008037229208275676
# Epoch 27, Average Loss: 0.006481808552052826
# Epoch 28, Average Loss: 0.00501184823224321
# Epoch 29, Average Loss: 0.008849406149238348
# Epoch 30, Average Loss: 0.005759598105214536
# Epoch 31, Average Loss: 0.0051809012307785455
# Epoch 32, Average Loss: 0.006859078211709857
# Epoch 33, Average Loss: 0.008032126643229276
# Epoch 34, Average Loss: 0.010651062882971019
# Epoch 35, Average Loss: 0.009005100571084768
# Epoch 36, Average Loss: 0.010185215435922147
# Epoch 37, Average Loss: 0.009851225186139345
# Epoch 38, Average Loss: 0.01000302736647427
# Epoch 39, Average Loss: 0.004942132101859897
# Epoch 40, Average Loss: 0.004642140597570688
# Epoch 41, Average Loss: 0.003464140318101272
# ...
# Epoch 52, Average Loss: 0.0007142523056245409
# Epoch 53, Average Loss: 0.0004306222559534945
# Epoch 54, Average Loss: 0.0002794557323795743
# Epoch 55, Average Loss: 0.00043326682862243615
# Epoch 56, Average Loss: 0.0002451751384796808
# Epoch 57, Average Loss: 0.00016630074915156002
# Epoch 58, Average Loss: 0.0001522907110484084
# Epoch 59, Average Loss: 0.00014256034828576957
# Epoch 60, Average Loss: 0.0003160984098940389
# Epoch 61, Average Loss: 0.00044098807265982034
# Epoch 62, Average Loss: 0.00024988016630231866
# Epoch 63, Average Loss: 0.0001828943637519842
# Epoch 64, Average Loss: 0.00022850393506814725
# Epoch 65, Average Loss: 0.00019944785053667148
# Epoch 66, Average Loss: 0.00024425611136393857
# Epoch 67, Average Loss: 0.00022074825719755608
# Epoch 68, Average Loss: 0.00019667527194542345
# Epoch 69, Average Loss: 0.000554890010971576
# Epoch 70, Average Loss: 0.00032549019597354344
# Epoch 71, Average Loss: 0.0009384245586261386
# Epoch 72, Average Loss: 0.0021011115837609395
# Epoch 73, Average Loss: 0.005444908168283291
# Epoch 74, Average Loss: 0.011321751039940865
# Epoch 75, Average Loss: 0.045257952297106385
# Epoch 76, Average Loss: 0.019198935444001107
# Epoch 77, Average Loss: 0.006104676780523732
# Epoch 78, Average Loss: 0.0016005910671083256
# Epoch 79, Average Loss: 0.001685713286860846
# Epoch 80, Average Loss: 0.0011694840170093812
# Epoch 81, Average Loss: 0.0007343292818404734
# Epoch 82, Average Loss: 0.0006978403485845775
# Epoch 83, Average Loss: 0.00044057108607375994
# Epoch 84, Average Loss: 0.0002523927738366183
# Epoch 85, Average Loss: 0.00020834088463743682
# Epoch 86, Average Loss: 0.00027835592009068933
# Epoch 87, Average Loss: 0.00031739558580738957
# Epoch 88, Average Loss: 0.00020683859111159109
# Epoch 89, Average Loss: 0.00021185552468523384
# Epoch 90, Average Loss: 0.00022461295702669304
# Epoch 91, Average Loss: 0.00034933364349853946
# Epoch 92, Average Loss: 0.00021640421255142428
# Epoch 93, Average Loss: 0.00013912156919104746
# Epoch 94, Average Loss: 0.00027064193454862107
# Epoch 95, Average Loss: 0.001125544806200196
# Epoch 96, Average Loss: 0.001324503203795757
# Epoch 97, Average Loss: 0.0030903725972166287
# Epoch 98, Average Loss: 0.0015517745654506144
# Epoch 99, Average Loss: 0.0009103334610699676
# Epoch 100, Average Loss: 0.00045180785164120605
# Epoch 1, Average Loss: 6.136389771103859
# Epoch 2, Average Loss: 0.6357825681567192
# Epoch 3, Average Loss: 0.19135481677949429
# Epoch 4, Average Loss: 0.06251946883276105
# Epoch 5, Average Loss: 0.03692252617329359
# Epoch 6, Average Loss: 0.02692260257899761
# Epoch 7, Average Loss: 0.026330593368038537
# Epoch 8, Average Loss: 0.024111181683838367
# Epoch 9, Average Loss: 0.02288816710934043
# Epoch 10, Average Loss: 0.022725363634526728
# Epoch 11, Average Loss: 0.019714144757017493
# Epoch 12, Average Loss: 0.020357265137135983
# Epoch 13, Average Loss: 0.019154788553714754
# Epoch 14, Average Loss: 0.018409610725939274
# Epoch 15, Average Loss: 0.014626087923534214
# Epoch 16, Average Loss: 0.012621892942115664
# Epoch 17, Average Loss: 0.013976007304154336
# Epoch 18, Average Loss: 0.012069186219014228
# Epoch 19, Average Loss: 0.011556838685646654
# Epoch 20, Average Loss: 0.010070272302255035
# Epoch 21, Average Loss: 0.008888454141560942
# Epoch 22, Average Loss: 0.008452855865471065
# Epoch 23, Average Loss: 0.0075914411339908835
# Epoch 24, Average Loss: 0.010390113992616534
# Epoch 25, Average Loss: 0.01439672107808292
# Epoch 26, Average Loss: 0.008114634873345494
# Epoch 27, Average Loss: 0.0076536037493497135
# Epoch 28, Average Loss: 0.006624242628458887
# Epoch 29, Average Loss: 0.00666422100039199
# Epoch 30, Average Loss: 0.004924910212866962
# Epoch 31, Average Loss: 0.005785843939520419
# Epoch 32, Average Loss: 0.009715542802587152
# Epoch 33, Average Loss: 0.00848621625918895
# Epoch 34, Average Loss: 0.00408985247486271
# Epoch 35, Average Loss: 0.0038051466806791725
# Epoch 36, Average Loss: 0.005650814436376095
# Epoch 37, Average Loss: 0.007818286074325442
# Epoch 38, Average Loss: 0.006364084407687187
# Epoch 39, Average Loss: 0.004929304902907461
# Epoch 40, Average Loss: 0.004696831735782325
# Epoch 41, Average Loss: 0.005631144164362922
# Epoch 42, Average Loss: 0.0038762184791266917
# Epoch 43, Average Loss: 0.003939421824179589
# Epoch 44, Average Loss: 0.003499566181562841
# Epoch 45, Average Loss: 0.0032604590815026313
# Epoch 46, Average Loss: 0.003708670608466491
# Epoch 47, Average Loss: 0.002622214291477576
# Epoch 48, Average Loss: 0.0024029335705563425
# Epoch 49, Average Loss: 0.0037253912829328328
# Epoch 50, Average Loss: 0.004227370908483863
# Epoch 51, Average Loss: 0.005251529562519864
# Epoch 52, Average Loss: 0.0047766787640284745
# Epoch 53, Average Loss: 0.003456084622303024
# Epoch 54, Average Loss: 0.005473820707993582
# Epoch 55, Average Loss: 0.004613821872044355
# Epoch 56, Average Loss: 0.004626189259579405
# Epoch 57, Average Loss: 0.003371783741749823
# Epoch 58, Average Loss: 0.003658494009869173
# Epoch 59, Average Loss: 0.0033018737973179667
# Epoch 60, Average Loss: 0.003536062123021111
# Epoch 61, Average Loss: 0.00542147820815444
# Epoch 62, Average Loss: 0.004001290700398385
# Epoch 63, Average Loss: 0.0027982750383671374
# Epoch 64, Average Loss: 0.0031757948454469442
# Epoch 65, Average Loss: 0.004906367114745081
# Epoch 66, Average Loss: 0.00297558288439177
# Epoch 67, Average Loss: 0.0033536229573655875
# Epoch 68, Average Loss: 0.0019038499536691233
# Epoch 69, Average Loss: 0.001759903519996442
# Epoch 70, Average Loss: 0.0020694619743153453
# Epoch 71, Average Loss: 0.0018880271527450532
# Epoch 72, Average Loss: 0.0028798733721487222
# Epoch 73, Average Loss: 0.0021169819112401454
# Epoch 74, Average Loss: 0.004281077132327482
# Epoch 75, Average Loss: 0.005398145667277277
# Epoch 76, Average Loss: 0.00614701472222805
# Epoch 77, Average Loss: 0.008008220477495342
# Epoch 78, Average Loss: 0.008216908504255115
# Epoch 79, Average Loss: 0.0034048850066028535
# Epoch 80, Average Loss: 0.009064456378109754
# Epoch 81, Average Loss: 0.00310666914738249
# Epoch 82, Average Loss: 0.004957958980230615
# Epoch 83, Average Loss: 0.006569613888859749
# Epoch 84, Average Loss: 0.022750020632520317
# Epoch 85, Average Loss: 0.021206399798393248
# Epoch 86, Average Loss: 0.007508812181185931
# Epoch 87, Average Loss: 0.003672522882698104
# Epoch 88, Average Loss: 0.003911704564234242
# Epoch 89, Average Loss: 0.008026079286355525
# Epoch 90, Average Loss: 0.005653707613237202
# Epoch 91, Average Loss: 0.003861756419064477
# Epoch 92, Average Loss: 0.0024553177761845292
# Epoch 93, Average Loss: 0.0023843177157687025
# Epoch 94, Average Loss: 0.003985903860302642
# Epoch 95, Average Loss: 0.004624900873750448
# Epoch 96, Average Loss: 0.00208751444297377
# Epoch 97, Average Loss: 0.00134279815829359
# Epoch 98, Average Loss: 0.0014066369883948937
# Epoch 99, Average Loss: 0.0020832326350500806
# Epoch 100, Average Loss: 0.0019334474200149998
# Epoch 1, Average Loss: 1.5793516788631679
# Epoch 2, Average Loss: 0.11111230654641986
# Epoch 3, Average Loss: 0.02705793408676982
# Epoch 4, Average Loss: 0.013065573526546359
# Epoch 5, Average Loss: 0.00624571586959064
# Epoch 6, Average Loss: 0.003898480167845264
# Epoch 7, Average Loss: 0.0023044578614644707
# Epoch 8, Average Loss: 0.0014526529732393101
# Epoch 9, Average Loss: 0.0015540171938482673
# Epoch 10, Average Loss: 0.0011780869477661326
# Epoch 11, Average Loss: 0.001065154914977029
# Epoch 12, Average Loss: 0.001190082245739177
# Epoch 13, Average Loss: 0.0009545651089865714
# Epoch 14, Average Loss: 0.0008184224599972368
# Epoch 15, Average Loss: 0.0007745833150693216
# Epoch 16, Average Loss: 0.0007376321053015999
# Epoch 17, Average Loss: 0.0007616362854605541
# Epoch 18, Average Loss: 0.0006381289233104326
# Epoch 19, Average Loss: 0.0005858957461896353
# Epoch 20, Average Loss: 0.0008717893026187085
# Epoch 21, Average Loss: 0.0007279262252268381
# Epoch 22, Average Loss: 0.0007393996682367287
# Epoch 23, Average Loss: 0.0010139982608961874
# Epoch 24, Average Loss: 0.0010588953009573743
# Epoch 25, Average Loss: 0.0007140727291698567
# Epoch 26, Average Loss: 0.0006500314237200655
# Epoch 27, Average Loss: 0.0009967249439796432
# Epoch 28, Average Loss: 0.0005061809351900592
# Epoch 29, Average Loss: 0.00050405972142471
# Epoch 30, Average Loss: 0.00047096707712626087
# Epoch 31, Average Loss: 0.0003810912312474102
# Epoch 32, Average Loss: 0.000285625012111268
# Epoch 33, Average Loss: 0.0002734729467192665
# Epoch 34, Average Loss: 0.0003905567005858757
# Epoch 35, Average Loss: 0.00036486675126070625
# Epoch 36, Average Loss: 0.00048416491044918076
# Epoch 37, Average Loss: 0.00044498847491922786
# Epoch 38, Average Loss: 0.00037158701961743646
# Epoch 39, Average Loss: 0.00047222372795658886
# Epoch 40, Average Loss: 0.0003181853382557165
# Epoch 41, Average Loss: 0.0005479224673763383
# Epoch 42, Average Loss: 0.00033818702577264047
# Epoch 43, Average Loss: 0.00036095287287025714
# Epoch 44, Average Loss: 0.00042057024111272765
# Epoch 45, Average Loss: 0.00042249737889505924
# Epoch 46, Average Loss: 0.0006653381351497956
# Epoch 47, Average Loss: 0.0018807096035743597
# Epoch 48, Average Loss: 0.0009195290520437993
# Epoch 49, Average Loss: 0.0007839070756745059
# Epoch 50, Average Loss: 0.00045301816790015436
# Epoch 51, Average Loss: 0.00022315973656077402
# Epoch 52, Average Loss: 0.00018487385859771165
# Epoch 53, Average Loss: 0.00018679827189771459
# Epoch 54, Average Loss: 0.00019315608369652182
# Epoch 55, Average Loss: 0.00045023940401733853
# Epoch 56, Average Loss: 0.00023761607844789977
# Epoch 57, Average Loss: 0.0008084831148153171
# Epoch 58, Average Loss: 0.0004559556702588452
# Epoch 59, Average Loss: 0.0006092817209719214
# Epoch 60, Average Loss: 0.00035423802291916217
# Epoch 61, Average Loss: 0.0002470547264238121
# Epoch 62, Average Loss: 0.0003494613767543342
# Epoch 63, Average Loss: 0.001394963676284533
# Epoch 64, Average Loss: 0.001073588968574768
# Epoch 65, Average Loss: 0.0012008359582978301
# Epoch 66, Average Loss: 0.001787063106894493
# Epoch 67, Average Loss: 0.0007869016037147958
# Epoch 68, Average Loss: 0.0008363345703401137
# Epoch 69, Average Loss: 0.0005511381321412045
# Epoch 70, Average Loss: 0.00027801452852145304
# Epoch 71, Average Loss: 0.0001606764108146308
# Epoch 72, Average Loss: 0.00016200807422137587
# Epoch 73, Average Loss: 0.0001358672456262866
# Epoch 74, Average Loss: 0.00017468410569563276
# Epoch 75, Average Loss: 0.0006175698043080046
# Epoch 76, Average Loss: 0.0009251574439986144
# Epoch 77, Average Loss: 0.0019133966619847343
# Epoch 78, Average Loss: 0.0012768823566148058
# Epoch 79, Average Loss: 0.0009574294381309301
# Epoch 80, Average Loss: 0.0007227296577184461
# Epoch 81, Average Loss: 0.0004524366380792344
# Epoch 82, Average Loss: 0.0008189609179680701
# Epoch 83, Average Loss: 0.001267754904984031
# Epoch 84, Average Loss: 0.0015317892029997893
# Epoch 85, Average Loss: 0.0012500333818024957
# Epoch 86, Average Loss: 0.0011340418612235225
# Epoch 87, Average Loss: 0.001095461165823508
# Epoch 88, Average Loss: 0.0012298046654905192
# Epoch 89, Average Loss: 0.0013496966872480697
# Epoch 90, Average Loss: 0.001559437930700369
# Epoch 91, Average Loss: 0.001059200927556958
# Epoch 92, Average Loss: 0.0005275336989143398
# Epoch 93, Average Loss: 0.0006817350433266256
# Epoch 94, Average Loss: 0.0007719861940131522
# Epoch 95, Average Loss: 0.0004530033613264095
# Epoch 96, Average Loss: 0.0006816126850026194
# Epoch 97, Average Loss: 0.0011732398423191625
# Epoch 98, Average Loss: 0.0017145481629995628
# Epoch 99, Average Loss: 0.0029277149311383254
# Epoch 100, Average Loss: 0.002114752895431593
# Epoch 1, Average Loss: 1.11181733161211
# Epoch 2, Average Loss: 0.10591666027903557
# Epoch 3, Average Loss: 0.04000034807249904
# Epoch 4, Average Loss: 0.01809979951940477
# Epoch 5, Average Loss: 0.007603500620462
# Epoch 6, Average Loss: 0.004443850059760735
# Epoch 7, Average Loss: 0.002118186926236376
# Epoch 8, Average Loss: 0.0012121775711420924
# Epoch 9, Average Loss: 0.0010882660048082472
# Epoch 10, Average Loss: 0.001130838770768605
# Epoch 11, Average Loss: 0.0009649163344874978
# Epoch 12, Average Loss: 0.0008305935160024091
# Epoch 13, Average Loss: 0.0006514482462080196
# Epoch 14, Average Loss: 0.0008989847599877975
# Epoch 15, Average Loss: 0.0008413010378717445
# Epoch 16, Average Loss: 0.0006222700845682994
# Epoch 17, Average Loss: 0.0006852422797237523
# Epoch 18, Average Loss: 0.0005515096796443686
# Epoch 19, Average Loss: 0.00044286336778895927
# Epoch 20, Average Loss: 0.0004581345958285965
# Epoch 21, Average Loss: 0.0005528530731680803
# Epoch 22, Average Loss: 0.0007128572433430236
# Epoch 23, Average Loss: 0.000602202903246507
# Epoch 24, Average Loss: 0.00042441177138243804
# Epoch 25, Average Loss: 0.0003668092700536363
# Epoch 26, Average Loss: 0.0006100864920881577
# Epoch 27, Average Loss: 0.0006636473757680505
# Epoch 28, Average Loss: 0.0006939356586372014
# Epoch 29, Average Loss: 0.0006447081999795045
# Epoch 30, Average Loss: 0.0007806474866811186
# Epoch 31, Average Loss: 0.0007193375822680537
# Epoch 32, Average Loss: 0.0005005278129829094
# Epoch 33, Average Loss: 0.00028494647413026544
# Epoch 34, Average Loss: 0.00029706397217523774
# Epoch 35, Average Loss: 0.0002267383133585099
# Epoch 36, Average Loss: 0.0002471107665769523
# Epoch 37, Average Loss: 0.000479236694809515
# Epoch 38, Average Loss: 0.000550322639173828
# Epoch 39, Average Loss: 0.0005192942400753964
# Epoch 40, Average Loss: 0.0003476202800811734
# Epoch 41, Average Loss: 0.0002265440569317434
# Epoch 42, Average Loss: 0.00021792485204059632
# Epoch 43, Average Loss: 0.00012626975567400222
# Epoch 44, Average Loss: 0.0001839807468059007
# Epoch 45, Average Loss: 0.0001877502765637473
# Epoch 46, Average Loss: 9.884858100122074e-05
# Epoch 47, Average Loss: 0.00010720953505369835
# Epoch 48, Average Loss: 0.00012185106043034466
# Epoch 49, Average Loss: 0.0001330290097030229
# Epoch 50, Average Loss: 0.000298413423661259
# Epoch 51, Average Loss: 0.0001836958083003992
# Epoch 52, Average Loss: 0.00034082629063050265
# Epoch 53, Average Loss: 0.00016422391454398166
# Epoch 54, Average Loss: 0.00021688101151084993
# Epoch 55, Average Loss: 0.00017795400253817206
# Epoch 56, Average Loss: 0.00020178498925815802
# Epoch 57, Average Loss: 0.00010858636924240272
# Epoch 58, Average Loss: 0.00019034928609471536
# Epoch 59, Average Loss: 0.00022950124475755728
# Epoch 60, Average Loss: 0.00011698042108037044
# Epoch 61, Average Loss: 0.0002679210425412748
# Epoch 62, Average Loss: 0.0002717788051086245
# Epoch 63, Average Loss: 0.00023399149977194612
# Epoch 64, Average Loss: 0.0006014632022925071
# Epoch 65, Average Loss: 0.0013541786684072576
# Epoch 66, Average Loss: 0.00037421024790091907
# Epoch 67, Average Loss: 0.00019227799311920534
# Epoch 68, Average Loss: 0.00012392742773954525
# Epoch 69, Average Loss: 0.00016252744262601482
# Epoch 70, Average Loss: 0.00016673375212121754
# Epoch 71, Average Loss: 0.0007103558240487473
# Epoch 72, Average Loss: 0.0018311399660888128
# Epoch 73, Average Loss: 0.0013251319760456681
# Epoch 74, Average Loss: 0.0028546672459924594
# Epoch 75, Average Loss: 0.006034724778146483
# Epoch 76, Average Loss: 0.002775500010466203
# Epoch 77, Average Loss: 0.0009384675293404143
# Epoch 78, Average Loss: 0.0005039128118369263
# Epoch 79, Average Loss: 0.00021090236186864785
# Epoch 80, Average Loss: 0.00020534715804387815
# Epoch 81, Average Loss: 0.00033085688264691273
# Epoch 82, Average Loss: 0.0004769886283611413
# Epoch 83, Average Loss: 0.000303585200526868
# Epoch 84, Average Loss: 0.0002537039737944724
# Epoch 85, Average Loss: 0.0002673434657481266
# Epoch 86, Average Loss: 0.00015272824530256912
# Epoch 87, Average Loss: 0.00021776584108010866
# Epoch 88, Average Loss: 0.00025627683571656236
# Epoch 89, Average Loss: 0.0002236596715192718
# Epoch 90, Average Loss: 0.00015523991896770895
# Epoch 91, Average Loss: 0.0001511487327661598
# Epoch 92, Average Loss: 0.00010725816855483572
# Epoch 93, Average Loss: 0.00034481218417568014
# Epoch 94, Average Loss: 0.0006360112922266126
# Epoch 95, Average Loss: 0.0008461522855213843
# Epoch 96, Average Loss: 0.00015265324946085458
# Epoch 97, Average Loss: 0.00020027246027893854
# Epoch 98, Average Loss: 0.00017158131740870885
# Epoch 99, Average Loss: 0.00015590648581564892
# Epoch 100, Average Loss: 0.00024354372362722643
